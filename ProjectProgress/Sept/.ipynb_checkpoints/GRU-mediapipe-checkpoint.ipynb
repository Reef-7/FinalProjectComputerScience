# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import GRU, Dense, Input, Dropout, BatchNormalization, ReLU, LeakyReLU, Lambda
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, accuracy_score, classification_report
import os

# הגדרת פרמטרים
WINDOW_SIZE = 30  # מספר הפריימים ברצף
RANDOM_STATE = 42
BATCH_SIZE = 32
EPOCHS = 300
LEARNING_RATE = 0.001

# פונקציה חדשה ליצירת קלאסים מright/left scores
def create_dominance_labels(df, knee_threshold=None, elbow_threshold=None):
    """
    יוצר עמודות חדשות עם קלאסים: 0=right, 1=left, 2=no dominance
    """
    if knee_threshold is None:
        knee_threshold = df[['right_knee_score', 'left_knee_score']].max(axis=1).median() * 0.1
    if elbow_threshold is None:
        elbow_threshold = df[['right_elbow_score', 'left_elbow_score']].max(axis=1).median() * 0.1

    def get_class(right, left, thr):
        diff = abs(right - left)
        if diff < thr:
            return 2  # no dominance
        return 0 if right > left else 1

    df['dominant_knee'] = df.apply(
        lambda row: get_class(row['right_knee_score'], row['left_knee_score'], knee_threshold),
        axis=1
    )
    df['dominant_elbow'] = df.apply(
        lambda row: get_class(row['right_elbow_score'], row['left_elbow_score'], elbow_threshold),
        axis=1
    )
    return df

def load_and_preprocess_data(file_paths, window_size=WINDOW_SIZE):
    """
    טעינה ועיבוד מקדים של הנתונים מקבצי האקסל
    """
    all_data = []
    test_data = []

    for file_path in file_paths:
        df = pd.read_csv(file_path) if file_path.endswith('.csv') else pd.read_excel(file_path)

        required_columns = ['video_id', 'frame', 'window_id', 
                           'overall_movement_score', 'right_knee_score', 'left_knee_score',
                           'right_elbow_score', 'left_elbow_score']

        if not all(col in df.columns for col in required_columns):
            print(f"The file {file_path} is missing required columns. Skipping...")
            continue

        # יצירת הקלאסים החדשים
        df = create_dominance_labels(df)

        test_subset = df[df['video_id'].isin([43, 44])]
        if not test_subset.empty:
            test_data.append(test_subset)
        df = df[~df['video_id'].isin([43, 44])]
        all_data.append(df)

    if not all_data:
        raise ValueError("No valid files found for processing")

    data = pd.concat(all_data, ignore_index=True)
    return data, {}, test_data

def prepare_sequences(data, window_size=WINDOW_SIZE):
    feature_columns = [col for col in data.columns if any(x in col for x in ['_x', '_y', '_confidence'])
                        and not any(skip in col.lower() for skip in ['velocity', 'angle'])]

    X = []
    y_movement = []
    y_knee = []
    y_elbow = []

    groups = data.groupby(['video_id', 'window_id'])

    for (vid_id, win_id), group in groups:
        if len(group) < window_size:
            continue

        for i in range(0, len(group) - window_size + 1):
            sequence = group.iloc[i:i+window_size][feature_columns].values
            target_frame = group.iloc[i+window_size-1]

            X.append(sequence)
            y_movement.append(target_frame['overall_movement_score'])
            y_knee.append(target_frame['dominant_knee'])
            y_elbow.append(target_frame['dominant_elbow'])

    X = np.array(X)
    y_movement = np.array(y_movement)
    y_knee = np.array(y_knee)
    y_elbow = np.array(y_elbow)

    return X, y_movement, y_knee, y_elbow, feature_columns

def build_gru_model(input_shape, num_knee_classes, num_elbow_classes):
    inputs = Input(shape=input_shape)
    x = GRU(128, return_sequences=True)(inputs)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)

    x = GRU(64)(x)
    x = BatchNormalization()(x)
    shared_features = Dropout(0.3)(x)

    movement_output = Dense(32, activation='relu')(shared_features)
    movement_output = Dense(1)(movement_output)
    movement_output = ReLU(max_value=10, name='movement_score')(movement_output)

    knee_output = Dense(32)(shared_features)
    knee_output = LeakyReLU(alpha=0.01)(knee_output)
    knee_output = Dense(num_knee_classes, activation='softmax', name='dominant_knee')(knee_output)

    elbow_output = Dense(32)(shared_features)
    elbow_output = LeakyReLU(alpha=0.01)(elbow_output)
    elbow_output = Dense(num_elbow_classes, activation='softmax', name='dominant_elbow')(elbow_output)

    model = Model(inputs=inputs, outputs=[movement_output, knee_output, elbow_output])

    model.compile(
        optimizer=Adam(learning_rate=LEARNING_RATE),
        loss={
            'movement_score': 'mean_squared_error',
            'dominant_knee': 'sparse_categorical_crossentropy',
            'dominant_elbow': 'sparse_categorical_crossentropy'
        },
        metrics={
            'movement_score': ['mae'],
            'dominant_knee': ['accuracy'],
            'dominant_elbow': ['accuracy']
        }
    )

    return model

def train_model(X_train, y_train, X_val, y_val, input_shape, num_knee_classes, num_elbow_classes):
    model = build_gru_model(input_shape, num_knee_classes, num_elbow_classes)

    early_stopping = EarlyStopping(
        monitor='val_loss', 
        patience=50, 
        restore_best_weights=True
    )

    reduce_lr = ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        min_lr=0.00001
    )

    model_checkpoint = ModelCheckpoint(
        'best_mediapipe_infant_movement_model_3class.keras', 
        monitor='val_loss',
        save_best_only=True,
        verbose=1
    )

    history = model.fit(
        X_train,
        y_train,
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=(X_val, y_val),
        callbacks=[early_stopping, reduce_lr, model_checkpoint],
        verbose=1
    )

    return model, history

def evaluate_model(model, X_test, y_test_movement, y_test_knee, y_test_elbow, label_encoders):
    y_pred_movement, y_pred_knee_prob, y_pred_elbow_prob = model.predict(X_test)

    y_pred_knee = np.argmax(y_pred_knee_prob, axis=1)
    y_pred_elbow = np.argmax(y_pred_elbow_prob, axis=1)

    mse_movement = mean_squared_error(y_test_movement, y_pred_movement)
    rmse_movement = np.sqrt(mse_movement)

    knee_accuracy = accuracy_score(y_test_knee, y_pred_knee)
    elbow_accuracy = accuracy_score(y_test_elbow, y_pred_elbow)

    print("\n===== תוצאות המודל =====")
    print(f"RMSE for motion score: {rmse_movement:.4f}")
    print(f"דיוק סיווג ברך דומיננטית: {knee_accuracy:.4f}")
    print(f"דיוק סיווג מרפק דומיננטי: {elbow_accuracy:.4f}")

    print("\nדוח סיווג - ברך דומיננטית:")
    print(classification_report(y_test_knee, y_pred_knee))

    print("\nדוח סיווג - מרפק דומיננטי:")
    print(classification_report(y_test_elbow, y_pred_elbow))

    return {
        'rmse_movement': rmse_movement,
        'knee_accuracy': knee_accuracy,
        'elbow_accuracy': elbow_accuracy
    }

def plot_training_history(history):
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))

    axes[0, 0].plot(history.history['loss'], label='Train Loss')
    axes[0, 0].plot(history.history['val_loss'], label='Validation Loss')
    axes[0, 0].set_title('Total Loss')
    axes[0, 0].legend()

    axes[0, 1].plot(history.history['dominant_knee_accuracy'], label='Train Accuracy')
    axes[0, 1].plot(history.history['val_dominant_knee_accuracy'], label='Validation Accuracy')
    axes[0, 1].set_title('Dominant Knee Accuracy')
    axes[0, 1].legend()

    axes[1, 0].plot(history.history['dominant_elbow_accuracy'], label='Train Accuracy')
    axes[1, 0].plot(history.history['val_dominant_elbow_accuracy'], label='Validation Accuracy')
    axes[1, 0].set_title('Dominant Elbow Accuracy')
    axes[1, 0].legend()

    axes[1, 1].plot(history.history['movement_score_mae'], label='Train MAE')
    axes[1, 1].plot(history.history['val_movement_score_mae'], label='Validation MAE')
    axes[1, 1].set_title('Movement Score MAE')
    axes[1, 1].legend()

    plt.tight_layout()
    plt.savefig('training_history_3class.png')
    plt.show()

def main():
    file_paths = ['mediapipe_dataset.csv']

    if not os.path.exists('mediapipe_dataset.csv'):
        print("שגיאה: הקובץ 'mediapipe_dataset.csv' לא נמצא בתיקייה הנוכחית")
        return

    print(f"מתחיל עיבוד של הקובץ: {file_paths[0]}")

    try:
        data, label_encoders, test_data = load_and_preprocess_data(file_paths)
        print(f"נטענו {len(data)} שורות נתונים")
    except Exception as e:
        print(f"שגיאה בטעינת הנתונים: {e}")
        return

    if test_data:
        test_df = pd.concat(test_data, ignore_index=True)
        test_df.to_csv('test_mediapipe_dataset.csv', index=False)
        print("קובץ test_mediapipe_dataset.csv נשמר בהצלחה.")
    else:
        print("לא נמצאו נתוני test_data לשמירה.")

    X, y_movement, y_knee, y_elbow, feature_columns = prepare_sequences(data)

    num_knee_classes = len(np.unique(y_knee))
    num_elbow_classes = len(np.unique(y_elbow))

    X_train_val, X_test, y_movement_train_val, y_movement_test, \
    y_knee_train_val, y_knee_test, y_elbow_train_val, y_elbow_test = train_test_split(
        X, y_movement, y_knee, y_elbow, test_size=0.2, random_state=RANDOM_STATE
    )

    X_train, X_val, y_movement_train, y_movement_val, \
    y_knee_train, y_knee_val, y_elbow_train, y_elbow_val = train_test_split(
        X_train_val, y_movement_train_val, y_knee_train_val, y_elbow_train_val, 
        test_size=0.2, random_state=RANDOM_STATE
    )

    input_shape = (X_train.shape[1], X_train.shape[2])

    y_train = [y_movement_train, y_knee_train, y_elbow_train]
    y_val = [y_movement_val, y_knee_val, y_elbow_val]

    model, history = train_model(
        X_train, y_train, X_val, y_val, 
        input_shape, num_knee_classes, num_elbow_classes
    )

    results = evaluate_model(
        model, X_test, y_movement_test, y_knee_test, y_elbow_test, label_encoders
    )

    plot_training_history(history)

    model.save('infant_mediapipe_movement_gru_model_3class.keras')
    print("המודל נשמר בהצלחה כקובץ 'infant_mediapipe_movement_gru_model_3class.keras'")

    with open('model_features_3class.txt', 'w') as f:
        f.write('\n'.join(feature_columns))

    print("\nהאימון הסתיים בהצלחה!")

if __name__ == "__main__":
    main()
# Out:
# מתחיל עיבוד של הקובץ: mediapipe_dataset.csv
# נטענו 55078 שורות נתונים
# קובץ test_mediapipe_dataset.csv נשמר בהצלחה.
# C:\Users\user\anaconda3\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Epoch 1/300
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dominant_elbow_accuracy: 0.3587 - dominant_elbow_loss: 1.2142 - dominant_knee_accuracy: 0.4670 - dominant_knee_loss: 1.1231 - loss: 11.6312 - movement_score_loss: 9.2939 - movement_score_mae: 2.3939
# Epoch 1: val_loss improved from inf to 4.68776, saving model to best_mediapipe_infant_movement_model_3class.keras
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 39s 49ms/step - dominant_elbow_accuracy: 0.3587 - dominant_elbow_loss: 1.2141 - dominant_knee_accuracy: 0.4670 - dominant_knee_loss: 1.1230 - loss: 11.6244 - movement_score_loss: 9.2874 - movement_score_mae: 2.3928 - val_dominant_elbow_accuracy: 0.4283 - val_dominant_elbow_loss: 1.0606 - val_dominant_knee_accuracy: 0.5320 - val_dominant_knee_loss: 1.0010 - val_loss: 4.6878 - val_movement_score_loss: 2.6270 - val_movement_score_mae: 1.1944 - learning_rate: 0.0010
# Epoch 2/300
# 562/563 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - dominant_elbow_accuracy: 0.4070 - dominant_elbow_loss: 1.0855 - dominant_knee_accuracy: 0.5299 - dominant_knee_loss: 0.9950 - loss: 4.9827 - movement_score_loss: 2.9021 - movement_score_mae: 1.2915
# Epoch 2: val_loss did not improve from 4.68776
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 25s 45ms/step - dominant_elbow_accuracy: 0.4070 - dominant_elbow_loss: 1.0855 - dominant_knee_accuracy: 0.5299 - dominant_knee_loss: 0.9950 - loss: 4.9825 - movement_score_loss: 2.9020 - movement_score_mae: 1.2915 - val_dominant_elbow_accuracy: 0.4276 - val_dominant_elbow_loss: 1.0577 - val_dominant_knee_accuracy: 0.5253 - val_dominant_knee_loss: 0.9721 - val_loss: 4.7453 - val_movement_score_loss: 2.7156 - val_movement_score_mae: 1.1979 - learning_rate: 0.0010
# Epoch 3/300
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - dominant_elbow_accuracy: 0.4001 - dominant_elbow_loss: 1.0857 - dominant_knee_accuracy: 0.5338 - dominant_knee_loss: 0.9836 - loss: 4.8684 - movement_score_loss: 2.7991 - movement_score_mae: 1.2688
# Epoch 3: val_loss did not improve from 4.68776
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 25s 45ms/step - dominant_elbow_accuracy: 0.4001 - dominant_elbow_loss: 1.0857 - dominant_knee_accuracy: 0.5338 - dominant_knee_loss: 0.9836 - loss: 4.8684 - movement_score_loss: 2.7991 - movement_score_mae: 1.2688 - val_dominant_elbow_accuracy: 0.3992 - val_dominant_elbow_loss: 1.0783 - val_dominant_knee_accuracy: 0.5331 - val_dominant_knee_loss: 0.9868 - val_loss: 4.9009 - val_movement_score_loss: 2.8339 - val_movement_score_mae: 1.2161 - learning_rate: 0.0010
# Epoch 4/300
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - dominant_elbow_accuracy: 0.3894 - dominant_elbow_loss: 1.0888 - dominant_knee_accuracy: 0.5361 - dominant_knee_loss: 0.9892 - loss: 5.0201 - movement_score_loss: 2.9421 - movement_score_mae: 1.3006
# Epoch 4: val_loss did not improve from 4.68776
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 26s 45ms/step - dominant_elbow_accuracy: 0.3894 - dominant_elbow_loss: 1.0888 - dominant_knee_accuracy: 0.5361 - dominant_knee_loss: 0.9892 - loss: 5.0200 - movement_score_loss: 2.9421 - movement_score_mae: 1.3006 - val_dominant_elbow_accuracy: 0.3216 - val_dominant_elbow_loss: 4.4348 - val_dominant_knee_accuracy: 0.1713 - val_dominant_knee_loss: 4.1299 - val_loss: 12.0609 - val_movement_score_loss: 3.4957 - val_movement_score_mae: 1.4359 - learning_rate: 0.0010
# Epoch 5/300
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - dominant_elbow_accuracy: 0.4075 - dominant_elbow_loss: 1.0806 - dominant_knee_accuracy: 0.5354 - dominant_knee_loss: 0.9791 - loss: 4.8973 - movement_score_loss: 2.8375 - movement_score_mae: 1.2787
# Epoch 5: val_loss did not improve from 4.68776
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 25s 45ms/step - dominant_elbow_accuracy: 0.4075 - dominant_elbow_loss: 1.0806 - dominant_knee_accuracy: 0.5354 - dominant_knee_loss: 0.9791 - loss: 4.8972 - movement_score_loss: 2.8374 - movement_score_mae: 1.2787 - val_dominant_elbow_accuracy: 0.3925 - val_dominant_elbow_loss: 1.0790 - val_dominant_knee_accuracy: 0.5318 - val_dominant_knee_loss: 0.9851 - val_loss: 4.9762 - val_movement_score_loss: 2.9118 - val_movement_score_mae: 1.3343 - learning_rate: 0.0010
# Epoch 6/300
# 562/563 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - dominant_elbow_accuracy: 0.4050 - dominant_elbow_loss: 1.0771 - dominant_knee_accuracy: 0.5382 - dominant_knee_loss: 0.9770 - loss: 4.8257 - movement_score_loss: 2.7715 - movement_score_mae: 1.2589
# Epoch 6: val_loss did not improve from 4.68776
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 26s 46ms/step - dominant_elbow_accuracy: 0.4050 - dominant_elbow_loss: 1.0771 - dominant_knee_accuracy: 0.5382 - dominant_knee_loss: 0.9770 - loss: 4.8256 - movement_score_loss: 2.7715 - movement_score_mae: 1.2589 - val_dominant_elbow_accuracy: 0.3841 - val_dominant_elbow_loss: 1.2469 - val_dominant_knee_accuracy: 0.5338 - val_dominant_knee_loss: 1.0211 - val_loss: 7.4620 - val_movement_score_loss: 5.1943 - val_movement_score_mae: 1.9414 - learning_rate: 0.0010
# Epoch 7/300
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dominant_elbow_accuracy: 0.4019 - dominant_elbow_loss: 1.0759 - dominant_knee_accuracy: 0.5383 - dominant_knee_loss: 0.9699 - loss: 4.6655 - movement_score_loss: 2.6198 - movement_score_mae: 1.2242
# Epoch 7: val_loss improved from 4.68776 to 4.67035, saving model to best_mediapipe_infant_movement_model_3class.keras
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 27s 47ms/step - dominant_elbow_accuracy: 0.4019 - dominant_elbow_loss: 1.0759 - dominant_knee_accuracy: 0.5383 - dominant_knee_loss: 0.9699 - loss: 4.6656 - movement_score_loss: 2.6198 - movement_score_mae: 1.2242 - val_dominant_elbow_accuracy: 0.3865 - val_dominant_elbow_loss: 1.0701 - val_dominant_knee_accuracy: 0.5455 - val_dominant_knee_loss: 0.9694 - val_loss: 4.6704 - val_movement_score_loss: 2.6315 - val_movement_score_mae: 1.2187 - learning_rate: 5.0000e-04
# Epoch 8/300
# 562/563 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dominant_elbow_accuracy: 0.4075 - dominant_elbow_loss: 1.0651 - dominant_knee_accuracy: 0.5400 - dominant_knee_loss: 0.9703 - loss: 4.6771 - movement_score_loss: 2.6417 - movement_score_mae: 1.2320
# Epoch 8: val_loss improved from 4.67035 to 4.38360, saving model to best_mediapipe_infant_movement_model_3class.keras
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 27s 48ms/step - dominant_elbow_accuracy: 0.4075 - dominant_elbow_loss: 1.0651 - dominant_knee_accuracy: 0.5400 - dominant_knee_loss: 0.9703 - loss: 4.6768 - movement_score_loss: 2.6414 - movement_score_mae: 1.2319 - val_dominant_elbow_accuracy: 0.3929 - val_dominant_elbow_loss: 1.0632 - val_dominant_knee_accuracy: 0.5362 - val_dominant_knee_loss: 0.9570 - val_loss: 4.3836 - val_movement_score_loss: 2.3639 - val_movement_score_mae: 1.1285 - learning_rate: 5.0000e-04
# Epoch 9/300
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - dominant_elbow_accuracy: 0.4004 - dominant_elbow_loss: 1.0684 - dominant_knee_accuracy: 0.5345 - dominant_knee_loss: 0.9674 - loss: 4.4073 - movement_score_loss: 2.3714 - movement_score_mae: 1.1681
# Epoch 9: val_loss did not improve from 4.38360
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 28s 50ms/step - dominant_elbow_accuracy: 0.4005 - dominant_elbow_loss: 1.0684 - dominant_knee_accuracy: 0.5345 - dominant_knee_loss: 0.9674 - loss: 4.4074 - movement_score_loss: 2.3715 - movement_score_mae: 1.1682 - val_dominant_elbow_accuracy: 0.4385 - val_dominant_elbow_loss: 1.0518 - val_dominant_knee_accuracy: 0.5451 - val_dominant_knee_loss: 0.9464 - val_loss: 4.4120 - val_movement_score_loss: 2.4146 - val_movement_score_mae: 1.1730 - learning_rate: 5.0000e-04
# Epoch 10/300
# 562/563 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - dominant_elbow_accuracy: 0.4119 - dominant_elbow_loss: 1.0635 - dominant_knee_accuracy: 0.5453 - dominant_knee_loss: 0.9559 - loss: 4.3829 - movement_score_loss: 2.3635 - movement_score_mae: 1.1654
# Epoch 10: val_loss improved from 4.38360 to 4.21860, saving model to best_mediapipe_infant_movement_model_3class.keras
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 28s 50ms/step - dominant_elbow_accuracy: 0.4119 - dominant_elbow_loss: 1.0635 - dominant_knee_accuracy: 0.5453 - dominant_knee_loss: 0.9559 - loss: 4.3827 - movement_score_loss: 2.3633 - movement_score_mae: 1.1654 - val_dominant_elbow_accuracy: 0.4220 - val_dominant_elbow_loss: 1.0653 - val_dominant_knee_accuracy: 0.5180 - val_dominant_knee_loss: 0.9694 - val_loss: 4.2186 - val_movement_score_loss: 2.1824 - val_movement_score_mae: 1.1278 - learning_rate: 5.0000e-04
# Epoch 11/300
# 562/563 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - dominant_elbow_accuracy: 0.4227 - dominant_elbow_loss: 1.0632 - dominant_knee_accuracy: 0.5375 - dominant_knee_loss: 0.9589 - loss: 4.2373 - movement_score_loss: 2.2153 - movement_score_mae: 1.1272
# Epoch 11: val_loss improved from 4.21860 to 4.05919, saving model to best_mediapipe_infant_movement_model_3class.keras
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 29s 51ms/step - dominant_elbow_accuracy: 0.4227 - dominant_elbow_loss: 1.0632 - dominant_knee_accuracy: 0.5375 - dominant_knee_loss: 0.9589 - loss: 4.2374 - movement_score_loss: 2.2153 - movement_score_mae: 1.1273 - val_dominant_elbow_accuracy: 0.4209 - val_dominant_elbow_loss: 1.0641 - val_dominant_knee_accuracy: 0.5404 - val_dominant_knee_loss: 0.9561 - val_loss: 4.0592 - val_movement_score_loss: 2.0384 - val_movement_score_mae: 1.0554 - learning_rate: 5.0000e-04
# Epoch 12/300
# 562/563 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dominant_elbow_accuracy: 0.4144 - dominant_elbow_loss: 1.0659 - dominant_knee_accuracy: 0.5415 - dominant_knee_loss: 0.9578 - loss: 4.2778 - movement_score_loss: 2.2541 - movement_score_mae: 1.1424
# Epoch 12: val_loss improved from 4.05919 to 3.91860, saving model to best_mediapipe_infant_movement_model_3class.keras
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 27s 48ms/step - dominant_elbow_accuracy: 0.4144 - dominant_elbow_loss: 1.0659 - dominant_knee_accuracy: 0.5415 - dominant_knee_loss: 0.9578 - loss: 4.2775 - movement_score_loss: 2.2538 - movement_score_mae: 1.1423 - val_dominant_elbow_accuracy: 0.4334 - val_dominant_elbow_loss: 1.0471 - val_dominant_knee_accuracy: 0.5384 - val_dominant_knee_loss: 0.9448 - val_loss: 3.9186 - val_movement_score_loss: 1.9260 - val_movement_score_mae: 1.0432 - learning_rate: 5.0000e-04
# Epoch 13/300
# 562/563 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - dominant_elbow_accuracy: 0.4356 - dominant_elbow_loss: 1.0535 - dominant_knee_accuracy: 0.5458 - dominant_knee_loss: 0.9523 - loss: 4.0746 - movement_score_loss: 2.0688 - movement_score_mae: 1.0934
# Epoch 13: val_loss did not improve from 3.91860
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 26s 47ms/step - dominant_elbow_accuracy: 0.4356 - dominant_elbow_loss: 1.0535 - dominant_knee_accuracy: 0.5458 - dominant_knee_loss: 0.9523 - loss: 4.0746 - movement_score_loss: 2.0688 - movement_score_mae: 1.0933 - val_dominant_elbow_accuracy: 0.4149 - val_dominant_elbow_loss: 1.0593 - val_dominant_knee_accuracy: 0.5389 - val_dominant_knee_loss: 0.9421 - val_loss: 4.0300 - val_movement_score_loss: 2.0285 - val_movement_score_mae: 1.0630 - learning_rate: 5.0000e-04
# Epoch 14/300
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dominant_elbow_accuracy: 0.4202 - dominant_elbow_loss: 1.0583 - dominant_knee_accuracy: 0.5355 - dominant_knee_loss: 0.9576 - loss: 4.0643 - movement_score_loss: 2.0484 - movement_score_mae: 1.0850
# Epoch 14: val_loss did not improve from 3.91860
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 26s 47ms/step - dominant_elbow_accuracy: 0.4202 - dominant_elbow_loss: 1.0583 - dominant_knee_accuracy: 0.5355 - dominant_knee_loss: 0.9576 - loss: 4.0643 - movement_score_loss: 2.0484 - movement_score_mae: 1.0850 - val_dominant_elbow_accuracy: 0.4216 - val_dominant_elbow_loss: 1.0626 - val_dominant_knee_accuracy: 0.5429 - val_dominant_knee_loss: 0.9480 - val_loss: 4.0748 - val_movement_score_loss: 2.0641 - val_movement_score_mae: 1.0629 - learning_rate: 5.0000e-04
# Epoch 15/300
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dominant_elbow_accuracy: 0.4255 - dominant_elbow_loss: 1.0506 - dominant_knee_accuracy: 0.5479 - dominant_knee_loss: 0.9492 - loss: 4.0927 - movement_score_loss: 2.0928 - movement_score_mae: 1.0903
# Epoch 15: val_loss did not improve from 3.91860
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 26s 47ms/step - dominant_elbow_accuracy: 0.4255 - dominant_elbow_loss: 1.0506 - dominant_knee_accuracy: 0.5479 - dominant_knee_loss: 0.9492 - loss: 4.0926 - movement_score_loss: 2.0928 - movement_score_mae: 1.0903 - val_dominant_elbow_accuracy: 0.4491 - val_dominant_elbow_loss: 1.0432 - val_dominant_knee_accuracy: 0.5393 - val_dominant_knee_loss: 0.9385 - val_loss: 4.0952 - val_movement_score_loss: 2.1123 - val_movement_score_mae: 1.0576 - learning_rate: 5.0000e-04
# Epoch 16/300
# 562/563 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dominant_elbow_accuracy: 0.4313 - dominant_elbow_loss: 1.0459 - dominant_knee_accuracy: 0.5400 - dominant_knee_loss: 0.9532 - loss: 3.9739 - movement_score_loss: 1.9748 - movement_score_mae: 1.0652
# Epoch 16: val_loss did not improve from 3.91860
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 27s 48ms/step - dominant_elbow_accuracy: 0.4313 - dominant_elbow_loss: 1.0459 - dominant_knee_accuracy: 0.5400 - dominant_knee_loss: 0.9532 - loss: 3.9740 - movement_score_loss: 1.9749 - movement_score_mae: 1.0652 - val_dominant_elbow_accuracy: 0.4358 - val_dominant_elbow_loss: 1.0614 - val_dominant_knee_accuracy: 0.5498 - val_dominant_knee_loss: 0.9332 - val_loss: 4.0064 - val_movement_score_loss: 2.0113 - val_movement_score_mae: 1.0296 - learning_rate: 5.0000e-04
# Epoch 17/300
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dominant_elbow_accuracy: 0.4343 - dominant_elbow_loss: 1.0496 - dominant_knee_accuracy: 0.5483 - dominant_knee_loss: 0.9453 - loss: 3.9944 - movement_score_loss: 1.9995 - movement_score_mae: 1.0714
# Epoch 17: val_loss did not improve from 3.91860
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 27s 47ms/step - dominant_elbow_accuracy: 0.4343 - dominant_elbow_loss: 1.0496 - dominant_knee_accuracy: 0.5482 - dominant_knee_loss: 0.9453 - loss: 3.9944 - movement_score_loss: 1.9995 - movement_score_mae: 1.0714 - val_dominant_elbow_accuracy: 0.4258 - val_dominant_elbow_loss: 1.0457 - val_dominant_knee_accuracy: 0.5449 - val_dominant_knee_loss: 0.9382 - val_loss: 3.9282 - val_movement_score_loss: 1.9442 - val_movement_score_mae: 1.0399 - learning_rate: 5.0000e-04
# Epoch 18/300
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - dominant_elbow_accuracy: 0.4374 - dominant_elbow_loss: 1.0385 - dominant_knee_accuracy: 0.5440 - dominant_knee_loss: 0.9469 - loss: 3.8595 - movement_score_loss: 1.8740 - movement_score_mae: 1.0367
# Epoch 18: val_loss improved from 3.91860 to 3.74548, saving model to best_mediapipe_infant_movement_model_3class.keras
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 27s 48ms/step - dominant_elbow_accuracy: 0.4374 - dominant_elbow_loss: 1.0385 - dominant_knee_accuracy: 0.5440 - dominant_knee_loss: 0.9469 - loss: 3.8594 - movement_score_loss: 1.8740 - movement_score_mae: 1.0367 - val_dominant_elbow_accuracy: 0.4462 - val_dominant_elbow_loss: 1.0374 - val_dominant_knee_accuracy: 0.5469 - val_dominant_knee_loss: 0.9319 - val_loss: 3.7455 - val_movement_score_loss: 1.7754 - val_movement_score_mae: 0.9903 - learning_rate: 2.5000e-04
# Epoch 19/300
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dominant_elbow_accuracy: 0.4408 - dominant_elbow_loss: 1.0363 - dominant_knee_accuracy: 0.5516 - dominant_knee_loss: 0.9383 - loss: 3.7831 - movement_score_loss: 1.8085 - movement_score_mae: 1.0172
# Epoch 19: val_loss improved from 3.74548 to 3.70830, saving model to best_mediapipe_infant_movement_model_3class.keras
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 27s 47ms/step - dominant_elbow_accuracy: 0.4408 - dominant_elbow_loss: 1.0363 - dominant_knee_accuracy: 0.5516 - dominant_knee_loss: 0.9383 - loss: 3.7832 - movement_score_loss: 1.8085 - movement_score_mae: 1.0172 - val_dominant_elbow_accuracy: 0.4380 - val_dominant_elbow_loss: 1.0303 - val_dominant_knee_accuracy: 0.5511 - val_dominant_knee_loss: 0.9331 - val_loss: 3.7083 - val_movement_score_loss: 1.7443 - val_movement_score_mae: 0.9768 - learning_rate: 2.5000e-04
# Epoch 20/300
# 562/563 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dominant_elbow_accuracy: 0.4481 - dominant_elbow_loss: 1.0398 - dominant_knee_accuracy: 0.5477 - dominant_knee_loss: 0.9421 - loss: 3.8219 - movement_score_loss: 1.8400 - movement_score_mae: 1.0177
# Epoch 20: val_loss did not improve from 3.70830
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 27s 47ms/step - dominant_elbow_accuracy: 0.4481 - dominant_elbow_loss: 1.0398 - dominant_knee_accuracy: 0.5477 - dominant_knee_loss: 0.9421 - loss: 3.8218 - movement_score_loss: 1.8400 - movement_score_mae: 1.0177 - val_dominant_elbow_accuracy: 0.4485 - val_dominant_elbow_loss: 1.0492 - val_dominant_knee_accuracy: 0.5518 - val_dominant_knee_loss: 0.9279 - val_loss: 3.8041 - val_movement_score_loss: 1.8273 - val_movement_score_mae: 0.9803 - learning_rate: 2.5000e-04
# Epoch 21/300
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dominant_elbow_accuracy: 0.4347 - dominant_elbow_loss: 1.0409 - dominant_knee_accuracy: 0.5552 - dominant_knee_loss: 0.9364 - loss: 3.7848 - movement_score_loss: 1.8075 - movement_score_mae: 1.0103
# Epoch 21: val_loss did not improve from 3.70830
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 27s 48ms/step - dominant_elbow_accuracy: 0.4347 - dominant_elbow_loss: 1.0409 - dominant_knee_accuracy: 0.5552 - dominant_knee_loss: 0.9364 - loss: 3.7848 - movement_score_loss: 1.8075 - movement_score_mae: 1.0104 - val_dominant_elbow_accuracy: 0.4498 - val_dominant_elbow_loss: 1.0318 - val_dominant_knee_accuracy: 0.5564 - val_dominant_knee_loss: 0.9345 - val_loss: 3.7292 - val_movement_score_loss: 1.7625 - val_movement_score_mae: 0.9675 - learning_rate: 2.5000e-04
# Epoch 22/300
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - dominant_elbow_accuracy: 0.4410 - dominant_elbow_loss: 1.0373 - dominant_knee_accuracy: 0.5489 - dominant_knee_loss: 0.9390 - loss: 3.7856 - movement_score_loss: 1.8093 - movement_score_mae: 1.0134
# Epoch 22: val_loss did not improve from 3.70830
# 563/563 ━━━━━━━━━━━━━━━━━━━━
300
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dominant_elbow_accuracy: 0.4561 - dominant_elbow_loss: 1.0278 - dominant_knee_accuracy: 0.5570 - dominant_knee_loss: 0.9294 - loss: 3.5888 - movement_score_loss: 1.6316 - movement_score_mae: 0.9611
# Epoch 26: val_loss did not improve from 3.63882
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 18s 33ms/step - dominant_elbow_accuracy: 0.4561 - dominant_elbow_loss: 1.0278 - dominant_knee_accuracy: 0.5570 - dominant_knee_loss: 0.9294 - loss: 3.5889 - movement_score_loss: 1.6317 - movement_score_mae: 0.9611 - val_dominant_elbow_accuracy: 0.4487 - val_dominant_elbow_loss: 1.0328 - val_dominant_knee_accuracy: 0.5671 - val_dominant_knee_loss: 0.9267 - val_loss: 3.7329 - val_movement_score_loss: 1.7734 - val_movement_score_mae: 0.9661 - learning_rate: 1.2500e-04
# Epoch 27/300
# 561/563 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - dominant_elbow_accuracy: 0.4708 - dominant_elbow_loss: 1.0249 - dominant_knee_accuracy: 0.5599 - dominant_knee_loss: 0.9253 - loss: 3.6351 - movement_score_loss: 1.6850 - movement_score_mae: 0.9776
# Epoch 27: val_loss did not improve from 3.63882
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 14s 24ms/step - dominant_elbow_accuracy: 0.4708 - dominant_elbow_loss: 1.0249 - dominant_knee_accuracy: 0.5599 - dominant_knee_loss: 0.9253 - loss: 3.6349 - movement_score_loss: 1.6848 - movement_score_mae: 0.9775 - val_dominant_elbow_accuracy: 0.4571 - val_dominant_elbow_loss: 1.0316 - val_dominant_knee_accuracy: 0.5677 - val_dominant_knee_loss: 0.9232 - val_loss: 3.6413 - val_movement_score_loss: 1.6864 - val_movement_score_mae: 0.9471 - learning_rate: 1.2500e-04
# Epoch 28/300
# 561/563 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - dominant_elbow_accuracy: 0.4624 - dominant_elbow_loss: 1.0219 - dominant_knee_accuracy: 0.5556 - dominant_knee_loss: 0.9295 - loss: 3.5718 - movement_score_loss: 1.6204 - movement_score_mae: 0.9538
# Epoch 28: val_loss improved from 3.63882 to 3.58230, saving model to best_mediapipe_infant_movement_model_3class.keras
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 14s 25ms/step - dominant_elbow_accuracy: 0.4624 - dominant_elbow_loss: 1.0219 - dominant_knee_accuracy: 0.5556 - dominant_knee_loss: 0.9295 - loss: 3.5720 - movement_score_loss: 1.6206 - movement_score_mae: 0.9539 - val_dominant_elbow_accuracy: 0.4638 - val_dominant_elbow_loss: 1.0238 - val_dominant_knee_accuracy: 0.5666 - val_dominant_knee_loss: 0.9062 - val_loss: 3.5823 - val_movement_score_loss: 1.6524 - val_movement_score_mae: 0.9512 - learning_rate: 1.2500e-04
# Epoch 29/300
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - dominant_elbow_accuracy: 0.4644 - dominant_elbow_loss: 1.0239 - dominant_knee_accuracy: 0.5565 - dominant_knee_loss: 0.9281 - loss: 3.5392 - movement_score_loss: 1.5872 - movement_score_mae: 0.9471
# Epoch 29: val_loss did not improve from 3.58230
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 14s 25ms/step - dominant_elbow_accuracy: 0.4644 - dominant_elbow_loss: 1.0239 - dominant_knee_accuracy: 0.5565 - dominant_knee_loss: 0.9281 - loss: 3.5392 - movement_score_loss: 1.5872 - movement_score_mae: 0.9472 - val_dominant_elbow_accuracy: 0.4551 - val_dominant_elbow_loss: 1.0280 - val_dominant_knee_accuracy: 0.5715 - val_dominant_knee_loss: 0.9091 - val_loss: 3.6353 - val_movement_score_loss: 1.6981 - val_movement_score_mae: 0.9585 - learning_rate: 1.2500e-04
# Epoch 30/300
# 562/563 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - dominant_elbow_accuracy: 0.4621 - dominant_elbow_loss: 1.0268 - dominant_knee_accuracy: 0.5542 - dominant_knee_loss: 0.9236 - loss: 3.5785 - movement_score_loss: 1.6281 - movement_score_mae: 0.9575
# Epoch 30: val_loss did not improve from 3.58230
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 14s 26ms/step - dominant_elbow_accuracy: 0.4621 - dominant_elbow_loss: 1.0268 - dominant_knee_accuracy: 0.5542 - dominant_knee_loss: 0.9236 - loss: 3.5784 - movement_score_loss: 1.6280 - movement_score_mae: 0.9575 - val_dominant_elbow_accuracy: 0.4629 - val_dominant_elbow_loss: 1.0223 - val_dominant_knee_accuracy: 0.5682 - val_dominant_knee_loss: 0.9414 - val_loss: 3.6422 - val_movement_score_loss: 1.6783 - val_movement_score_mae: 0.9472 - learning_rate: 1.2500e-04
# Epoch 31/300
# 562/563 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - dominant_elbow_accuracy: 0.4566 - dominant_elbow_loss: 1.0251 - dominant_knee_accuracy: 0.5657 - dominant_knee_loss: 0.9234 - loss: 3.5456 - movement_score_loss: 1.5971 - movement_score_mae: 0.9468
# Epoch 31: val_loss improved from 3.58230 to 3.54567, saving model to best_mediapipe_infant_movement_model_3class.keras
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 14s 26ms/step - dominant_elbow_accuracy: 0.4566 - dominant_elbow_loss: 1.0251 - dominant_knee_accuracy: 0.5657 - dominant_knee_loss: 0.9234 - loss: 3.5456 - movement_score_loss: 1.5971 - movement_score_mae: 0.9468 - val_dominant_elbow_accuracy: 0.4549 - val_dominant_elbow_loss: 1.0215 - val_dominant_knee_accuracy: 0.5657 - val_dominant_knee_loss: 0.9138 - val_loss: 3.5457 - val_movement_score_loss: 1.6101 - val_movement_score_mae: 0.9326 - learning_rate: 1.2500e-04
# Epoch 32/300
# 561/563 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - dominant_elbow_accuracy: 0.4590 - dominant_elbow_loss: 1.0224 - dominant_knee_accuracy: 0.5528 - dominant_knee_loss: 0.9305 - loss: 3.5359 - movement_score_loss: 1.5829 - movement_score_mae: 0.9440
# Epoch 32: val_loss did not improve from 3.54567
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 14s 26ms/step - dominant_elbow_accuracy: 0.4590 - dominant_elbow_loss: 1.0224 - dominant_knee_accuracy: 0.5528 - dominant_knee_loss: 0.9305 - loss: 3.5360 - movement_score_loss: 1.5831 - movement_score_mae: 0.9440 - val_dominant_elbow_accuracy: 0.4598 - val_dominant_elbow_loss: 1.0344 - val_dominant_knee_accuracy: 0.5613 - val_dominant_knee_loss: 0.9298 - val_loss: 3.6994 - val_movement_score_loss: 1.7360 - val_movement_score_mae: 0.9563 - learning_rate: 1.2500e-04
# Epoch 33/300
# 562/563 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step -
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - dominant_elbow_accuracy: 0.4672 - dominant_elbow_loss: 1.0138 - dominant_knee_accuracy: 0.5682 - dominant_knee_loss: 0.9125 - loss: 3.4657 - movement_score_loss: 1.5394 - movement_score_mae: 0.9235 - val_dominant_elbow_accuracy: 0.4534 - val_dominant_elbow_loss: 1.0229 - val_dominant_knee_accuracy: 0.5615 - val_dominant_knee_loss: 0.9137 - val_loss: 3.5912 - val_movement_score_loss: 1.6539 - val_movement_score_mae: 0.9335 - learning_rate: 6.2500e-05
# Epoch 41/300
# 561/563 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - dominant_elbow_accuracy: 0.4708 - dominant_elbow_loss: 1.0098 - dominant_knee_accuracy: 0.5658 - dominant_knee_loss: 0.9112 - loss: 3.4446 - movement_score_loss: 1.5235 - movement_score_mae: 0.9202
# Epoch 41: val_loss did not improve from 3.54567
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - dominant_elbow_accuracy: 0.4708 - dominant_elbow_loss: 1.0099 - dominant_knee_accuracy: 0.5658 - dominant_knee_loss: 0.9112 - loss: 3.4446 - movement_score_loss: 1.5235 - movement_score_mae: 0.9202 - val_dominant_elbow_accuracy: 0.4558 - val_dominant_elbow_loss: 1.0193 - val_dominant_knee_accuracy: 0.5598 - val_dominant_knee_loss: 0.9078 - val_loss: 3.6152 - val_movement_score_loss: 1.6878 - val_movement_score_mae: 0.9468 - learning_rate: 6.2500e-05
# Epoch 42/300
# 562/563 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - dominant_elbow_accuracy: 0.4749 - dominant_elbow_loss: 1.0103 - dominant_knee_accuracy: 0.5687 - dominant_knee_loss: 0.9081 - loss: 3.4546 - movement_score_loss: 1.5362 - movement_score_mae: 0.9275
# Epoch 42: val_loss did not improve from 3.54567
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - dominant_elbow_accuracy: 0.4749 - dominant_elbow_loss: 1.0103 - dominant_knee_accuracy: 0.5687 - dominant_knee_loss: 0.9081 - loss: 3.4546 - movement_score_loss: 1.5362 - movement_score_mae: 0.9275 - val_dominant_elbow_accuracy: 0.4576 - val_dominant_elbow_loss: 1.0158 - val_dominant_knee_accuracy: 0.5669 - val_dominant_knee_loss: 0.9037 - val_loss: 3.5641 - val_movement_score_loss: 1.6441 - val_movement_score_mae: 0.9306 - learning_rate: 3.1250e-05
# Epoch 43/300
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dominant_elbow_accuracy: 0.4767 - dominant_elbow_loss: 1.0104 - dominant_knee_accuracy: 0.5638 - dominant_knee_loss: 0.9153 - loss: 3.4431 - movement_score_loss: 1.5174 - movement_score_mae: 0.9202
# Epoch 43: val_loss did not improve from 3.54567
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 17s 29ms/step - dominant_elbow_accuracy: 0.4766 - dominant_elbow_loss: 1.0104 - dominant_knee_accuracy: 0.5638 - dominant_knee_loss: 0.9153 - loss: 3.4431 - movement_score_loss: 1.5174 - movement_score_mae: 0.9202 - val_dominant_elbow_accuracy: 0.4594 - val_dominant_elbow_loss: 1.0164 - val_dominant_knee_accuracy: 0.5709 - val_dominant_knee_loss: 0.9056 - val_loss: 3.5862 - val_movement_score_loss: 1.6634 - val_movement_score_mae: 0.9354 - learning_rate: 3.1250e-05
# Epoch 44/300
# 562/563 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - dominant_elbow_accuracy: 0.4701 - dominant_elbow_loss: 1.0097 - dominant_knee_accuracy: 0.5657 - dominant_knee_loss: 0.9109 - loss: 3.4504 - movement_score_loss: 1.5299 - movement_score_mae: 0.9220
# Epoch 44: val_loss did not improve from 3.54567
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - dominant_elbow_accuracy: 0.4701 - dominant_elbow_loss: 1.0097 - dominant_knee_accuracy: 0.5657 - dominant_knee_loss: 0.9109 - loss: 3.4503 - movement_score_loss: 1.5298 - movement_score_mae: 0.9219 - val_dominant_elbow_accuracy: 0.4576 - val_dominant_elbow_loss: 1.0162 - val_dominant_knee_accuracy: 0.5717 - val_dominant_knee_loss: 0.9014 - val_loss: 3.5632 - val_movement_score_loss: 1.6449 - val_movement_score_mae: 0.9301 - learning_rate: 3.1250e-05
# Epoch 45/300
# 562/563 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dominant_elbow_accuracy: 0.4640 - dominant_elbow_loss: 1.0158 - dominant_knee_accuracy: 0.5640 - dominant_knee_loss: 0.9091 - loss: 3.4153 - movement_score_loss: 1.4904 - movement_score_mae: 0.9140
# Epoch 45: val_loss did not improve from 3.54567
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 17s 30ms/step - dominant_elbow_accuracy: 0.4640 - dominant_elbow_loss: 1.0158 - dominant_knee_accuracy: 0.5640 - dominant_knee_loss: 0.9091 - loss: 3.4154 - movement_score_loss: 1.4905 - movement_score_mae: 0.9140 - val_dominant_elbow_accuracy: 0.4594 - val_dominant_elbow_loss: 1.0162 - val_dominant_knee_accuracy: 0.5729 - val_dominant_knee_loss: 0.9065 - val_loss: 3.5632 - val_movement_score_loss: 1.6403 - val_movement_score_mae: 0.9297 - learning_rate: 3.1250e-05
# Epoch 46/300
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - dominant_elbow_accuracy: 0.4677 - dominant_elbow_loss: 1.0142 - dominant_knee_accuracy: 0.5675 - dominant_knee_loss: 0.9106 - loss: 3.4314 - movement_score_loss: 1.5066 - movement_score_mae: 0.9212
# Epoch 46: val_loss did not improve from 3.54567
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 16s 29ms/step - dominant_elbow_accuracy: 0.4677 - dominant_elbow_loss: 1.0142 - dominant_knee_accuracy: 0.5675 - dominant_knee_loss: 0.9106 - loss: 3.4314 - movement_score_loss: 1.5066 - movement_score_mae: 0.9211 - val_dominant_elbow_accuracy: 0.4587 - val_dominant_elbow_loss: 1.0151 - val_dominant_knee_accuracy: 0.5735 - val_dominant_knee_loss: 0.9062 - val_loss: 3.5761 - val_movement_score_loss: 1.6540 - val_movement_score_mae: 0.9345 - learning_rate: 3.1250e-05
# Epoch 47/300
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - dominant_elbow_accuracy: 0.4638 - dominant_elbow_loss: 1.0192 - dominant_knee_accuracy: 0.5674 - dominant_knee_loss: 0.9141 - loss: 3.4048 - movement_score_loss: 1.4715 - movement_score_mae: 0.9098
# Epoch 47: val_loss improved from 3.54567 to 3.52803, saving model to best_mediapipe_infant_movement_model_3class.keras
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 17s 31ms/step - dominant_elbow_accuracy: 0.4638 - dominant_elbow_loss: 1.0192 - dominant_knee_accuracy: 0.5674 - dominant_knee_loss: 0.9141 - loss: 3.4048 - movement_score_loss: 1.4716 - movement_score_mae: 0.9098 - val_dominant_elbow_accuracy: 0.4602 - val_dominant_elbow_loss: 1.0136 - val_dominant_knee_accuracy: 0.5726 - val_dominant_knee_loss: 0.8992 - val_loss: 3.5280 - val_movement_score_loss: 1.6143 - val_movement_score_mae: 0.9236 - learning_rate: 1.5625e-05
# Epoch 48/300
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step -
val_loss did not improve from 3.52803
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - dominant_elbow_accuracy: 0.4675 - dominant_elbow_loss: 1.0146 - dominant_knee_accuracy: 0.5647 - dominant_knee_loss: 0.9114 - loss: 3.3401 - movement_score_loss: 1.4142 - movement_score_mae: 0.8893 - val_dominant_elbow_accuracy: 0.4673 - val_dominant_elbow_loss: 1.0112 - val_dominant_knee_accuracy: 0.5697 - val_dominant_knee_loss: 0.9130 - val_loss: 3.5811 - val_movement_score_loss: 1.6555 - val_movement_score_mae: 0.9259 - learning_rate: 1.0000e-05
# Epoch 96/300
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - dominant_elbow_accuracy: 0.4743 - dominant_elbow_loss: 1.0054 - dominant_knee_accuracy: 0.5724 - dominant_knee_loss: 0.9019 - loss: 3.3570 - movement_score_loss: 1.4496 - movement_score_mae: 0.9013
# Epoch 96: val_loss did not improve from 3.52803
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 18s 31ms/step - dominant_elbow_accuracy: 0.4743 - dominant_elbow_loss: 1.0054 - dominant_knee_accuracy: 0.5724 - dominant_knee_loss: 0.9019 - loss: 3.3570 - movement_score_loss: 1.4496 - movement_score_mae: 0.9013 - val_dominant_elbow_accuracy: 0.4700 - val_dominant_elbow_loss: 1.0111 - val_dominant_knee_accuracy: 0.5684 - val_dominant_knee_loss: 0.9104 - val_loss: 3.5656 - val_movement_score_loss: 1.6427 - val_movement_score_mae: 0.9224 - learning_rate: 1.0000e-05
# Epoch 97/300
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - dominant_elbow_accuracy: 0.4774 - dominant_elbow_loss: 1.0049 - dominant_knee_accuracy: 0.5696 - dominant_knee_loss: 0.9079 - loss: 3.3050 - movement_score_loss: 1.3922 - movement_score_mae: 0.8852
# Epoch 97: val_loss did not improve from 3.52803
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 19s 33ms/step - dominant_elbow_accuracy: 0.4774 - dominant_elbow_loss: 1.0049 - dominant_knee_accuracy: 0.5696 - dominant_knee_loss: 0.9079 - loss: 3.3051 - movement_score_loss: 1.3922 - movement_score_mae: 0.8852 - val_dominant_elbow_accuracy: 0.4665 - val_dominant_elbow_loss: 1.0101 - val_dominant_knee_accuracy: 0.5693 - val_dominant_knee_loss: 0.9027 - val_loss: 3.5577 - val_movement_score_loss: 1.6435 - val_movement_score_mae: 0.9245 - learning_rate: 1.0000e-05
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step
#
# ===== תוצאות המודל =====
# RMSE for motion score: 1.2540
# דיוק סיווג ברך דומיננטית: 0.5774
# דיוק סיווג מרפק דומיננטי: 0.4779
#
# דוח סיווג - ברך דומיננטית:
#               precision    recall  f1-score   support
#
#          0.0       0.58      0.92      0.71      3005
#          1.0       0.61      0.06      0.12       911
#          2.0       0.55      0.24      0.34      1711
#
#     accuracy                           0.58      5627
#    macro avg       0.58      0.41      0.39      5627
# weighted avg       0.58      0.58      0.50      5627
#
#
# דוח סיווג - מרפק דומיננטי:
#               precision    recall  f1-score   support
#
#          0.0       0.46      0.62      0.53      1972
#          1.0       0.47      0.52      0.49      1884
#          2.0       0.54      0.28      0.37      1771
#
#     accuracy                           0.48      5627
#    macro avg       0.49      0.47      0.46      5627
# weighted avg       0.49      0.48      0.47      5627
# המודל נשמר בהצלחה כקובץ 'infant_mediapipe_movement_gru_model_3class.keras'
#
# האימון הסתיים בהצלחה!
