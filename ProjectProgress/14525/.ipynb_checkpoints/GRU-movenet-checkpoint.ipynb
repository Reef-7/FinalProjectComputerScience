# %%
'''
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import GRU, Dense, Input, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import mean_squared_error, accuracy_score, classification_report
import os
import glob

# הגדרת פרמטרים
WINDOW_SIZE = 30  # מספר הפריימים ברצף (ניתן לשינוי בהתאם לצרכים)
RANDOM_STATE = 42
BATCH_SIZE = 32
EPOCHS = 100
LEARNING_RATE = 0.001

def load_and_preprocess_data(file_paths, window_size=WINDOW_SIZE):
    """
    טעינה ועיבוד מקדים של הנתונים מקבצי האקסל
    """
    all_data = []
    test_data = []

    for file_path in file_paths:
        df = pd.read_csv(file_path) if file_path.endswith('.csv') else pd.read_excel(file_path)
        
        # בדיקה שקיימים העמודות הנדרשות
        required_columns = ['video_id', 'frame', 'window_id', 
                           'overall_movement_score', 'dominant_knee', 'dominant_elbow']
        
        if not all(col in df.columns for col in required_columns):
            print(f"The file {file_path} is missing required columns. Skipping...")
            continue
        test_subset = df[df['video_id'].isin([43, 44])]
        if not test_subset.empty:
            test_data.append(test_subset)
        df = df[~df['video_id'].isin([43, 44])]
        all_data.append(df)
    
    if not all_data:
        raise ValueError("No valid files found for processing")
        
    # איחוד כל הנתונים
    data = pd.concat(all_data, ignore_index=True)
    
    # המרת ערכים קטגוריאליים למספרים
    label_encoders = {}
    for col in ['dominant_knee', 'dominant_elbow']:
        if data[col].dtype == 'object':
            le = LabelEncoder()
            data[col] = le.fit_transform(data[col])
            label_encoders[col] = le
    
    return data, label_encoders, test_data


def prepare_sequences(data, window_size=WINDOW_SIZE):
    """
    הכנת רצפי נתונים עבור GRU לפי חלונות
    """
    feature_columns = [col for col in data.columns if any(x in col for x in ['_x', '_y', '_confidence'])
                        and not any(skip in col.lower() for skip in ['velocity', 'angle'])]
    
    X = []
    y_movement = []
    y_knee = []
    y_elbow = []
    
    # קיבוץ לפי וידאו וחלון
    groups = data.groupby(['video_id', 'window_id'])
    
    for (vid_id, win_id), group in groups:
        if len(group) < window_size:
            # דילוג על חלונות קטנים מדי
            continue
        
        # לכל חלון, ניקח רצפים באורך window_size
        for i in range(0, len(group) - window_size + 1):
            sequence = group.iloc[i:i+window_size][feature_columns].values
            
            # המטרות הן הערכים בפריים האחרון ברצף
            target_frame = group.iloc[i+window_size-1]
            
            X.append(sequence)
            y_movement.append(target_frame['overall_movement_score'])
            y_knee.append(target_frame['dominant_knee'])
            y_elbow.append(target_frame['dominant_elbow'])
    
    X = np.array(X)
    y_movement = np.array(y_movement)
    y_knee = np.array(y_knee)
    y_elbow = np.array(y_elbow)
    
    return X, y_movement, y_knee, y_elbow, feature_columns

def build_gru_model(input_shape, num_knee_classes, num_elbow_classes):
    """
    בניית מודל GRU עם מספר שכבות והתאמה למשימות מרובות
    """
    # שכבת הקלט המשותפת
    inputs = Input(shape=input_shape)
    
    # שכבות GRU משותפות
    x = GRU(128, return_sequences=True)(inputs)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)
    
    x = GRU(64)(x)
    x = BatchNormalization()(x)
    shared_features = Dropout(0.3)(x)
    
    # ענף לציון תנועה כללי (רגרסיה)
    movement_output = Dense(32, activation='relu')(shared_features)
    movement_output = Dense(1, name='movement_score')(movement_output)
    
    # ענף לברך דומיננטית (סיווג)
    knee_output = Dense(32, activation='relu')(shared_features)
    knee_output = Dense(num_knee_classes, activation='softmax', name='dominant_knee')(knee_output)
    
    # ענף למרפק דומיננטי (סיווג)
    elbow_output = Dense(32, activation='relu')(shared_features)
    elbow_output = Dense(num_elbow_classes, activation='softmax', name='dominant_elbow')(elbow_output)
    
    # הגדרת המודל עם קלט ושלושה פלטים
    model = Model(inputs=inputs, outputs=[movement_output, knee_output, elbow_output])
    
    # הגדרת אופטימייזר ופונקציות שגיאה
    model.compile(
        optimizer=Adam(learning_rate=LEARNING_RATE),
        loss={
            'movement_score': 'mean_squared_error',
            'dominant_knee': 'sparse_categorical_crossentropy',
            'dominant_elbow': 'sparse_categorical_crossentropy'
        },
        metrics={
            'movement_score': ['mae'],
            'dominant_knee': ['accuracy'],
            'dominant_elbow': ['accuracy']
        }
    )
    
    return model

def train_model(X_train, y_train, X_val, y_val, input_shape, num_knee_classes, num_elbow_classes):
    """
    אימון המודל עם מנגנוני עצירה מוקדמת ושיפור ביצועים
    """
    model = build_gru_model(input_shape, num_knee_classes, num_elbow_classes)
    
    # הגדרת callbacks
    early_stopping = EarlyStopping(
        monitor='val_loss', 
        patience=15, 
        restore_best_weights=True
    )
    
    reduce_lr = ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        min_lr=0.00001
    )

    '''
        קובץ בו נשמר המודל שמתקבלת בו התוצאה הטובה ביותר על סט הוולידציה
    '''
    model_checkpoint = ModelCheckpoint(
        'best_movenet_infant_movement_model.keras', 
        monitor='val_loss',
        save_best_only=True,
        verbose=1
    )
    
    # אימון המודל
    history = model.fit(
        X_train,
        y_train,
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=(X_val, y_val),
        callbacks=[early_stopping, reduce_lr, model_checkpoint],
        verbose=1
    )
    
    return model, history

def evaluate_model(model, X_test, y_test_movement, y_test_knee, y_test_elbow, label_encoders):
    """
    הערכת המודל והצגת מדדי ביצוע
    """
    # ביצוע חיזוי
    y_pred_movement, y_pred_knee_prob, y_pred_elbow_prob = model.predict(X_test)
    
    # המרת הסתברויות לתוויות
    y_pred_knee = np.argmax(y_pred_knee_prob, axis=1)
    y_pred_elbow = np.argmax(y_pred_elbow_prob, axis=1)
    
    # מדדי ביצוע לציון תנועה כללי
    mse_movement = mean_squared_error(y_test_movement, y_pred_movement)
    '''
    ציון בין 0-10 שמודד עד כמה המודל שגה בחישוב ציון התנועה הכללי- כמה רחוק המודל היהי מהציון תנועה הכללי האמיתי שחושב
    '''
    rmse_movement = np.sqrt(mse_movement) 
    
    # מדדי ביצוע לסיווג ברך ומרפק דומיננטיים
    knee_accuracy = accuracy_score(y_test_knee, y_pred_knee)
    elbow_accuracy = accuracy_score(y_test_elbow, y_pred_elbow)
    
    print("\n===== תוצאות המודל =====")
    print(f"RMSE for motion score: {rmse_movement:.4f}")
    print(f"דיוק סיווג ברך דומיננטית: {knee_accuracy:.4f}")
    print(f"דיוק סיווג מרפק דומיננטי: {elbow_accuracy:.4f}")
    
    print("\nדוח סיווג - ברך דומיננטית:")
    print(classification_report(y_test_knee, y_pred_knee))
    
    print("\nדוח סיווג - מרפק דומיננטי:")
    print(classification_report(y_test_elbow, y_pred_elbow))
    
    # פענוח התוויות חזרה לערכים המקוריים (אם נדרש)
    if 'dominant_knee' in label_encoders:
        original_knee_labels = label_encoders['dominant_knee'].inverse_transform(range(len(label_encoders['dominant_knee'].classes_)))
        print("\nמיפוי תוויות ברך:")
        for i, label in enumerate(original_knee_labels):
            print(f"{i}: {label}")
    
    if 'dominant_elbow' in label_encoders:
        original_elbow_labels = label_encoders['dominant_elbow'].inverse_transform(range(len(label_encoders['dominant_elbow'].classes_)))
        print("\nמיפוי תוויות מרפק:")
        for i, label in enumerate(original_elbow_labels):
            print(f"{i}: {label}")
    
    return {
        'rmse_movement': rmse_movement,
        'knee_accuracy': knee_accuracy,
        'elbow_accuracy': elbow_accuracy
    }

def plot_training_history(history):
    """
    יצירת גרפים להצגת התקדמות האימון
    """
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))
    
    # עקומות שגיאה
    axes[0, 0].plot(history.history['loss'], label='Train Loss')
    axes[0, 0].plot(history.history['val_loss'], label='Validation Loss')
    axes[0, 0].set_title('Total Loss')
    axes[0, 0].set_xlabel('Epochs')
    axes[0, 0].set_ylabel('Loss')
    axes[0, 0].legend()
    
    # דיוק ברך דומיננטית
    axes[0, 1].plot(history.history['dominant_knee_accuracy'], label='Train Accuracy')
    axes[0, 1].plot(history.history['val_dominant_knee_accuracy'], label='Validation Accuracy')
    axes[0, 1].set_title('Dominant Knee Accuracy')
    axes[0, 1].set_xlabel('Epochs')
    axes[0, 1].set_ylabel('Accuracy')
    axes[0, 1].legend()
    
    # דיוק מרפק דומיננטי
    axes[1, 0].plot(history.history['dominant_elbow_accuracy'], label='Train Accuracy')
    axes[1, 0].plot(history.history['val_dominant_elbow_accuracy'], label='Validation Accuracy')
    axes[1, 0].set_title('Dominant Elbow Accuracy')
    axes[1, 0].set_xlabel('Epochs')
    axes[1, 0].set_ylabel('Accuracy')
    axes[1, 0].legend()
    
    # שגיאה ממוצעת מוחלטת לציון תנועה
    axes[1, 1].plot(history.history['movement_score_mae'], label='Train MAE')
    axes[1, 1].plot(history.history['val_movement_score_mae'], label='Validation MAE')
    axes[1, 1].set_title('Movement Score MAE')
    axes[1, 1].set_xlabel('Epochs')
    axes[1, 1].set_ylabel('MAE')
    axes[1, 1].legend()
    
    plt.tight_layout()
    plt.savefig('training_history.png')
    plt.show()

def main():
    # הגדרה ידנית של קובץ הנתונים
    file_paths = ['movenet_dataset.csv']
    
    if not os.path.exists('movenet_dataset.csv'):
        print("שגיאה: הקובץ 'movenet_dataset.csv' לא נמצא בתיקייה הנוכחית")
        return
    
    print(f"מתחיל עיבוד של הקובץ: {file_paths[0]}")
    
    # טעינת הנתונים
    try:
        data, label_encoders, test_data = load_and_preprocess_data(file_paths)
        print(f"נטענו {len(data)} שורות נתונים")
    except Exception as e:
        print(f"שגיאה בטעינת הנתונים: {e}")
        return

    if test_data:  # בדיקה שיש נתונים
        test_df = pd.concat(test_data, ignore_index=True)
        test_df.to_csv('test_movenet_dataset.csv', index=False)
        print("קובץ test_movenet_dataset.csv נשמר בהצלחה.")
    else:
        print("לא נמצאו נתוני test_data לשמירה.")
    
    # הכנת רצפי הנתונים
    X, y_movement, y_knee, y_elbow, feature_columns = prepare_sequences(data)
    
    print(f"מספר דוגמאות: {len(X)}")
    print(f"מספר מאפיינים: {X.shape[2]}")
    
    # ספירת מספר הקלאסים הייחודיים
    num_knee_classes = len(np.unique(y_knee))
    num_elbow_classes = len(np.unique(y_elbow))
    
    print(f"מספר קלאסים לברך דומיננטית: {num_knee_classes}")
    print(f"מספר קלאסים למרפק דומיננטי: {num_elbow_classes}")
    
    # חלוקת הנתונים לאימון ובדיקה
    X_train_val, X_test, y_movement_train_val, y_movement_test, \
    y_knee_train_val, y_knee_test, y_elbow_train_val, y_elbow_test = train_test_split(
        X, y_movement, y_knee, y_elbow, test_size=0.2, random_state=RANDOM_STATE
    )
    
    # חלוקה נוספת לאימון ותיקוף
    X_train, X_val, y_movement_train, y_movement_val, \
    y_knee_train, y_knee_val, y_elbow_train, y_elbow_val = train_test_split(
        X_train_val, y_movement_train_val, y_knee_train_val, y_elbow_train_val, 
        test_size=0.2, random_state=RANDOM_STATE
    )
    
    # נירמול הנתונים
    # אין צורך לנרמל את המאפיינים מאחר וכל דגימה היא רצף, 
    # ובמקום זאת נשתמש ב-BatchNormalization בתוך המודל
    
    # הגדרת צורת הקלט למודל
    input_shape = (X_train.shape[1], X_train.shape[2])
    
    # הגדרת הפלטים באופן מתאים לפורמט הנדרש עבור מודל עם פלט מרובה
    y_train = [y_movement_train, y_knee_train, y_elbow_train]
    y_val = [y_movement_val, y_knee_val, y_elbow_val]
    
    # אימון המודל
    model, history = train_model(
        X_train, y_train, X_val, y_val, 
        input_shape, num_knee_classes, num_elbow_classes
    )
    
    # הערכת המודל
    results = evaluate_model(
        model, X_test, y_movement_test, y_knee_test, y_elbow_test, label_encoders
    )
    
    # יצירת גרפים להצגת התקדמות האימון
    plot_training_history(history)
    
    # שמירת המודל
    '''
     הקובץ בו נשמר המודל האחרון לאחר סיום כל האפוקים (לא בהכרח הטוב ביותר
     '''
    model.save('infant_movenet_movement_gru_model.keras') 
    print("המודל נשמר בהצלחה כקובץ 'infant_movenet_movement_gru_model.keras'")
    
    # שמירת מידע על המאפיינים ששימשו לאימון (לשימוש עתידי)
    with open('model_features.txt', 'w') as f:
        f.write('\n'.join(feature_columns))
    
    print("\nהאימון הסתיים בהצלחה!")

if __name__ == "__main__":
    main()
'''
# Out:
# מתחיל עיבוד של הקובץ: movenet_dataset.csv
# נטענו 55117 שורות נתונים
# קובץ test_movenet_dataset.csv נשמר בהצלחה.
# מספר דוגמאות: 28174
# מספר מאפיינים: 24
# מספר קלאסים לברך דומיננטית: 2
# מספר קלאסים למרפק דומיננטי: 2
# Epoch 1/100
# 563/564 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - dominant_elbow_accuracy: 0.8943 - dominant_elbow_loss: 0.3417 - dominant_knee_accuracy: 0.8638 - dominant_knee_loss: 0.4062 - loss: 16.0227 - movement_score_loss: 15.2749 - movement_score_mae: 3.2203
# Epoch 1: val_loss improved from inf to 9.96043, saving model to best_movenet_infant_movement_model.keras
# 564/564 ━━━━━━━━━━━━━━━━━━━━
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.01      0.02       577
#          1.0       0.90      1.00      0.95      5058
#
#     accuracy                           0.90      5635
#    macro avg       0.87      0.50      0.48      5635
# weighted avg       0.89      0.90      0.85      5635
#
#
# דוח סיווג - מרפק דומיננטי:
#               precision    recall  f1-score   support
#
#          0.0       0.25      0.00      0.00       440
#          1.0       0.92      1.00      0.96      5195
#
#     accuracy                           0.92      5635
#    macro avg       0.59      0.50      0.48      5635
# weighted avg       0.87      0.92      0.88      5635
#
#
# מיפוי תוויות ברך:
# 0: left
# 1: right
#
# מיפוי תוויות מרפק:
# 0: left
# 1: right
# המודל נשמר בהצלחה כקובץ 'infant_movement_gru_model.keras'
#
# האימון הסתיים בהצלחה!

# %%
'''
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import GRU, Dense, Input, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import mean_squared_error, accuracy_score, classification_report
import os
import glob

# הגדרת פרמטרים
WINDOW_SIZE = 30  # מספר הפריימים ברצף (ניתן לשינוי בהתאם לצרכים)
RANDOM_STATE = 42
BATCH_SIZE = 32
EPOCHS = 150
LEARNING_RATE = 0.001

def load_and_preprocess_data(file_paths, window_size=WINDOW_SIZE):
    """
    טעינה ועיבוד מקדים של הנתונים מקבצי האקסל
    """
    all_data = []
    test_data = []

    for file_path in file_paths:
        df = pd.read_csv(file_path) if file_path.endswith('.csv') else pd.read_excel(file_path)
        
        # בדיקה שקיימים העמודות הנדרשות
        required_columns = ['video_id', 'frame', 'window_id', 
                           'overall_movement_score', 'dominant_knee', 'dominant_elbow']
        
        if not all(col in df.columns for col in required_columns):
            print(f"The file {file_path} is missing required columns. Skipping...")
            continue
        test_subset = df[df['video_id'].isin([43, 44])]
        if not test_subset.empty:
            test_data.append(test_subset)
        df = df[~df['video_id'].isin([43, 44])]
        all_data.append(df)
    
    if not all_data:
        raise ValueError("No valid files found for processing")
        
    # איחוד כל הנתונים
    data = pd.concat(all_data, ignore_index=True)
    
    # המרת ערכים קטגוריאליים למספרים
    label_encoders = {}
    for col in ['dominant_knee', 'dominant_elbow']:
        if data[col].dtype == 'object':
            le = LabelEncoder()
            data[col] = le.fit_transform(data[col])
            label_encoders[col] = le
    
    return data, label_encoders, test_data


def prepare_sequences(data, window_size=WINDOW_SIZE):
    """
    הכנת רצפי נתונים עבור GRU לפי חלונות
    """
    feature_columns = [col for col in data.columns if any(x in col for x in ['_x', '_y', '_confidence'])
                        and not any(skip in col.lower() for skip in ['velocity', 'angle'])]
    
    X = []
    y_movement = []
    y_knee = []
    y_elbow = []
    
    # קיבוץ לפי וידאו וחלון
    groups = data.groupby(['video_id', 'window_id'])
    
    for (vid_id, win_id), group in groups:
        if len(group) < window_size:
            # דילוג על חלונות קטנים מדי
            continue
        
        # לכל חלון, ניקח רצפים באורך window_size
        for i in range(0, len(group) - window_size + 1):
            sequence = group.iloc[i:i+window_size][feature_columns].values
            
            # המטרות הן הערכים בפריים האחרון ברצף
            target_frame = group.iloc[i+window_size-1]
            
            X.append(sequence)
            y_movement.append(target_frame['overall_movement_score'])
            y_knee.append(target_frame['dominant_knee'])
            y_elbow.append(target_frame['dominant_elbow'])
    
    X = np.array(X)
    y_movement = np.array(y_movement)
    y_knee = np.array(y_knee)
    y_elbow = np.array(y_elbow)
    
    return X, y_movement, y_knee, y_elbow, feature_columns

def build_gru_model(input_shape, num_knee_classes, num_elbow_classes):
    """
    בניית מודל GRU עם מספר שכבות והתאמה למשימות מרובות
    """
    # שכבת הקלט המשותפת
    inputs = Input(shape=input_shape)
    
    # שכבות GRU משותפות
    x = GRU(128, return_sequences=True)(inputs)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)
    
    x = GRU(64)(x)
    x = BatchNormalization()(x)
    shared_features = Dropout(0.3)(x)
    
    # ענף לציון תנועה כללי (רגרסיה)
    movement_output = Dense(32, activation='relu')(shared_features)
    movement_output = Dense(1, name='movement_score')(movement_output)
    
    # ענף לברך דומיננטית (סיווג)
    knee_output = Dense(32, activation='relu')(shared_features)
    knee_output = Dense(num_knee_classes, activation='softmax', name='dominant_knee')(knee_output)
    
    # ענף למרפק דומיננטי (סיווג)
    elbow_output = Dense(32, activation='relu')(shared_features)
    elbow_output = Dense(num_elbow_classes, activation='softmax', name='dominant_elbow')(elbow_output)
    
    # הגדרת המודל עם קלט ושלושה פלטים
    model = Model(inputs=inputs, outputs=[movement_output, knee_output, elbow_output])
    
    # הגדרת אופטימייזר ופונקציות שגיאה
    model.compile(
        optimizer=Adam(learning_rate=LEARNING_RATE),
        loss={
            'movement_score': 'mean_squared_error',
            'dominant_knee': 'sparse_categorical_crossentropy',
            'dominant_elbow': 'sparse_categorical_crossentropy'
        },
        metrics={
            'movement_score': ['mae'],
            'dominant_knee': ['accuracy'],
            'dominant_elbow': ['accuracy']
        }
    )
    
    return model

def train_model(X_train, y_train, X_val, y_val, input_shape, num_knee_classes, num_elbow_classes):
    """
    אימון המודל עם מנגנוני עצירה מוקדמת ושיפור ביצועים
    """
    model = build_gru_model(input_shape, num_knee_classes, num_elbow_classes)
    
    # הגדרת callbacks
    early_stopping = EarlyStopping(
        monitor='val_loss', 
        patience=15, 
        restore_best_weights=True
    )
    
    reduce_lr = ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        min_lr=0.00001
    )

    '''
        קובץ בו נשמר המודל שמתקבלת בו התוצאה הטובה ביותר על סט הוולידציה
    '''
    model_checkpoint = ModelCheckpoint(
        'best_movenet_infant_movement_model.keras', 
        monitor='val_loss',
        save_best_only=True,
        verbose=1
    )
    
    # אימון המודל
    history = model.fit(
        X_train,
        y_train,
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=(X_val, y_val),
        callbacks=[early_stopping, reduce_lr, model_checkpoint],
        verbose=1
    )
    
    return model, history

def evaluate_model(model, X_test, y_test_movement, y_test_knee, y_test_elbow, label_encoders):
    """
    הערכת המודל והצגת מדדי ביצוע
    """
    # ביצוע חיזוי
    y_pred_movement, y_pred_knee_prob, y_pred_elbow_prob = model.predict(X_test)
    
    # המרת הסתברויות לתוויות
    y_pred_knee = np.argmax(y_pred_knee_prob, axis=1)
    y_pred_elbow = np.argmax(y_pred_elbow_prob, axis=1)
    
    # מדדי ביצוע לציון תנועה כללי
    mse_movement = mean_squared_error(y_test_movement, y_pred_movement)
    '''
    ציון בין 0-10 שמודד עד כמה המודל שגה בחישוב ציון התנועה הכללי- כמה רחוק המודל היהי מהציון תנועה הכללי האמיתי שחושב
    '''
    rmse_movement = np.sqrt(mse_movement) 
    
    # מדדי ביצוע לסיווג ברך ומרפק דומיננטיים
    knee_accuracy = accuracy_score(y_test_knee, y_pred_knee)
    elbow_accuracy = accuracy_score(y_test_elbow, y_pred_elbow)
    
    print("\n===== תוצאות המודל =====")
    print(f"RMSE for motion score: {rmse_movement:.4f}")
    print(f"דיוק סיווג ברך דומיננטית: {knee_accuracy:.4f}")
    print(f"דיוק סיווג מרפק דומיננטי: {elbow_accuracy:.4f}")
    
    print("\nדוח סיווג - ברך דומיננטית:")
    print(classification_report(y_test_knee, y_pred_knee))
    
    print("\nדוח סיווג - מרפק דומיננטי:")
    print(classification_report(y_test_elbow, y_pred_elbow))
    
    # פענוח התוויות חזרה לערכים המקוריים (אם נדרש)
    if 'dominant_knee' in label_encoders:
        original_knee_labels = label_encoders['dominant_knee'].inverse_transform(range(len(label_encoders['dominant_knee'].classes_)))
        print("\nמיפוי תוויות ברך:")
        for i, label in enumerate(original_knee_labels):
            print(f"{i}: {label}")
    
    if 'dominant_elbow' in label_encoders:
        original_elbow_labels = label_encoders['dominant_elbow'].inverse_transform(range(len(label_encoders['dominant_elbow'].classes_)))
        print("\nמיפוי תוויות מרפק:")
        for i, label in enumerate(original_elbow_labels):
            print(f"{i}: {label}")
    
    return {
        'rmse_movement': rmse_movement,
        'knee_accuracy': knee_accuracy,
        'elbow_accuracy': elbow_accuracy
    }

def plot_training_history(history):
    """
    יצירת גרפים להצגת התקדמות האימון
    """
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))
    
    # עקומות שגיאה
    axes[0, 0].plot(history.history['loss'], label='Train Loss')
    axes[0, 0].plot(history.history['val_loss'], label='Validation Loss')
    axes[0, 0].set_title('Total Loss')
    axes[0, 0].set_xlabel('Epochs')
    axes[0, 0].set_ylabel('Loss')
    axes[0, 0].legend()
    
    # דיוק ברך דומיננטית
    axes[0, 1].plot(history.history['dominant_knee_accuracy'], label='Train Accuracy')
    axes[0, 1].plot(history.history['val_dominant_knee_accuracy'], label='Validation Accuracy')
    axes[0, 1].set_title('Dominant Knee Accuracy')
    axes[0, 1].set_xlabel('Epochs')
    axes[0, 1].set_ylabel('Accuracy')
    axes[0, 1].legend()
    
    # דיוק מרפק דומיננטי
    axes[1, 0].plot(history.history['dominant_elbow_accuracy'], label='Train Accuracy')
    axes[1, 0].plot(history.history['val_dominant_elbow_accuracy'], label='Validation Accuracy')
    axes[1, 0].set_title('Dominant Elbow Accuracy')
    axes[1, 0].set_xlabel('Epochs')
    axes[1, 0].set_ylabel('Accuracy')
    axes[1, 0].legend()
    
    # שגיאה ממוצעת מוחלטת לציון תנועה
    axes[1, 1].plot(history.history['movement_score_mae'], label='Train MAE')
    axes[1, 1].plot(history.history['val_movement_score_mae'], label='Validation MAE')
    axes[1, 1].set_title('Movement Score MAE')
    axes[1, 1].set_xlabel('Epochs')
    axes[1, 1].set_ylabel('MAE')
    axes[1, 1].legend()
    
    plt.tight_layout()
    plt.savefig('training_history.png')
    plt.show()

def main():
    # הגדרה ידנית של קובץ הנתונים
    file_paths = ['movenet_dataset.csv']
    
    if not os.path.exists('movenet_dataset.csv'):
        print("שגיאה: הקובץ 'movenet_dataset.csv' לא נמצא בתיקייה הנוכחית")
        return
    
    print(f"מתחיל עיבוד של הקובץ: {file_paths[0]}")
    
    # טעינת הנתונים
    try:
        data, label_encoders, test_data = load_and_preprocess_data(file_paths)
        print(f"נטענו {len(data)} שורות נתונים")
    except Exception as e:
        print(f"שגיאה בטעינת הנתונים: {e}")
        return

    if test_data:  # בדיקה שיש נתונים
        test_df = pd.concat(test_data, ignore_index=True)
        test_df.to_csv('test_movenet_dataset.csv', index=False)
        print("קובץ test_movenet_dataset.csv נשמר בהצלחה.")
    else:
        print("לא נמצאו נתוני test_data לשמירה.")
    
    # הכנת רצפי הנתונים
    X, y_movement, y_knee, y_elbow, feature_columns = prepare_sequences(data)
    
    print(f"מספר דוגמאות: {len(X)}")
    print(f"מספר מאפיינים: {X.shape[2]}")
    
    # ספירת מספר הקלאסים הייחודיים
    num_knee_classes = len(np.unique(y_knee))
    num_elbow_classes = len(np.unique(y_elbow))
    
    print(f"מספר קלאסים לברך דומיננטית: {num_knee_classes}")
    print(f"מספר קלאסים למרפק דומיננטי: {num_elbow_classes}")
    
    # חלוקת הנתונים לאימון ובדיקה
    X_train_val, X_test, y_movement_train_val, y_movement_test, \
    y_knee_train_val, y_knee_test, y_elbow_train_val, y_elbow_test = train_test_split(
        X, y_movement, y_knee, y_elbow, test_size=0.2, random_state=RANDOM_STATE
    )
    
    # חלוקה נוספת לאימון ותיקוף
    X_train, X_val, y_movement_train, y_movement_val, \
    y_knee_train, y_knee_val, y_elbow_train, y_elbow_val = train_test_split(
        X_train_val, y_movement_train_val, y_knee_train_val, y_elbow_train_val, 
        test_size=0.2, random_state=RANDOM_STATE
    )
    
    # נירמול הנתונים
    # אין צורך לנרמל את המאפיינים מאחר וכל דגימה היא רצף, 
    # ובמקום זאת נשתמש ב-BatchNormalization בתוך המודל
    
    # הגדרת צורת הקלט למודל
    input_shape = (X_train.shape[1], X_train.shape[2])
    
    # הגדרת הפלטים באופן מתאים לפורמט הנדרש עבור מודל עם פלט מרובה
    y_train = [y_movement_train, y_knee_train, y_elbow_train]
    y_val = [y_movement_val, y_knee_val, y_elbow_val]
    
    # אימון המודל
    model, history = train_model(
        X_train, y_train, X_val, y_val, 
        input_shape, num_knee_classes, num_elbow_classes
    )
    
    # הערכת המודל
    results = evaluate_model(
        model, X_test, y_movement_test, y_knee_test, y_elbow_test, label_encoders
    )
    
    # יצירת גרפים להצגת התקדמות האימון
    plot_training_history(history)
    
    # שמירת המודל
    '''
     הקובץ בו נשמר המודל האחרון לאחר סיום כל האפוקים (לא בהכרח הטוב ביותר
     '''
    model.save('infant_movenet_movement_gru_model.keras') 
    print("המודל נשמר בהצלחה כקובץ 'infant_movenet_movement_gru_model.keras'")
    
    # שמירת מידע על המאפיינים ששימשו לאימון (לשימוש עתידי)
    with open('model_features.txt', 'w') as f:
        f.write('\n'.join(feature_columns))
    
    print("\nהאימון הסתיים בהצלחה!")

if __name__ == "__main__":
    main()
    '''
# Out:
# מתחיל עיבוד של הקובץ: movenet_dataset.csv
# נטענו 55117 שורות נתונים
# קובץ test_movenet_dataset.csv נשמר בהצלחה.
# מספר דוגמאות: 28174
# מספר מאפיינים: 24
# מספר קלאסים לברך דומיננטית: 2
# מספר קלאסים למרפק דומיננטי: 2
# Epoch 1/150
# 562/564 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - dominant_elbow_accuracy: 0.9205 - dominant_elbow_loss: 0.2415 - dominant_knee_accuracy: 0.9043 - dominant_knee_loss: 0.2751 - loss: 5.0055 - movement_score_loss: 4.4889 - movement_score_mae: 1.5981
# Epoch 97: val_loss did not improve from 4.83155
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 13s 23ms/step - dominant_elbow_accuracy: 0.9205 - dominant_elbow_loss: 0.2415 - dominant_knee_accuracy: 0.9043 - dominant_knee_loss: 0.2751 - loss: 5.0057 - movement_score_loss: 4.4891 - movement_score_mae: 1.5981 - val_dominant_elbow_accuracy: 0.9153 - val_dominant_elbow_loss: 0.2494 - val_dominant_knee_accuracy: 0.8993 - val_dominant_knee_loss: 0.2900 - val_loss: 4.8777 - val_movement_score_loss: 4.3361 - val_movement_score_mae: 1.4712 - learning_rate: 1.0000e-05
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step
#
# ===== תוצאות המודל =====
# RMSE for motion score: 2.1324
# דיוק סיווג ברך דומיננטית: 0.8980
# דיוק סיווג מרפק דומיננטי: 0.9219
#
# דוח סיווג - ברך דומיננטית:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.00      0.01       577
#          1.0       0.90      1.00      0.95      5058
#
#     accuracy                           0.90      5635
#    macro avg       0.95      0.50      0.48      5635
# weighted avg       0.91      0.90      0.85      5635
#
#
# דוח סיווג - מרפק דומיננטי:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       440
#          1.0       0.92      1.00      0.96      5195
#
#     accuracy                           0.92      5635
#    macro avg       0.46      0.50      0.48      5635
# weighted avg       0.85      0.92      0.88      5635
#
#
# מיפוי תוויות ברך:
# 0: left
# 1: right
#
# מיפוי תוויות מרפק:
# 0: left
# 1: right
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# המודל נשמר בהצלחה כקובץ 'infant_movenet_movement_gru_model.keras'
#
# האימון הסתיים בהצלחה!

# %%
'''
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import GRU, Dense, Input, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import mean_squared_error, accuracy_score, classification_report
import os
import glob
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import Dense, Lambda

# הגדרת פרמטרים
WINDOW_SIZE = 30  # מספר הפריימים ברצף (ניתן לשינוי בהתאם לצרכים)
RANDOM_STATE = 42
BATCH_SIZE = 32
EPOCHS = 200
LEARNING_RATE = 0.001

def load_and_preprocess_data(file_paths, window_size=WINDOW_SIZE):
    """
    טעינה ועיבוד מקדים של הנתונים מקבצי האקסל
    """
    all_data = []
    test_data = []

    for file_path in file_paths:
        df = pd.read_csv(file_path) if file_path.endswith('.csv') else pd.read_excel(file_path)
        
        # בדיקה שקיימים העמודות הנדרשות
        required_columns = ['video_id', 'frame', 'window_id', 
                           'overall_movement_score', 'dominant_knee', 'dominant_elbow']
        
        if not all(col in df.columns for col in required_columns):
            print(f"The file {file_path} is missing required columns. Skipping...")
            continue
        test_subset = df[df['video_id'].isin([43, 44])]
        if not test_subset.empty:
            test_data.append(test_subset)
        df = df[~df['video_id'].isin([43, 44])]
        all_data.append(df)
    
    if not all_data:
        raise ValueError("No valid files found for processing")
        
    # איחוד כל הנתונים
    data = pd.concat(all_data, ignore_index=True)
    
    # המרת ערכים קטגוריאליים למספרים
    label_encoders = {}
    for col in ['dominant_knee', 'dominant_elbow']:
        if data[col].dtype == 'object':
            le = LabelEncoder()
            data[col] = le.fit_transform(data[col])
            label_encoders[col] = le
    
    return data, label_encoders, test_data


def prepare_sequences(data, window_size=WINDOW_SIZE):
    """
    הכנת רצפי נתונים עבור GRU לפי חלונות
    """
    feature_columns = [col for col in data.columns if any(x in col for x in ['_x', '_y', '_confidence'])
                        and not any(skip in col.lower() for skip in ['velocity', 'angle'])]
    
    X = []
    y_movement = []
    y_knee = []
    y_elbow = []
    
    # קיבוץ לפי וידאו וחלון
    groups = data.groupby(['video_id', 'window_id'])
    
    for (vid_id, win_id), group in groups:
        if len(group) < window_size:
            # דילוג על חלונות קטנים מדי
            continue
        
        # לכל חלון, ניקח רצפים באורך window_size
        for i in range(0, len(group) - window_size + 1):
            sequence = group.iloc[i:i+window_size][feature_columns].values
            
            # המטרות הן הערכים בפריים האחרון ברצף
            target_frame = group.iloc[i+window_size-1]
            
            X.append(sequence)
            y_movement.append(target_frame['overall_movement_score'])
            y_knee.append(target_frame['dominant_knee'])
            y_elbow.append(target_frame['dominant_elbow'])
    
    X = np.array(X)
    y_movement = np.array(y_movement)
    y_knee = np.array(y_knee)
    y_elbow = np.array(y_elbow)
    
    return X, y_movement, y_knee, y_elbow, feature_columns

def build_gru_model(input_shape, num_knee_classes, num_elbow_classes):
    """
    בניית מודל GRU עם מספר שכבות והתאמה למשימות מרובות
    """
    # שכבת הקלט המשותפת
    inputs = Input(shape=input_shape)
    
    # שכבות GRU משותפות
    x = GRU(128, return_sequences=True)(inputs)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)
    
    x = GRU(64)(x)
    x = BatchNormalization()(x)
    shared_features = Dropout(0.3)(x)
    
    # ענף לציון תנועה כללי (רגרסיה)
    movement_output = Dense(32, activation='relu')(shared_features)
    movement_output = Dense(1, activation='sigmoid')(movement_output)
    movement_output = Lambda(lambda x: x * 10, name='movement_score')(movement_output)
    
    # ענף לברך דומיננטית (סיווג)
    knee_output = Dense(32)(shared_features)
    knee_output = LeakyReLU(alpha=0.01)(knee_output)
    knee_output = Dense(num_knee_classes, activation='softmax', name='dominant_knee')(knee_output)
    
    # ענף למרפק דומיננטי (סיווג)
    elbow_output = Dense(32)(shared_features)
    elbow_output = LeakyReLU(alpha=0.01)(elbow_output)
    elbow_output = Dense(num_elbow_classes, activation='softmax', name='dominant_elbow')(elbow_output)
    
    # הגדרת המודל עם קלט ושלושה פלטים
    model = Model(inputs=inputs, outputs=[movement_output, knee_output, elbow_output])
    
    # הגדרת אופטימייזר ופונקציות שגיאה
    model.compile(
        optimizer=Adam(learning_rate=LEARNING_RATE),
        loss={
            'movement_score': 'mean_squared_error',
            'dominant_knee': 'sparse_categorical_crossentropy',
            'dominant_elbow': 'sparse_categorical_crossentropy'
        },
        metrics={
            'movement_score': ['mae'],
            'dominant_knee': ['accuracy'],
            'dominant_elbow': ['accuracy']
        }
    )
    
    return model

def train_model(X_train, y_train, X_val, y_val, input_shape, num_knee_classes, num_elbow_classes):
    """
    אימון המודל עם מנגנוני עצירה מוקדמת ושיפור ביצועים
    """
    model = build_gru_model(input_shape, num_knee_classes, num_elbow_classes)
    
    # הגדרת callbacks
    early_stopping = EarlyStopping(
        monitor='val_loss', 
        patience=15, 
        restore_best_weights=True
    )
    
    reduce_lr = ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        min_lr=0.00001
    )

    '''
        קובץ בו נשמר המודל שמתקבלת בו התוצאה הטובה ביותר על סט הוולידציה
    '''
    model_checkpoint = ModelCheckpoint(
        'best_movenet_infant_movement_model.keras', 
        monitor='val_loss',
        save_best_only=True,
        verbose=1
    )
    
    # אימון המודל
    history = model.fit(
        X_train,
        y_train,
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=(X_val, y_val),
        callbacks=[early_stopping, reduce_lr, model_checkpoint],
        verbose=1
    )
    
    return model, history

def evaluate_model(model, X_test, y_test_movement, y_test_knee, y_test_elbow, label_encoders):
    """
    הערכת המודל והצגת מדדי ביצוע
    """
    # ביצוע חיזוי
    y_pred_movement, y_pred_knee_prob, y_pred_elbow_prob = model.predict(X_test)
    
    # המרת הסתברויות לתוויות
    y_pred_knee = np.argmax(y_pred_knee_prob, axis=1)
    y_pred_elbow = np.argmax(y_pred_elbow_prob, axis=1)
    
    # מדדי ביצוע לציון תנועה כללי
    mse_movement = mean_squared_error(y_test_movement, y_pred_movement)
    '''
    ציון בין 0-10 שמודד עד כמה המודל שגה בחישוב ציון התנועה הכללי- כמה רחוק המודל היהי מהציון תנועה הכללי האמיתי שחושב
    '''
    rmse_movement = np.sqrt(mse_movement) 
    
    # מדדי ביצוע לסיווג ברך ומרפק דומיננטיים
    knee_accuracy = accuracy_score(y_test_knee, y_pred_knee)
    elbow_accuracy = accuracy_score(y_test_elbow, y_pred_elbow)
    
    print("\n===== תוצאות המודל =====")
    print(f"RMSE for motion score: {rmse_movement:.4f}")
    print(f"דיוק סיווג ברך דומיננטית: {knee_accuracy:.4f}")
    print(f"דיוק סיווג מרפק דומיננטי: {elbow_accuracy:.4f}")
    
    print("\nדוח סיווג - ברך דומיננטית:")
    print(classification_report(y_test_knee, y_pred_knee))
    
    print("\nדוח סיווג - מרפק דומיננטי:")
    print(classification_report(y_test_elbow, y_pred_elbow))
    
    # פענוח התוויות חזרה לערכים המקוריים (אם נדרש)
    if 'dominant_knee' in label_encoders:
        original_knee_labels = label_encoders['dominant_knee'].inverse_transform(range(len(label_encoders['dominant_knee'].classes_)))
        print("\nמיפוי תוויות ברך:")
        for i, label in enumerate(original_knee_labels):
            print(f"{i}: {label}")
    
    if 'dominant_elbow' in label_encoders:
        original_elbow_labels = label_encoders['dominant_elbow'].inverse_transform(range(len(label_encoders['dominant_elbow'].classes_)))
        print("\nמיפוי תוויות מרפק:")
        for i, label in enumerate(original_elbow_labels):
            print(f"{i}: {label}")
    
    return {
        'rmse_movement': rmse_movement,
        'knee_accuracy': knee_accuracy,
        'elbow_accuracy': elbow_accuracy
    }

def plot_training_history(history):
    """
    יצירת גרפים להצגת התקדמות האימון
    """
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))
    
    # עקומות שגיאה
    axes[0, 0].plot(history.history['loss'], label='Train Loss')
    axes[0, 0].plot(history.history['val_loss'], label='Validation Loss')
    axes[0, 0].set_title('Total Loss')
    axes[0, 0].set_xlabel('Epochs')
    axes[0, 0].set_ylabel('Loss')
    axes[0, 0].legend()
    
    # דיוק ברך דומיננטית
    axes[0, 1].plot(history.history['dominant_knee_accuracy'], label='Train Accuracy')
    axes[0, 1].plot(history.history['val_dominant_knee_accuracy'], label='Validation Accuracy')
    axes[0, 1].set_title('Dominant Knee Accuracy')
    axes[0, 1].set_xlabel('Epochs')
    axes[0, 1].set_ylabel('Accuracy')
    axes[0, 1].legend()
    
    # דיוק מרפק דומיננטי
    axes[1, 0].plot(history.history['dominant_elbow_accuracy'], label='Train Accuracy')
    axes[1, 0].plot(history.history['val_dominant_elbow_accuracy'], label='Validation Accuracy')
    axes[1, 0].set_title('Dominant Elbow Accuracy')
    axes[1, 0].set_xlabel('Epochs')
    axes[1, 0].set_ylabel('Accuracy')
    axes[1, 0].legend()
    
    # שגיאה ממוצעת מוחלטת לציון תנועה
    axes[1, 1].plot(history.history['movement_score_mae'], label='Train MAE')
    axes[1, 1].plot(history.history['val_movement_score_mae'], label='Validation MAE')
    axes[1, 1].set_title('Movement Score MAE')
    axes[1, 1].set_xlabel('Epochs')
    axes[1, 1].set_ylabel('MAE')
    axes[1, 1].legend()
    
    plt.tight_layout()
    plt.savefig('training_history.png')
    plt.show()

def main():
    # הגדרה ידנית של קובץ הנתונים
    file_paths = ['movenet_dataset.csv']
    
    if not os.path.exists('movenet_dataset.csv'):
        print("שגיאה: הקובץ 'movenet_dataset.csv' לא נמצא בתיקייה הנוכחית")
        return
    
    print(f"מתחיל עיבוד של הקובץ: {file_paths[0]}")
    
    # טעינת הנתונים
    try:
        data, label_encoders, test_data = load_and_preprocess_data(file_paths)
        print(f"נטענו {len(data)} שורות נתונים")
    except Exception as e:
        print(f"שגיאה בטעינת הנתונים: {e}")
        return

    if test_data:  # בדיקה שיש נתונים
        test_df = pd.concat(test_data, ignore_index=True)
        test_df.to_csv('test_movenet_dataset.csv', index=False)
        print("קובץ test_movenet_dataset.csv נשמר בהצלחה.")
    else:
        print("לא נמצאו נתוני test_data לשמירה.")
    
    # הכנת רצפי הנתונים
    X, y_movement, y_knee, y_elbow, feature_columns = prepare_sequences(data)
    
    print(f"מספר דוגמאות: {len(X)}")
    print(f"מספר מאפיינים: {X.shape[2]}")
    
    # ספירת מספר הקלאסים הייחודיים
    num_knee_classes = len(np.unique(y_knee))
    num_elbow_classes = len(np.unique(y_elbow))
    
    print(f"מספר קלאסים לברך דומיננטית: {num_knee_classes}")
    print(f"מספר קלאסים למרפק דומיננטי: {num_elbow_classes}")
    
    # חלוקת הנתונים לאימון ובדיקה
    X_train_val, X_test, y_movement_train_val, y_movement_test, \
    y_knee_train_val, y_knee_test, y_elbow_train_val, y_elbow_test = train_test_split(
        X, y_movement, y_knee, y_elbow, test_size=0.2, random_state=RANDOM_STATE
    )
    
    # חלוקה נוספת לאימון ותיקוף
    X_train, X_val, y_movement_train, y_movement_val, \
    y_knee_train, y_knee_val, y_elbow_train, y_elbow_val = train_test_split(
        X_train_val, y_movement_train_val, y_knee_train_val, y_elbow_train_val, 
        test_size=0.2, random_state=RANDOM_STATE
    )
    
    # נירמול הנתונים
    # אין צורך לנרמל את המאפיינים מאחר וכל דגימה היא רצף, 
    # ובמקום זאת נשתמש ב-BatchNormalization בתוך המודל
    
    # הגדרת צורת הקלט למודל
    input_shape = (X_train.shape[1], X_train.shape[2])
    
    # הגדרת הפלטים באופן מתאים לפורמט הנדרש עבור מודל עם פלט מרובה
    y_train = [y_movement_train, y_knee_train, y_elbow_train]
    y_val = [y_movement_val, y_knee_val, y_elbow_val]
    
    # אימון המודל
    model, history = train_model(
        X_train, y_train, X_val, y_val, 
        input_shape, num_knee_classes, num_elbow_classes
    )
    
    # הערכת המודל
    results = evaluate_model(
        model, X_test, y_movement_test, y_knee_test, y_elbow_test, label_encoders
    )
    
    # יצירת גרפים להצגת התקדמות האימון
    plot_training_history(history)
    
    # שמירת המודל
    '''
     הקובץ בו נשמר המודל האחרון לאחר סיום כל האפוקים (לא בהכרח הטוב ביותר
     '''
    model.save('infant_movenet_movement_gru_model.keras') 
    print("המודל נשמר בהצלחה כקובץ 'infant_movenet_movement_gru_model.keras'")
    
    # שמירת מידע על המאפיינים ששימשו לאימון (לשימוש עתידי)
    with open('model_features.txt', 'w') as f:
        f.write('\n'.join(feature_columns))
    
    print("\nהאימון הסתיים בהצלחה!")

if __name__ == "__main__":
    main()
    '''
# Out:
# מתחיל עיבוד של הקובץ: movenet_dataset.csv
# נטענו 55117 שורות נתונים
# קובץ test_movenet_dataset.csv נשמר בהצלחה.
# מספר דוגמאות: 28174
# מספר מאפיינים: 24
# מספר קלאסים לברך דומיננטית: 2
# מספר קלאסים למרפק דומיננטי: 2
# WARNING:tensorflow:From C:\Users\user\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\core.py:222: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Epoch 1/200
# C:\Users\user\anaconda3\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# 563/564 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - dominant_elbow_accuracy: 0.8661 - dominant_elbow_loss: 0.3656 - dominant_knee_accuracy: 0.8231 - dominant_knee_loss: 0.4367 - loss: 9.7581 - movement_score_loss: 8.9558 - movement_score_mae: 2.5839
# Epoch 1: val_loss improved from inf to 10.89287, saving model to best_movenet_infant_movement_model.keras
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 33s 43ms/step - dominant_elbow_accuracy: 0.8662 - dominant_elbow_loss: 0.3654 - dominant_knee_accuracy: 0.8233 - dominant_knee_loss: 0.4365 - loss: 9.7555 - movement_score_loss: 8.9536 - movement_score_mae: 2.5838 - val_dominant_elbow_accuracy: 0.9148 - val_dominant_elbow_loss: 0.2943 - val_dominant_knee_accuracy: 0.8991 - val_dominant_knee_loss: 0.3239 - val_loss: 10.8929 - val_movement_score_loss: 10.2757 - val_movement_score_mae: 2.7787 - learning_rate: 0.0010
# Epoch 2/200
# 563/564 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - dominant_elbow_accuracy: 0.9244 - dominant_elbow_loss: 0.2771 - dominant_knee_accuracy: 0.8954 - dominant_knee_loss: 0.3455 - loss: 8.6272 - movement_score_loss: 8.0047 - movement_score_mae: 2.5655
# Epoch 2: val_loss improved from 10.89287 to 8.25807, saving model to best_movenet_infant_movement_model.keras
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 23s 40ms/step - dominant_elbow_accuracy: 0.9243 - dominant_elbow_loss: 0.2771 - dominant_knee_accuracy: 0.8954 - dominant_knee_loss: 0.3454 - loss: 8.6271 - movement_score_loss: 8.0045 - movement_score_mae: 2.5655 - val_dominant_elbow_accuracy: 0.9148 - val_dominant_elbow_loss: 0.
200
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - dominant_elbow_accuracy: 0.9235 - dominant_elbow_loss: 0.2362 - dominant_knee_accuracy: 0.8970 - dominant_knee_loss: 0.2887 - loss: 5.0334 - movement_score_loss: 4.5085 - movement_score_mae: 1.5868
# Epoch 91: val_loss did not improve from 4.96163
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 36s 64ms/step - dominant_elbow_accuracy: 0.9235 - dominant_elbow_loss: 0.2362 - dominant_knee_accuracy: 0.8970 - dominant_knee_loss: 0.2887 - loss: 5.0334 - movement_score_loss: 4.5085 - movement_score_mae: 1.5868 - val_dominant_elbow_accuracy: 0.9175 - val_dominant_elbow_loss: 0.2424 - val_dominant_knee_accuracy: 0.8991 - val_dominant_knee_loss: 0.2859 - val_loss: 4.9620 - val_movement_score_loss: 4.4326 - val_movement_score_mae: 1.5323 - learning_rate: 3.1250e-05
# Epoch 92/200
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 0s 445ms/step - dominant_elbow_accuracy: 0.9242 - dominant_elbow_loss: 0.2315 - dominant_knee_accuracy: 0.8922 - dominant_knee_loss: 0.2983 - loss: 5.0312 - movement_score_loss: 4.5014 - movement_score_mae: 1.5602
# Epoch 127: val_loss did not improve from 4.80040
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 254s 450ms/step - dominant_elbow_accuracy: 0.9242 - dominant_elbow_loss: 0.2315 - dominant_knee_accuracy: 0.8922 - dominant_knee_loss: 0.2983 - loss: 5.0311 - movement_score_loss: 4.5013 - movement_score_mae: 1.5602 - val_dominant_elbow_accuracy: 0.9173 - val_dominant_elbow_loss: 0.2398 - val_dominant_knee_accuracy: 0.8988 - val_dominant_knee_loss: 0.2831 - val_loss: 4.8249 - val_movement_score_loss: 4.3010 - val_movement_score_mae: 1.5040 - learning_rate: 1.0000e-05
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step
#
# ===== תוצאות המודל =====
# RMSE for motion score: 2.0725
# דיוק סיווג ברך דומיננטית: 0.8974
# דיוק סיווג מרפק דומיננטי: 0.9244
#
# דוח סיווג - ברך דומיננטית:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       577
#          1.0       0.90      1.00      0.95      5058
#
#     accuracy                           0.90      5635
#    macro avg       0.45      0.50      0.47      5635
# weighted avg       0.81      0.90      0.85      5635
#
#
# דוח סיווג - מרפק דומיננטי:
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.04      0.08       440
#          1.0       0.92      1.00      0.96      5195
#
#     accuracy                           0.92      5635
#    macro avg       0.86      0.52      0.52      5635
# weighted avg       0.91      0.92      0.89      5635
#
#
# מיפוי תוויות ברך:
# 0: left
# 1: right
#
# מיפוי תוויות מרפק:
# 0: left
# 1: right
# המודל נשמר בהצלחה כקובץ 'infant_movenet_movement_gru_model.keras'
#
# האימון הסתיים בהצלחה!

# %%
'''
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import GRU, Dense, Input, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import mean_squared_error, accuracy_score, classification_report
import os
import glob
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import Dense, Lambda

# הגדרת פרמטרים
WINDOW_SIZE = 30  # מספר הפריימים ברצף (ניתן לשינוי בהתאם לצרכים)
RANDOM_STATE = 42
BATCH_SIZE = 32
EPOCHS = 300
LEARNING_RATE = 0.001

def load_and_preprocess_data(file_paths, window_size=WINDOW_SIZE):
    """
    טעינה ועיבוד מקדים של הנתונים מקבצי האקסל
    """
    all_data = []
    test_data = []

    for file_path in file_paths:
        df = pd.read_csv(file_path) if file_path.endswith('.csv') else pd.read_excel(file_path)
        
        # בדיקה שקיימים העמודות הנדרשות
        required_columns = ['video_id', 'frame', 'window_id', 
                           'overall_movement_score', 'dominant_knee', 'dominant_elbow']
        
        if not all(col in df.columns for col in required_columns):
            print(f"The file {file_path} is missing required columns. Skipping...")
            continue
        test_subset = df[df['video_id'].isin([43, 44])]
        if not test_subset.empty:
            test_data.append(test_subset)
        df = df[~df['video_id'].isin([43, 44])]
        all_data.append(df)
    
    if not all_data:
        raise ValueError("No valid files found for processing")
        
    # איחוד כל הנתונים
    data = pd.concat(all_data, ignore_index=True)
    
    # המרת ערכים קטגוריאליים למספרים
    label_encoders = {}
    for col in ['dominant_knee', 'dominant_elbow']:
        if data[col].dtype == 'object':
            le = LabelEncoder()
            data[col] = le.fit_transform(data[col])
            label_encoders[col] = le
    
    return data, label_encoders, test_data


def prepare_sequences(data, window_size=WINDOW_SIZE):
    """
    הכנת רצפי נתונים עבור GRU לפי חלונות
    """
    feature_columns = [col for col in data.columns if any(x in col for x in ['_x', '_y', '_confidence'])
                        and not any(skip in col.lower() for skip in ['velocity', 'angle'])]
    
    X = []
    y_movement = []
    y_knee = []
    y_elbow = []
    
    # קיבוץ לפי וידאו וחלון
    groups = data.groupby(['video_id', 'window_id'])
    
    for (vid_id, win_id), group in groups:
        if len(group) < window_size:
            # דילוג על חלונות קטנים מדי
            continue
        
        # לכל חלון, ניקח רצפים באורך window_size
        for i in range(0, len(group) - window_size + 1):
            sequence = group.iloc[i:i+window_size][feature_columns].values
            
            # המטרות הן הערכים בפריים האחרון ברצף
            target_frame = group.iloc[i+window_size-1]
            
            X.append(sequence)
            y_movement.append(target_frame['overall_movement_score'])
            y_knee.append(target_frame['dominant_knee'])
            y_elbow.append(target_frame['dominant_elbow'])
    
    X = np.array(X)
    y_movement = np.array(y_movement)
    y_knee = np.array(y_knee)
    y_elbow = np.array(y_elbow)
    
    return X, y_movement, y_knee, y_elbow, feature_columns

def build_gru_model(input_shape, num_knee_classes, num_elbow_classes):
    """
    בניית מודל GRU עם מספר שכבות והתאמה למשימות מרובות
    """
    # שכבת הקלט המשותפת
    inputs = Input(shape=input_shape)
    
    # שכבות GRU משותפות
    x = GRU(128, return_sequences=True)(inputs)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)
    
    x = GRU(64)(x)
    x = BatchNormalization()(x)
    shared_features = Dropout(0.3)(x)
    
    # ענף לציון תנועה כללי (רגרסיה)
    from tensorflow.keras.layers import ReLU

    movement_output = Dense(32, activation='relu')(shared_features)
    movement_output = Dense(1)(movement_output)
    movement_output = ReLU(max_value=10, name='movement_score')(movement_output)

    
    # ענף לברך דומיננטית (סיווג)
    knee_output = Dense(32)(shared_features)
    knee_output = LeakyReLU(alpha=0.01)(knee_output)
    knee_output = Dense(num_knee_classes, activation='softmax', name='dominant_knee')(knee_output)
    
    # ענף למרפק דומיננטי (סיווג)
    elbow_output = Dense(32)(shared_features)
    elbow_output = LeakyReLU(alpha=0.01)(elbow_output)
    elbow_output = Dense(num_elbow_classes, activation='softmax', name='dominant_elbow')(elbow_output)
    
    # הגדרת המודל עם קלט ושלושה פלטים
    model = Model(inputs=inputs, outputs=[movement_output, knee_output, elbow_output])
    
    # הגדרת אופטימייזר ופונקציות שגיאה
    model.compile(
        optimizer=Adam(learning_rate=LEARNING_RATE),
        loss={
            'movement_score': 'mean_squared_error',
            'dominant_knee': 'sparse_categorical_crossentropy',
            'dominant_elbow': 'sparse_categorical_crossentropy'
        },
        metrics={
            'movement_score': ['mae'],
            'dominant_knee': ['accuracy'],
            'dominant_elbow': ['accuracy']
        }
    )
    
    return model

def train_model(X_train, y_train, X_val, y_val, input_shape, num_knee_classes, num_elbow_classes):
    """
    אימון המודל עם מנגנוני עצירה מוקדמת ושיפור ביצועים
    """
    model = build_gru_model(input_shape, num_knee_classes, num_elbow_classes)
    
    # הגדרת callbacks
    early_stopping = EarlyStopping(
        monitor='val_loss', 
        patience=15, 
        restore_best_weights=True
    )
    
    reduce_lr = ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        min_lr=0.00001
    )

    '''
        קובץ בו נשמר המודל שמתקבלת בו התוצאה הטובה ביותר על סט הוולידציה
    '''
    model_checkpoint = ModelCheckpoint(
        'best_movenet_infant_movement_model.keras', 
        monitor='val_loss',
        save_best_only=True,
        verbose=1
    )
    
    # אימון המודל
    history = model.fit(
        X_train,
        y_train,
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=(X_val, y_val),
        callbacks=[early_stopping, reduce_lr, model_checkpoint],
        verbose=1
    )
    
    return model, history

def evaluate_model(model, X_test, y_test_movement, y_test_knee, y_test_elbow, label_encoders):
    """
    הערכת המודל והצגת מדדי ביצוע
    """
    # ביצוע חיזוי
    y_pred_movement, y_pred_knee_prob, y_pred_elbow_prob = model.predict(X_test)
    
    # המרת הסתברויות לתוויות
    y_pred_knee = np.argmax(y_pred_knee_prob, axis=1)
    y_pred_elbow = np.argmax(y_pred_elbow_prob, axis=1)
    
    # מדדי ביצוע לציון תנועה כללי
    mse_movement = mean_squared_error(y_test_movement, y_pred_movement)
    '''
    ציון בין 0-10 שמודד עד כמה המודל שגה בחישוב ציון התנועה הכללי- כמה רחוק המודל היהי מהציון תנועה הכללי האמיתי שחושב
    '''
    rmse_movement = np.sqrt(mse_movement) 
    
    # מדדי ביצוע לסיווג ברך ומרפק דומיננטיים
    knee_accuracy = accuracy_score(y_test_knee, y_pred_knee)
    elbow_accuracy = accuracy_score(y_test_elbow, y_pred_elbow)
    
    print("\n===== תוצאות המודל =====")
    print(f"RMSE for motion score: {rmse_movement:.4f}")
    print(f"דיוק סיווג ברך דומיננטית: {knee_accuracy:.4f}")
    print(f"דיוק סיווג מרפק דומיננטי: {elbow_accuracy:.4f}")
    
    print("\nדוח סיווג - ברך דומיננטית:")
    print(classification_report(y_test_knee, y_pred_knee))
    
    print("\nדוח סיווג - מרפק דומיננטי:")
    print(classification_report(y_test_elbow, y_pred_elbow))
    
    # פענוח התוויות חזרה לערכים המקוריים (אם נדרש)
    if 'dominant_knee' in label_encoders:
        original_knee_labels = label_encoders['dominant_knee'].inverse_transform(range(len(label_encoders['dominant_knee'].classes_)))
        print("\nמיפוי תוויות ברך:")
        for i, label in enumerate(original_knee_labels):
            print(f"{i}: {label}")
    
    if 'dominant_elbow' in label_encoders:
        original_elbow_labels = label_encoders['dominant_elbow'].inverse_transform(range(len(label_encoders['dominant_elbow'].classes_)))
        print("\nמיפוי תוויות מרפק:")
        for i, label in enumerate(original_elbow_labels):
            print(f"{i}: {label}")
    
    return {
        'rmse_movement': rmse_movement,
        'knee_accuracy': knee_accuracy,
        'elbow_accuracy': elbow_accuracy
    }

def plot_training_history(history):
    """
    יצירת גרפים להצגת התקדמות האימון
    """
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))
    
    # עקומות שגיאה
    axes[0, 0].plot(history.history['loss'], label='Train Loss')
    axes[0, 0].plot(history.history['val_loss'], label='Validation Loss')
    axes[0, 0].set_title('Total Loss')
    axes[0, 0].set_xlabel('Epochs')
    axes[0, 0].set_ylabel('Loss')
    axes[0, 0].legend()
    
    # דיוק ברך דומיננטית
    axes[0, 1].plot(history.history['dominant_knee_accuracy'], label='Train Accuracy')
    axes[0, 1].plot(history.history['val_dominant_knee_accuracy'], label='Validation Accuracy')
    axes[0, 1].set_title('Dominant Knee Accuracy')
    axes[0, 1].set_xlabel('Epochs')
    axes[0, 1].set_ylabel('Accuracy')
    axes[0, 1].legend()
    
    # דיוק מרפק דומיננטי
    axes[1, 0].plot(history.history['dominant_elbow_accuracy'], label='Train Accuracy')
    axes[1, 0].plot(history.history['val_dominant_elbow_accuracy'], label='Validation Accuracy')
    axes[1, 0].set_title('Dominant Elbow Accuracy')
    axes[1, 0].set_xlabel('Epochs')
    axes[1, 0].set_ylabel('Accuracy')
    axes[1, 0].legend()
    
    # שגיאה ממוצעת מוחלטת לציון תנועה
    axes[1, 1].plot(history.history['movement_score_mae'], label='Train MAE')
    axes[1, 1].plot(history.history['val_movement_score_mae'], label='Validation MAE')
    axes[1, 1].set_title('Movement Score MAE')
    axes[1, 1].set_xlabel('Epochs')
    axes[1, 1].set_ylabel('MAE')
    axes[1, 1].legend()
    
    plt.tight_layout()
    plt.savefig('training_history.png')
    plt.show()

def main():
    # הגדרה ידנית של קובץ הנתונים
    file_paths = ['movenet_dataset.csv']
    
    if not os.path.exists('movenet_dataset.csv'):
        print("שגיאה: הקובץ 'movenet_dataset.csv' לא נמצא בתיקייה הנוכחית")
        return
    
    print(f"מתחיל עיבוד של הקובץ: {file_paths[0]}")
    
    # טעינת הנתונים
    try:
        data, label_encoders, test_data = load_and_preprocess_data(file_paths)
        print(f"נטענו {len(data)} שורות נתונים")
    except Exception as e:
        print(f"שגיאה בטעינת הנתונים: {e}")
        return

    if test_data:  # בדיקה שיש נתונים
        test_df = pd.concat(test_data, ignore_index=True)
        test_df.to_csv('test_movenet_dataset.csv', index=False)
        print("קובץ test_movenet_dataset.csv נשמר בהצלחה.")
    else:
        print("לא נמצאו נתוני test_data לשמירה.")
    
    # הכנת רצפי הנתונים
    X, y_movement, y_knee, y_elbow, feature_columns = prepare_sequences(data)
    
    print(f"מספר דוגמאות: {len(X)}")
    print(f"מספר מאפיינים: {X.shape[2]}")
    
    # ספירת מספר הקלאסים הייחודיים
    num_knee_classes = len(np.unique(y_knee))
    num_elbow_classes = len(np.unique(y_elbow))
    
    print(f"מספר קלאסים לברך דומיננטית: {num_knee_classes}")
    print(f"מספר קלאסים למרפק דומיננטי: {num_elbow_classes}")
    
    # חלוקת הנתונים לאימון ובדיקה
    X_train_val, X_test, y_movement_train_val, y_movement_test, \
    y_knee_train_val, y_knee_test, y_elbow_train_val, y_elbow_test = train_test_split(
        X, y_movement, y_knee, y_elbow, test_size=0.2, random_state=RANDOM_STATE
    )
    
    # חלוקה נוספת לאימון ותיקוף
    X_train, X_val, y_movement_train, y_movement_val, \
    y_knee_train, y_knee_val, y_elbow_train, y_elbow_val = train_test_split(
        X_train_val, y_movement_train_val, y_knee_train_val, y_elbow_train_val, 
        test_size=0.2, random_state=RANDOM_STATE
    )
    
    # נירמול הנתונים
    # אין צורך לנרמל את המאפיינים מאחר וכל דגימה היא רצף, 
    # ובמקום זאת נשתמש ב-BatchNormalization בתוך המודל
    
    # הגדרת צורת הקלט למודל
    input_shape = (X_train.shape[1], X_train.shape[2])
    
    # הגדרת הפלטים באופן מתאים לפורמט הנדרש עבור מודל עם פלט מרובה
    y_train = [y_movement_train, y_knee_train, y_elbow_train]
    y_val = [y_movement_val, y_knee_val, y_elbow_val]
    
    # אימון המודל
    model, history = train_model(
        X_train, y_train, X_val, y_val, 
        input_shape, num_knee_classes, num_elbow_classes
    )
    
    # הערכת המודל
    results = evaluate_model(
        model, X_test, y_movement_test, y_knee_test, y_elbow_test, label_encoders
    )
    
    # יצירת גרפים להצגת התקדמות האימון
    plot_training_history(history)
    
    # שמירת המודל
    '''
     הקובץ בו נשמר המודל האחרון לאחר סיום כל האפוקים (לא בהכרח הטוב ביותר
     '''
    model.save('infant_movenet_movement_gru_model.keras') 
    print("המודל נשמר בהצלחה כקובץ 'infant_movenet_movement_gru_model.keras'")
    
    # שמירת מידע על המאפיינים ששימשו לאימון (לשימוש עתידי)
    with open('model_features.txt', 'w') as f:
        f.write('\n'.join(feature_columns))
    
    print("\nהאימון הסתיים בהצלחה!")

if __name__ == "__main__":
    main()
# Out:
# מתחיל עיבוד של הקובץ: movenet_dataset.csv
# נטענו 55117 שורות נתונים
# קובץ test_movenet_dataset.csv נשמר בהצלחה.
# מספר דוגמאות: 28174
# מספר מאפיינים: 24
# מספר קלאסים לברך דומיננטית: 2
# מספר קלאסים למרפק דומיננטי: 2
# C:\Users\user\anaconda3\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Epoch 1/300
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - dominant_elbow_accuracy: 0.8505 - dominant_elbow_loss: 0.4040 - dominant_knee_accuracy: 0.8827 - dominant_knee_loss: 0.3759 - loss: 13.9143 - movement_score_loss: 13.1344 - movement_score_mae: 2.9604
# Epoch 1: val_loss improved from inf to 8.71053, saving model to best_movenet_infant_movement_model.keras
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 45s 66ms/step - dominant_elbow_accuracy: 0.8506 - dominant_elbow_loss: 0.4039 - dominant_knee_accuracy: 0.8827 - dominant_knee_loss: 0.3759 - loss: 13.9088 - movement_score_loss: 13.1291 - movement_score_mae: 2.9599 - val_dominant_elbow_accuracy: 0.9148 - val_dominant_elbow_loss: 0.
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 36s 64ms/step - dominant_elbow_accuracy: 0.9256 - dominant_elbow_loss: 0.2114 - dominant_knee_accuracy: 0.9009 - dominant_knee_loss: 0.2561 - loss: 3.2319 - movement_score_loss: 2.7644 - movement_score_mae: 1.0073 - val_dominant_elbow_accuracy: 0.9246 - val_dominant_elbow_loss: 0.2038 - val_dominant_knee_accuracy: 0.9086 - val_dominant_knee_loss: 0.2474 - val_loss: 3.0520 - val_movement_score_loss: 2.6011 - val_movement_score_mae: 0.9011 - learning_rate: 1.0000e-05
# Epoch 173/300
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - dominant_elbow_accuracy: 0.9255 - dominant_elbow_loss: 0.2116 - dominant_knee_accuracy: 0.8984 - dominant_knee_loss: 0.2607 - loss: 3.2489 - movement_score_loss: 2.7766 - movement_score_mae: 1.0163
# Epoch 173: val_loss did not improve from 3.04532
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 36s 64ms/step - dominant_elbow_accuracy: 0.9255 - dominant_elbow_loss: 0.2116 - dominant_knee_accuracy: 0.8984 - dominant_knee_loss: 0.2607 - loss: 3.2490 - movement_score_loss: 2.7767 - movement_score_mae: 1.0163 - val_dominant_elbow_accuracy: 0.9255 - val_dominant_elbow_loss: 0.2043 - val_dominant_knee_accuracy: 0.9071 - val_dominant_knee_loss: 0.2471 - val_loss: 3.0499 - val_movement_score_loss: 2.5985 - val_movement_score_mae: 0.9101 - learning_rate: 1.0000e-05
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step
#
# ===== תוצאות המודל =====
# RMSE for motion score: 1.6233
# דיוק סיווג ברך דומיננטית: 0.9051
# דיוק סיווג מרפק דומיננטי: 0.9301
#
# דוח סיווג - ברך דומיננטית:
#               precision    recall  f1-score   support
#
#          0.0       0.72      0.12      0.20       577
#          1.0       0.91      0.99      0.95      5058
#
#     accuracy                           0.91      5635
#    macro avg       0.82      0.56      0.58      5635
# weighted avg       0.89      0.91      0.87      5635
#
#
# דוח סיווג - מרפק דומיננטי:
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.14      0.24       440
#          1.0       0.93      1.00      0.96      5195
#
#     accuracy                           0.93      5635
#    macro avg       0.86      0.57      0.60      5635
# weighted avg       0.92      0.93      0.91      5635
#
#
# מיפוי תוויות ברך:
# 0: left
# 1: right
#
# מיפוי תוויות מרפק:
# 0: left
# 1: right
# המודל נשמר בהצלחה כקובץ 'infant_movenet_movement_gru_model.keras'
#
# האימון הסתיים בהצלחה!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import GRU, Dense, Input, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import mean_squared_error, accuracy_score, classification_report
import os
import glob
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import Dense, Lambda

# הגדרת פרמטרים
WINDOW_SIZE = 30  # מספר הפריימים ברצף (ניתן לשינוי בהתאם לצרכים)
RANDOM_STATE = 42
BATCH_SIZE = 32
EPOCHS = 300
LEARNING_RATE = 0.001

def load_and_preprocess_data(file_paths, window_size=WINDOW_SIZE):
    """
    טעינה ועיבוד מקדים של הנתונים מקבצי האקסל
    """
    all_data = []
    test_data = []

    for file_path in file_paths:
        df = pd.read_csv(file_path) if file_path.endswith('.csv') else pd.read_excel(file_path)
        
        # בדיקה שקיימים העמודות הנדרשות
        required_columns = ['video_id', 'frame', 'window_id', 
                           'overall_movement_score', 'dominant_knee', 'dominant_elbow']
        
        if not all(col in df.columns for col in required_columns):
            print(f"The file {file_path} is missing required columns. Skipping...")
            continue
        test_subset = df[df['video_id'].isin([43, 44])]
        if not test_subset.empty:
            test_data.append(test_subset)
        df = df[~df['video_id'].isin([43, 44])]
        all_data.append(df)
    
    if not all_data:
        raise ValueError("No valid files found for processing")
        
    # איחוד כל הנתונים
    data = pd.concat(all_data, ignore_index=True)
    
    # המרת ערכים קטגוריאליים למספרים
    label_encoders = {}
    for col in ['dominant_knee', 'dominant_elbow']:
        if data[col].dtype == 'object':
            le = LabelEncoder()
            data[col] = le.fit_transform(data[col])
            label_encoders[col] = le
    
    return data, label_encoders, test_data


def prepare_sequences(data, window_size=WINDOW_SIZE):
    """
    הכנת רצפי נתונים עבור GRU לפי חלונות
    """
    feature_columns = [col for col in data.columns if any(x in col for x in ['_x', '_y', '_confidence'])
                        and not any(skip in col.lower() for skip in ['velocity', 'angle'])]
    
    X = []
    y_movement = []
    y_knee = []
    y_elbow = []
    
    # קיבוץ לפי וידאו וחלון
    groups = data.groupby(['video_id', 'window_id'])
    
    for (vid_id, win_id), group in groups:
        if len(group) < window_size:
            # דילוג על חלונות קטנים מדי
            continue
        
        # לכל חלון, ניקח רצפים באורך window_size
        for i in range(0, len(group) - window_size + 1):
            sequence = group.iloc[i:i+window_size][feature_columns].values
            
            # המטרות הן הערכים בפריים האחרון ברצף
            target_frame = group.iloc[i+window_size-1]
            
            X.append(sequence)
            y_movement.append(target_frame['overall_movement_score'])
            y_knee.append(target_frame['dominant_knee'])
            y_elbow.append(target_frame['dominant_elbow'])
    
    X = np.array(X)
    y_movement = np.array(y_movement)
    y_knee = np.array(y_knee)
    y_elbow = np.array(y_elbow)
    
    return X, y_movement, y_knee, y_elbow, feature_columns

def build_gru_model(input_shape, num_knee_classes, num_elbow_classes):
    """
    בניית מודל GRU עם מספר שכבות והתאמה למשימות מרובות
    """
    # שכבת הקלט המשותפת
    inputs = Input(shape=input_shape)
    
    # שכבות GRU משותפות
    x = GRU(128, return_sequences=True)(inputs)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)
    
    x = GRU(64)(x)
    x = BatchNormalization()(x)
    shared_features = Dropout(0.3)(x)
    
    # ענף לציון תנועה כללי (רגרסיה)
    from tensorflow.keras.layers import ReLU

    movement_output = Dense(32, activation='relu')(shared_features)
    movement_output = Dense(1)(movement_output)
    movement_output = ReLU(max_value=10, name='movement_score')(movement_output)

    
    # ענף לברך דומיננטית (סיווג)
    knee_output = Dense(32)(shared_features)
    knee_output = LeakyReLU(alpha=0.01)(knee_output)
    knee_output = Dense(num_knee_classes, activation='softmax', name='dominant_knee')(knee_output)
    
    # ענף למרפק דומיננטי (סיווג)
    elbow_output = Dense(32)(shared_features)
    elbow_output = LeakyReLU(alpha=0.01)(elbow_output)
    elbow_output = Dense(num_elbow_classes, activation='softmax', name='dominant_elbow')(elbow_output)
    
    # הגדרת המודל עם קלט ושלושה פלטים
    model = Model(inputs=inputs, outputs=[movement_output, knee_output, elbow_output])
    
    # הגדרת אופטימייזר ופונקציות שגיאה
    model.compile(
        optimizer=Adam(learning_rate=LEARNING_RATE),
        loss={
            'movement_score': 'mean_squared_error',
            'dominant_knee': 'sparse_categorical_crossentropy',
            'dominant_elbow': 'sparse_categorical_crossentropy'
        },
        metrics={
            'movement_score': ['mae'],
            'dominant_knee': ['accuracy'],
            'dominant_elbow': ['accuracy']
        }
    )
    
    return model

def train_model(X_train, y_train, X_val, y_val, input_shape, num_knee_classes, num_elbow_classes):
    """
    אימון המודל עם מנגנוני עצירה מוקדמת ושיפור ביצועים
    """
    model = build_gru_model(input_shape, num_knee_classes, num_elbow_classes)
    
    # הגדרת callbacks
    early_stopping = EarlyStopping(
        monitor='val_loss', 
        patience=50, 
        restore_best_weights=True
    )
    
    reduce_lr = ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        min_lr=0.00001
    )

    '''
        קובץ בו נשמר המודל שמתקבלת בו התוצאה הטובה ביותר על סט הוולידציה
    '''
    model_checkpoint = ModelCheckpoint(
        'best_movenet_infant_movement_model.keras', 
        monitor='val_loss',
        save_best_only=True,
        verbose=1
    )
    
    # אימון המודל
    history = model.fit(
        X_train,
        y_train,
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=(X_val, y_val),
        callbacks=[early_stopping, reduce_lr, model_checkpoint],
        verbose=1
    )
    
    return model, history

def evaluate_model(model, X_test, y_test_movement, y_test_knee, y_test_elbow, label_encoders):
    """
    הערכת המודל והצגת מדדי ביצוע
    """
    # ביצוע חיזוי
    y_pred_movement, y_pred_knee_prob, y_pred_elbow_prob = model.predict(X_test)
    
    # המרת הסתברויות לתוויות
    y_pred_knee = np.argmax(y_pred_knee_prob, axis=1)
    y_pred_elbow = np.argmax(y_pred_elbow_prob, axis=1)
    
    # מדדי ביצוע לציון תנועה כללי
    mse_movement = mean_squared_error(y_test_movement, y_pred_movement)
    '''
    ציון בין 0-10 שמודד עד כמה המודל שגה בחישוב ציון התנועה הכללי- כמה רחוק המודל היהי מהציון תנועה הכללי האמיתי שחושב
    '''
    rmse_movement = np.sqrt(mse_movement) 
    
    # מדדי ביצוע לסיווג ברך ומרפק דומיננטיים
    knee_accuracy = accuracy_score(y_test_knee, y_pred_knee)
    elbow_accuracy = accuracy_score(y_test_elbow, y_pred_elbow)
    
    print("\n===== תוצאות המודל =====")
    print(f"RMSE for motion score: {rmse_movement:.4f}")
    print(f"דיוק סיווג ברך דומיננטית: {knee_accuracy:.4f}")
    print(f"דיוק סיווג מרפק דומיננטי: {elbow_accuracy:.4f}")
    
    print("\nדוח סיווג - ברך דומיננטית:")
    print(classification_report(y_test_knee, y_pred_knee))
    
    print("\nדוח סיווג - מרפק דומיננטי:")
    print(classification_report(y_test_elbow, y_pred_elbow))
    
    # פענוח התוויות חזרה לערכים המקוריים (אם נדרש)
    if 'dominant_knee' in label_encoders:
        original_knee_labels = label_encoders['dominant_knee'].inverse_transform(range(len(label_encoders['dominant_knee'].classes_)))
        print("\nמיפוי תוויות ברך:")
        for i, label in enumerate(original_knee_labels):
            print(f"{i}: {label}")
    
    if 'dominant_elbow' in label_encoders:
        original_elbow_labels = label_encoders['dominant_elbow'].inverse_transform(range(len(label_encoders['dominant_elbow'].classes_)))
        print("\nמיפוי תוויות מרפק:")
        for i, label in enumerate(original_elbow_labels):
            print(f"{i}: {label}")
    
    return {
        'rmse_movement': rmse_movement,
        'knee_accuracy': knee_accuracy,
        'elbow_accuracy': elbow_accuracy
    }

def plot_training_history(history):
    """
    יצירת גרפים להצגת התקדמות האימון
    """
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))
    
    # עקומות שגיאה
    axes[0, 0].plot(history.history['loss'], label='Train Loss')
    axes[0, 0].plot(history.history['val_loss'], label='Validation Loss')
    axes[0, 0].set_title('Total Loss')
    axes[0, 0].set_xlabel('Epochs')
    axes[0, 0].set_ylabel('Loss')
    axes[0, 0].legend()
    
    # דיוק ברך דומיננטית
    axes[0, 1].plot(history.history['dominant_knee_accuracy'], label='Train Accuracy')
    axes[0, 1].plot(history.history['val_dominant_knee_accuracy'], label='Validation Accuracy')
    axes[0, 1].set_title('Dominant Knee Accuracy')
    axes[0, 1].set_xlabel('Epochs')
    axes[0, 1].set_ylabel('Accuracy')
    axes[0, 1].legend()
    
    # דיוק מרפק דומיננטי
    axes[1, 0].plot(history.history['dominant_elbow_accuracy'], label='Train Accuracy')
    axes[1, 0].plot(history.history['val_dominant_elbow_accuracy'], label='Validation Accuracy')
    axes[1, 0].set_title('Dominant Elbow Accuracy')
    axes[1, 0].set_xlabel('Epochs')
    axes[1, 0].set_ylabel('Accuracy')
    axes[1, 0].legend()
    
    # שגיאה ממוצעת מוחלטת לציון תנועה
    axes[1, 1].plot(history.history['movement_score_mae'], label='Train MAE')
    axes[1, 1].plot(history.history['val_movement_score_mae'], label='Validation MAE')
    axes[1, 1].set_title('Movement Score MAE')
    axes[1, 1].set_xlabel('Epochs')
    axes[1, 1].set_ylabel('MAE')
    axes[1, 1].legend()
    
    plt.tight_layout()
    plt.savefig('training_history.png')
    plt.show()

def main():
    # הגדרה ידנית של קובץ הנתונים
    file_paths = ['movenet_dataset.csv']
    
    if not os.path.exists('movenet_dataset.csv'):
        print("שגיאה: הקובץ 'movenet_dataset.csv' לא נמצא בתיקייה הנוכחית")
        return
    
    print(f"מתחיל עיבוד של הקובץ: {file_paths[0]}")
    
    # טעינת הנתונים
    try:
        data, label_encoders, test_data = load_and_preprocess_data(file_paths)
        print(f"נטענו {len(data)} שורות נתונים")
    except Exception as e:
        print(f"שגיאה בטעינת הנתונים: {e}")
        return

    if test_data:  # בדיקה שיש נתונים
        test_df = pd.concat(test_data, ignore_index=True)
        test_df.to_csv('test_movenet_dataset.csv', index=False)
        print("קובץ test_movenet_dataset.csv נשמר בהצלחה.")
    else:
        print("לא נמצאו נתוני test_data לשמירה.")
    
    # הכנת רצפי הנתונים
    X, y_movement, y_knee, y_elbow, feature_columns = prepare_sequences(data)
    
    print(f"מספר דוגמאות: {len(X)}")
    print(f"מספר מאפיינים: {X.shape[2]}")
    
    # ספירת מספר הקלאסים הייחודיים
    num_knee_classes = len(np.unique(y_knee))
    num_elbow_classes = len(np.unique(y_elbow))
    
    print(f"מספר קלאסים לברך דומיננטית: {num_knee_classes}")
    print(f"מספר קלאסים למרפק דומיננטי: {num_elbow_classes}")
    
    # חלוקת הנתונים לאימון ובדיקה
    X_train_val, X_test, y_movement_train_val, y_movement_test, \
    y_knee_train_val, y_knee_test, y_elbow_train_val, y_elbow_test = train_test_split(
        X, y_movement, y_knee, y_elbow, test_size=0.2, random_state=RANDOM_STATE
    )
    
    # חלוקה נוספת לאימון ותיקוף
    X_train, X_val, y_movement_train, y_movement_val, \
    y_knee_train, y_knee_val, y_elbow_train, y_elbow_val = train_test_split(
        X_train_val, y_movement_train_val, y_knee_train_val, y_elbow_train_val, 
        test_size=0.2, random_state=RANDOM_STATE
    )
    
    # נירמול הנתונים
    # אין צורך לנרמל את המאפיינים מאחר וכל דגימה היא רצף, 
    # ובמקום זאת נשתמש ב-BatchNormalization בתוך המודל
    
    # הגדרת צורת הקלט למודל
    input_shape = (X_train.shape[1], X_train.shape[2])
    
    # הגדרת הפלטים באופן מתאים לפורמט הנדרש עבור מודל עם פלט מרובה
    y_train = [y_movement_train, y_knee_train, y_elbow_train]
    y_val = [y_movement_val, y_knee_val, y_elbow_val]
    
    # אימון המודל
    model, history = train_model(
        X_train, y_train, X_val, y_val, 
        input_shape, num_knee_classes, num_elbow_classes
    )
    
    # הערכת המודל
    results = evaluate_model(
        model, X_test, y_movement_test, y_knee_test, y_elbow_test, label_encoders
    )
    
    # יצירת גרפים להצגת התקדמות האימון
    plot_training_history(history)
    
    # שמירת המודל
    '''
     הקובץ בו נשמר המודל האחרון לאחר סיום כל האפוקים (לא בהכרח הטוב ביותר
     '''
    model.save('infant_movenet_movement_gru_model.keras') 
    print("המודל נשמר בהצלחה כקובץ 'infant_movenet_movement_gru_model.keras'")
    
    # שמירת מידע על המאפיינים ששימשו לאימון (לשימוש עתידי)
    with open('model_features.txt', 'w') as f:
        f.write('\n'.join(feature_columns))
    
    print("\nהאימון הסתיים בהצלחה!")

if __name__ == "__main__":
    main()
# Out:
# מתחיל עיבוד של הקובץ: movenet_dataset.csv
# נטענו 55117 שורות נתונים
# קובץ test_movenet_dataset.csv נשמר בהצלחה.
# מספר דוגמאות: 28174
# מספר מאפיינים: 24
# מספר קלאסים לברך דומיננטית: 2
# מספר קלאסים למרפק דומיננטי: 2
# Epoch 1/300
# C:\Users\user\anaconda3\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - dominant_elbow_accuracy: 0.9080 - dominant_elbow_loss: 0.3166 - dominant_knee_accuracy: 0.8462 - dominant_knee_loss: 0.4198 - loss: 16.9469 - movement_score_loss: 16.2105 - movement_score_mae: 3.2569
# Epoch 1: val_loss improved from inf to 10.20676, saving model to best_movenet_infant_movement_model.keras
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 21s 26ms/step - dominant_elbow_accuracy: 0.9080 - dominant_elbow_loss: 0.3166 - dominant_knee_accuracy: 0.8463 - dominant_knee_loss: 0.4197 - loss: 16.9374 - movement_score_loss: 16.2011 - movement_score_mae: 3.2560 - val_dominant_elbow_accuracy: 0.9148 - val_dominant_elbow_loss: 0.2976 - val_dominant_knee_accuracy: 0.8991 - val_dominant_knee_loss: 0.3434 - val_loss: 10.2068 - val_movement_score_loss: 9.5656 - val_movement_score_mae: 2.5234 - learning_rate: 0.0010
# Epoch 2/300
# 562/564 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - dominant_elbow_accuracy: 0.9207 - dominant_elbow_loss: 0.2832 - dominant_knee_accuracy: 0.8938 - dominant_knee_loss: 0.3470 - loss: 9.4027 - movement_score_loss: 8.7725 - movement_score_mae: 2.5878
# Epoch 2: val_loss improved from 10.20676 to 8.34551, saving model to best_movenet_infant_movement_model.keras
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 14s 25ms/step - dominant_elbow_accuracy: 0.
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 19s 33ms/step - dominant_elbow_accuracy: 0.9247 - dominant_elbow_loss: 0.2220 - dominant_knee_accuracy: 0.8974 - dominant_knee_loss: 0.2619 - loss: 3.7224 - movement_score_loss: 3.2385 - movement_score_mae: 1.1393 - val_dominant_elbow_accuracy: 0.9179 - val_dominant_elbow_loss: 0.2160 - val_dominant_knee_accuracy: 0.9028 - val_dominant_knee_loss: 0.2527 - val_loss: 3.6588 - val_movement_score_loss: 3.1899 - val_movement_score_mae: 1.0882 - learning_rate: 1.0000e-05
# Epoch 299/300
# 563/564 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dominant_elbow_accuracy: 0.9234 - dominant_elbow_loss: 0.2211 - dominant_knee_accuracy: 0.8954 - dominant_knee_loss: 0.2689 - loss: 3.7348 - movement_score_loss: 3.2448 - movement_score_mae: 1.1514
# Epoch 299: val_loss did not improve from 3.64134
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 20s 35ms/step - dominant_elbow_accuracy: 0.9234 - dominant_elbow_loss: 0.2211 - dominant_knee_accuracy: 0.8954 - dominant_knee_loss: 0.2689 - loss: 3.7346 - movement_score_loss: 3.2447 - movement_score_mae: 1.1514 - val_dominant_elbow_accuracy: 0.9181 - val_dominant_elbow_loss: 0.2170 - val_dominant_knee_accuracy: 0.9031 - val_dominant_knee_loss: 0.2521 - val_loss: 3.6433 - val_movement_score_loss: 3.1739 - val_movement_score_mae: 1.0832 - learning_rate: 1.0000e-05
# Epoch 300/300
# 563/564 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - dominant_elbow_accuracy: 0.9277 - dominant_elbow_loss: 0.2077 - dominant_knee_accuracy: 0.8964 - dominant_knee_loss: 0.2656 - loss: 3.6362 - movement_score_loss: 3.1629 - movement_score_mae: 1.1278
# Epoch 300: val_loss did not improve from 3.64134
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 19s 33ms/step - dominant_elbow_accuracy: 0.9277 - dominant_elbow_loss: 0.2077 - dominant_knee_accuracy: 0.8964 - dominant_knee_loss: 0.2656 - loss: 3.6365 - movement_score_loss: 3.1632 - movement_score_mae: 1.1279 - val_dominant_elbow_accuracy: 0.9173 - val_dominant_elbow_loss: 0.2173 - val_dominant_knee_accuracy: 0.9022 - val_dominant_knee_loss: 0.2525 - val_loss: 3.6550 - val_movement_score_loss: 3.1850 - val_movement_score_mae: 1.0944 - learning_rate: 1.0000e-05
# 177/177 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step
#
# ===== תוצאות המודל =====
# RMSE for motion score: 1.7612
# דיוק סיווג ברך דומיננטית: 0.9051
# דיוק סיווג מרפק דומיננטי: 0.9269
#
# דוח סיווג - ברך דומיננטית:
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.10      0.18       577
#          1.0       0.91      1.00      0.95      5058
#
#     accuracy                           0.91      5635
#    macro avg       0.85      0.55      0.56      5635
# weighted avg       0.89      0.91      0.87      5635
#
#
# דוח סיווג - מרפק דומיננטי:
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.09      0.16       440
#          1.0       0.93      1.00      0.96      5195
#
#     accuracy                           0.93      5635
#    macro avg       0.85      0.54      0.56      5635
# weighted avg       0.92      0.93      0.90      5635
#
#
# מיפוי תוויות ברך:
# 0: left
# 1: right
#
# מיפוי תוויות מרפק:
# 0: left
# 1: right
# המודל נשמר בהצלחה כקובץ 'infant_movenet_movement_gru_model.keras'
#
# האימון הסתיים בהצלחה!
