# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import GRU, Dense, Input, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import mean_squared_error, accuracy_score, classification_report
import os
import glob

# %%
WINDOW_SIZE = 30  
RANDOM_STATE = 42
BATCH_SIZE = 32
EPOCHS = 100
LEARNING_RATE = 0.001

# %%
def load_and_preprocess_data(file_paths, window_size=WINDOW_SIZE):
    """
    טעינה ועיבוד מקדים של הנתונים מקבצי האקסל
    """
    all_data = []
    
    for file_path in file_paths:
        df = pd.read_csv(file_path) if file_path.endswith('.csv') else pd.read_excel(file_path)
        
        # בדיקה שקיימים העמודות הנדרשות
        required_columns = ['video_id', 'frame', 'window_id', 
                           'overall_movement_score', 'dominant_knee', 'dominant_elbow']
        
        if not all(col in df.columns for col in required_columns):
            print(f"קובץ {file_path} חסרות עמודות נדרשות. דילוג...")
            continue
        
        df = df[~df['video_id'].isin([43, 44])]
        all_data.append(df)
    
    if not all_data:
        raise ValueError("לא נמצאו קבצים תקינים לעיבוד")
    
    # איחוד כל הנתונים
    data = pd.concat(all_data, ignore_index=True)
    
    # המרת ערכים קטגוריאליים למספרים
    label_encoders = {}
    for col in ['dominant_knee', 'dominant_elbow']:
        if data[col].dtype == 'object':
            le = LabelEncoder()
            data[col] = le.fit_transform(data[col])
            label_encoders[col] = le
    
    return data, label_encoders

def prepare_sequences(data, window_size=WINDOW_SIZE):
    """
    הכנת רצפי נתונים עבור GRU לפי חלונות
    """
    feature_columns = [col for col in data.columns if any(x in col for x in 
                      ['_x', '_y', '_confidence'])]
    
    X = []
    y_movement = []
    y_knee = []
    y_elbow = []
    
    # קיבוץ לפי וידאו וחלון
    groups = data.groupby(['video_id', 'window_id'])
    
    for (vid_id, win_id), group in groups:
        if len(group) < window_size:
            # דילוג על חלונות קטנים מדי
            continue
        
        # לכל חלון, ניקח רצפים באורך window_size
        for i in range(0, len(group) - window_size + 1):
            sequence = group.iloc[i:i+window_size][feature_columns].values
            
            # המטרות הן הערכים בפריים האחרון ברצף
            target_frame = group.iloc[i+window_size-1]
            
            X.append(sequence)
            y_movement.append(target_frame['overall_movement_score'])
            y_knee.append(target_frame['dominant_knee'])
            y_elbow.append(target_frame['dominant_elbow'])
    
    X = np.array(X)
    y_movement = np.array(y_movement)
    y_knee = np.array(y_knee)
    y_elbow = np.array(y_elbow)
    
    return X, y_movement, y_knee, y_elbow, feature_columns

def build_gru_model(input_shape, num_knee_classes, num_elbow_classes):
    """
    בניית מודל GRU עם מספר שכבות והתאמה למשימות מרובות
    """
    # שכבת הקלט המשותפת
    inputs = Input(shape=input_shape)
    
    # שכבות GRU משותפות
    x = GRU(128, return_sequences=True)(inputs)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)
    
    x = GRU(64)(x)
    x = BatchNormalization()(x)
    shared_features = Dropout(0.3)(x)
    
    # ענף לציון תנועה כללי (רגרסיה)
    movement_output = Dense(32, activation='relu')(shared_features)
    movement_output = Dense(1, name='movement_score')(movement_output)
    
    # ענף לברך דומיננטית (סיווג)
    knee_output = Dense(32, activation='relu')(shared_features)
    knee_output = Dense(num_knee_classes, activation='softmax', name='dominant_knee')(knee_output)
    
    # ענף למרפק דומיננטי (סיווג)
    elbow_output = Dense(32, activation='relu')(shared_features)
    elbow_output = Dense(num_elbow_classes, activation='softmax', name='dominant_elbow')(elbow_output)
    
    # הגדרת המודל עם קלט ושלושה פלטים
    model = Model(inputs=inputs, outputs=[movement_output, knee_output, elbow_output])
    
    # הגדרת אופטימייזר ופונקציות שגיאה
    model.compile(
        optimizer=Adam(learning_rate=LEARNING_RATE),
        loss={
            'movement_score': 'mean_squared_error',
            'dominant_knee': 'sparse_categorical_crossentropy',
            'dominant_elbow': 'sparse_categorical_crossentropy'
        },
        metrics={
            'movement_score': ['mae'],
            'dominant_knee': ['accuracy'],
            'dominant_elbow': ['accuracy']
        }
    )
    
    return model

def train_model(X_train, y_train, X_val, y_val, input_shape, num_knee_classes, num_elbow_classes):
    
    model = build_gru_model(input_shape, num_knee_classes, num_elbow_classes)
    
    # הגדרת callbacks
    early_stopping = EarlyStopping(
        monitor='val_loss', 
        patience=15, 
        restore_best_weights=True
    )
    
    reduce_lr = ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        min_lr=0.00001
    )
    
    model_checkpoint = ModelCheckpoint(
        'best_infant_movement_model.keras',
        monitor='val_loss',
        save_best_only=True,
        verbose=1
    )
    
    # אימון המודל
    history = model.fit(
        X_train,
        y_train,
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=(X_val, y_val),
        callbacks=[early_stopping, reduce_lr, model_checkpoint],
        verbose=1
    )
    
    return model, history

def evaluate_model(model, X_test, y_test_movement, y_test_knee, y_test_elbow, label_encoders):
    """
    הערכת המודל והצגת מדדי ביצוע
    """
    # ביצוע חיזוי
    y_pred_movement, y_pred_knee_prob, y_pred_elbow_prob = model.predict(X_test)
    
    # המרת הסתברויות לתוויות
    y_pred_knee = np.argmax(y_pred_knee_prob, axis=1)
    y_pred_elbow = np.argmax(y_pred_elbow_prob, axis=1)
    
    # מדדי ביצוע לציון תנועה כללי
    mse_movement = mean_squared_error(y_test_movement, y_pred_movement)
    rmse_movement = np.sqrt(mse_movement) # ציון בין 0-10 שמודד עד כמה המודל שגה בחישוב ציון התנועה הכללי- כמה רחוק המודל היהי מהציון תנועה הכללי האמיתי שחושב
    
    # מדדי ביצוע לסיווג ברך ומרפק דומיננטיים
    knee_accuracy = accuracy_score(y_test_knee, y_pred_knee)
    elbow_accuracy = accuracy_score(y_test_elbow, y_pred_elbow)
    
    print("\n===== תוצאות המודל =====")
    print(f"RMSE לציון תנועה כללי: {rmse_movement:.4f}")
    print(f"דיוק סיווג ברך דומיננטית: {knee_accuracy:.4f}")
    print(f"דיוק סיווג מרפק דומיננטי: {elbow_accuracy:.4f}")
    
    print("\nדוח סיווג - ברך דומיננטית:")
    print(classification_report(y_test_knee, y_pred_knee))
    
    print("\nדוח סיווג - מרפק דומיננטי:")
    print(classification_report(y_test_elbow, y_pred_elbow))
    
    # פענוח התוויות חזרה לערכים המקוריים (אם נדרש)
    if 'dominant_knee' in label_encoders:
        original_knee_labels = label_encoders['dominant_knee'].inverse_transform(range(len(label_encoders['dominant_knee'].classes_)))
        print("\nמיפוי תוויות ברך:")
        for i, label in enumerate(original_knee_labels):
            print(f"{i}: {label}")
    
    if 'dominant_elbow' in label_encoders:
        original_elbow_labels = label_encoders['dominant_elbow'].inverse_transform(range(len(label_encoders['dominant_elbow'].classes_)))
        print("\nמיפוי תוויות מרפק:")
        for i, label in enumerate(original_elbow_labels):
            print(f"{i}: {label}")
    
    return {
        'rmse_movement': rmse_movement,
        'knee_accuracy': knee_accuracy,
        'elbow_accuracy': elbow_accuracy
    }

def plot_training_history(history):
    """
    יצירת גרפים להצגת התקדמות האימון
    """
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))
    
    # עקומות שגיאה
    axes[0, 0].plot(history.history['loss'], label='Train Loss')
    axes[0, 0].plot(history.history['val_loss'], label='Validation Loss')
    axes[0, 0].set_title('Total Loss')
    axes[0, 0].set_xlabel('Epochs')
    axes[0, 0].set_ylabel('Loss')
    axes[0, 0].legend()
    
    # דיוק ברך דומיננטית
    axes[0, 1].plot(history.history['dominant_knee_accuracy'], label='Train Accuracy')
    axes[0, 1].plot(history.history['val_dominant_knee_accuracy'], label='Validation Accuracy')
    axes[0, 1].set_title('Dominant Knee Accuracy')
    axes[0, 1].set_xlabel('Epochs')
    axes[0, 1].set_ylabel('Accuracy')
    axes[0, 1].legend()
    
    # דיוק מרפק דומיננטי
    axes[1, 0].plot(history.history['dominant_elbow_accuracy'], label='Train Accuracy')
    axes[1, 0].plot(history.history['val_dominant_elbow_accuracy'], label='Validation Accuracy')
    axes[1, 0].set_title('Dominant Elbow Accuracy')
    axes[1, 0].set_xlabel('Epochs')
    axes[1, 0].set_ylabel('Accuracy')
    axes[1, 0].legend()
    
    # שגיאה ממוצעת מוחלטת לציון תנועה
    axes[1, 1].plot(history.history['movement_score_mae'], label='Train MAE')
    axes[1, 1].plot(history.history['val_movement_score_mae'], label='Validation MAE')
    axes[1, 1].set_title('Movement Score MAE')
    axes[1, 1].set_xlabel('Epochs')
    axes[1, 1].set_ylabel('MAE')
    axes[1, 1].legend()
    
    plt.tight_layout()
    plt.savefig('training_history.png')
    plt.show()

# %%
def main():
    
    movenet_path = ['movenet_dataset.csv']
    
    print(f"file is being proccessed: {movenet_path[0]}")
    
    # טעינת הנתונים
    try:
        data, label_encoders = load_and_preprocess_data(movenet_path)
        print(f" {len(data)} Data rows have been loaded")
    except Exception as e:
        print(f"Error loading the data: {e}")
        return
    
    
    X, y_movement, y_knee, y_elbow, feature_columns = prepare_sequences(data)
    
    print(f"number of examples: {len(X)}")
    print(f"number of features: {X.shape[2]}")
    
    
    num_knee_classes = len(np.unique(y_knee))
    num_elbow_classes = len(np.unique(y_elbow))
    
    print(f"number of classes for dominant knee: {num_knee_classes}")
    print(f"number of classses for dominant elbow: {num_elbow_classes}")
    
    
    X_train_val, X_test, y_movement_train_val, y_movement_test, \
    y_knee_train_val, y_knee_test, y_elbow_train_val, y_elbow_test = train_test_split(
        X, y_movement, y_knee, y_elbow, test_size=0.2, random_state=RANDOM_STATE
    )
    
   
    X_train, X_val, y_movement_train, y_movement_val, \
    y_knee_train, y_knee_val, y_elbow_train, y_elbow_val = train_test_split(
        X_train_val, y_movement_train_val, y_knee_train_val, y_elbow_train_val, 
        test_size=0.2, random_state=RANDOM_STATE
    )
    
   
    
    
    input_shape = (X_train.shape[1], X_train.shape[2])
    
    
    y_train = [y_movement_train, y_knee_train, y_elbow_train]
    y_val = [y_movement_val, y_knee_val, y_elbow_val]
    
    # Model Training 
    model, history = train_model(
        X_train, y_train, X_val, y_val, 
        input_shape, num_knee_classes, num_elbow_classes
    )
    
    # Model Evaluation
    results = evaluate_model(
        model, X_test, y_movement_test, y_knee_test, y_elbow_test, label_encoders
    )
    
    
    plot_training_history(history)
    
    # Model Save
    model.save('infant_movement_gru_movenet_model.keras')
    print("'infant_movement_gru_movenet_model.keras'")
    
    
    with open('model_features.txt', 'w') as f:
        f.write('\n'.join(feature_columns))
    
    print("\nMovenet Training Ended")
    print("=" * 50)  


    yolo_path = ['yolo_dataset.csv']
    
    print(f"file is being proccessed: {yolo_path[0]}")
    
    # טעינת הנתונים
    try:
        data, label_encoders = load_and_preprocess_data(yolo_path)
        print(f" {len(data)} Data rows have been loaded")
    except Exception as e:
        print(f"Error loading the data: {e}")
        return
    
    
    X, y_movement, y_knee, y_elbow, feature_columns = prepare_sequences(data)
    
    print(f"number of examples: {len(X)}")
    print(f"number of features: {X.shape[2]}")
    
    
    num_knee_classes = len(np.unique(y_knee))
    num_elbow_classes = len(np.unique(y_elbow))
    
    print(f"number of classes for dominant knee: {num_knee_classes}")
    print(f"number of classses for dominant elbow: {num_elbow_classes}")
    
    
    X_train_val, X_test, y_movement_train_val, y_movement_test, \
    y_knee_train_val, y_knee_test, y_elbow_train_val, y_elbow_test = train_test_split(
        X, y_movement, y_knee, y_elbow, test_size=0.2, random_state=RANDOM_STATE
    )
    
   
    X_train, X_val, y_movement_train, y_movement_val, \
    y_knee_train, y_knee_val, y_elbow_train, y_elbow_val = train_test_split(
        X_train_val, y_movement_train_val, y_knee_train_val, y_elbow_train_val, 
        test_size=0.2, random_state=RANDOM_STATE
    )
    
   
    
    
    input_shape = (X_train.shape[1], X_train.shape[2])
    
    
    y_train = [y_movement_train, y_knee_train, y_elbow_train]
    y_val = [y_movement_val, y_knee_val, y_elbow_val]
    
    # Model Training 
    model, history = train_model(
        X_train, y_train, X_val, y_val, 
        input_shape, num_knee_classes, num_elbow_classes
    )
    
    # Model Evaluation
    results = evaluate_model(
        model, X_test, y_movement_test, y_knee_test, y_elbow_test, label_encoders
    )
    
    
    plot_training_history(history)
    
    # Model Save
    model.save('infant_movement_gru_yolo_model.keras')
    print("'infant_movement_gru_yolo_model.keras'")
    
    
    with open('model_features.txt', 'w') as f:
        f.write('\n'.join(feature_columns))
    
    print("\nYolo Training Ended")
    print("=" * 50)  



    mediapipe_path = ['mediapipe_dataset.csv']
    
    print(f"file is being proccessed: {mediapipe_path[0]}")
    
    
    try:
        data, label_encoders = load_and_preprocess_data(mediapipe_path)
        print(f" {len(data)} Data rows have been loaded")
    except Exception as e:
        print(f"Error loading the data: {e}")
        return
    
    
    X, y_movement, y_knee, y_elbow, feature_columns = prepare_sequences(data)
    
    print(f"number of examples: {len(X)}")
    print(f"number of features: {X.shape[2]}")
    
    
    num_knee_classes = len(np.unique(y_knee))
    num_elbow_classes = len(np.unique(y_elbow))
    
    print(f"number of classes for dominant knee: {num_knee_classes}")
    print(f"number of classses for dominant elbow: {num_elbow_classes}")
    
    
    X_train_val, X_test, y_movement_train_val, y_movement_test, \
    y_knee_train_val, y_knee_test, y_elbow_train_val, y_elbow_test = train_test_split(
        X, y_movement, y_knee, y_elbow, test_size=0.2, random_state=RANDOM_STATE
    )
    
   
    X_train, X_val, y_movement_train, y_movement_val, \
    y_knee_train, y_knee_val, y_elbow_train, y_elbow_val = train_test_split(
        X_train_val, y_movement_train_val, y_knee_train_val, y_elbow_train_val, 
        test_size=0.2, random_state=RANDOM_STATE
    )
    
   
    
    
    input_shape = (X_train.shape[1], X_train.shape[2])
    
    
    y_train = [y_movement_train, y_knee_train, y_elbow_train]
    y_val = [y_movement_val, y_knee_val, y_elbow_val]
    
    # Model Training 
    model, history = train_model(
        X_train, y_train, X_val, y_val, 
        input_shape, num_knee_classes, num_elbow_classes
    )
    
    # Model Evaluation
    results = evaluate_model(
        model, X_test, y_movement_test, y_knee_test, y_elbow_test, label_encoders
    )
    
    
    plot_training_history(history)
    
    # Model Save
    model.save('infant_movement_gru_mediapipe_model.keras')
    print("'infant_movement_gru_mediapipe_model.keras'")
    
    
    with open('model_features.txt', 'w') as f:
        f.write('\n'.join(feature_columns))
    
    print("\nMediapipe Training Ended")
    print("=" * 50)  


if __name__ == "__main__":
    main()
# Out:
# file is being proccessed: movenet_dataset.csv
#  57945 Data rows have been loaded
# number of examples: 29610
# number of features: 40
# number of classes for dominant knee: 2
# number of classses for dominant elbow: 2
# Epoch 1/100
# 592/593 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - dominant_elbow_accuracy: 0.8553 - dominant_elbow_loss: 0.3926 - dominant_knee_accuracy: 0.8397 - dominant_knee_loss: 0.4396 - loss: 20.4444 - movement_score_loss: 19.6121 - movement_score_mae: 3.5979
# Epoch 1: val_loss improved from inf to 8.07203, saving model to best_infant_movement_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 22s 29ms/step - dominant_elbow_accuracy: 0.8555 - dominant_elbow_loss: 0.3924 - dominant_knee_accuracy: 0.8398 - dominant_knee_loss: 0.4394 - loss: 20.4177 - movement_score_loss: 19.5859 - movement_score_mae: 3.5954 - val_dominant_elbow_accuracy: 0.9240 - val_dominant_elbow_loss: 0.2681 - val_dominant_knee_accuracy: 0.8926 - val_dominant_knee_loss: 0.3478 - val_loss: 8.0720 - val_movement_score_loss: 7.4253 - val_movement_score_mae: 2.4517 - learning_rate: 0.0010
# Epoch 2/100
# 591/593 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - dominant_elbow_accuracy: 0.9204 - dominant_elbow_loss: 0.2889 - dominant_knee_accuracy: 0.8998 - dominant_knee_loss: 0.3316 - loss: 9.2838 - movement_score_loss: 8.6633 - movement_score_mae: 2.5800
# Epoch 2: val_loss did not improve from 8.07203
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 17s 28ms/step - dominant_elbow_accuracy: 0.9204 - dominant_elbow_loss: 0.2889 - dominant_knee_accuracy: 0.8998 - dominant_knee_loss: 0.3316 - loss: 9.2836 - movement_score_loss: 8.6631 - movement_score_mae: 2.5800 - val_dominant_elbow_accuracy: 0.9240 - val_dominant_elbow_loss: 0.2768 - val_dominant_knee_accuracy: 0.8926 - val_dominant_knee_loss: 0.3410 - val_loss: 8.5529 - val_movement_score_loss: 7.9096 - val_movement_score_mae: 2.5743 - learning_rate: 0.0010
# Epoch 3/100
# 591/593 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - dominant_elbow_accuracy: 0.9182 - dominant_elbow_loss: 0.2902 - dominant_knee_accuracy: 0.8970 - dominant_knee_loss: 0.3368 - loss: 9.1536 - movement_score_loss: 8.5266 - movement_score_mae: 2.5912
# Epoch 3: val_loss did not improve from 8.07203
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 17s 28ms/step - dominant_elbow_accuracy: 0.9183 - dominant_elbow_loss: 0.2901 - dominant_knee_accuracy: 0.8970 - dominant_knee_loss: 0.3368 - loss: 9.1532 - movement_score_loss: 8.5263 - movement_score_mae: 2.5912 - val_dominant_elbow_accuracy: 0.9240 - val_dominant_elbow_loss: 0.2776 - val_dominant_knee_accuracy: 0.8926 - val_dominant_knee_loss: 0.3505 - val_loss: 8.9855 - val_movement_score_loss: 8.3584 - val_movement_score_mae: 2.6164 - learning_rate: 0.0010
# Epoch 4/100
# 591/593 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - dominant_elbow_accuracy: 0.9201 - dominant_elbow_loss: 0.2817 - dominant_knee_accuracy: 0.8985 - dominant_knee_loss: 0.3310 - loss: 8.8035 - movement_score_loss: 8.1907 - movement_score_mae: 2.5703
# Epoch 4: val_loss improved from 8.07203 to 7.94993, saving model to best_infant_movement_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - dominant_elbow_accuracy: 0.9201 - dominant_elbow_loss: 0.2817 - dominant_knee_accuracy: 0.8985 - dominant_knee_loss: 0.3310 - loss: 8.8037 - movement_score_loss: 8.1909 - movement_score_mae: 2.5703 - val_dominant_elbow_accuracy: 0.9240 - val_dominant_elbow_loss: 0.2577 - val_dominant_knee_accuracy: 0.8926 - val_dominant_knee_loss: 0.3450 - val_loss: 7.9499 - val_movement_score_loss: 7.3475 - val_movement_score_mae: 2.4804 - learning_rate: 0.0010
# Epoch 5/100
# 592/593 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - dominant_elbow_accuracy: 0.9177 - dominant_elbow_loss: 0.2831 - dominant_knee_accuracy: 0.8982 - dominant_knee_loss: 0.3268 - loss: 8.4240 - movement_score_loss: 7.8142 - movement_score_mae: 2.4859
# Epoch 5: val_loss did not improve from 7.94993
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 13s 22ms/step - dominant_elbow_accuracy: 0.9177 - dominant_elbow_loss: 0.2831 - dominant_knee_accuracy: 0.8982 - dominant_knee_loss: 0.3268 - loss: 8.4240 - movement_score_loss: 7.8143 - movement_score_mae: 2.4859 - val_dominant_elbow_accuracy: 0.9240 - val_dominant_elbow_loss: 0.2640 - val_dominant_knee_accuracy: 0.8926 - val_dominant_knee_loss: 0.3402 - val_loss: 7.9909 - val_movement_score_loss: 7.4180 - val_movement_score_mae: 2.3825 - learning_rate: 0.0010
# Epoch 6/100
# 592/593 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - dominant_elbow_accuracy: 0.9153 - dominant_elbow_loss: 0.2848 - dominant_knee_accuracy: 0.9024 - dominant_knee_loss: 0.3153 - loss: 8.1688 - movement_score_loss: 7.5687 - movement_score_mae: 2.4192
# Epoch 6: val_loss improved from 7.94993 to 7.70704, saving model to best_infant_movement_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 14s 23ms/step - dominant_elbow_accuracy: 0.9153 - dominant_elbow_loss: 0.2848 - dominant_knee_accuracy: 0.9024 - dominant_knee_loss: 0.3153 - loss: 8.1687 - movement_score_loss: 7.5686 - movement_score_mae: 2.4192 - val_dominant_elbow_accuracy: 0.9240 - val_dominant_elbow_loss: 0.2653 - val_dominant_knee_accuracy: 0.8926 - val_dominant_knee_loss: 0.3325 - val_loss: 7.7070 - val_movement_score_loss: 7.0748 - val_movement_score_mae: 2.3369 - learning_rate: 0.0010
# Epoch 7/100
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - dominant_elbow_accuracy: 0.9204 - dominant_elbow_loss: 0.2697 - dominant_knee_accuracy: 0.8987 - dominant_knee_loss: 0.3220 - loss: 7.8710 - movement_score_loss: 7.2793 - movement_score_mae: 2.3709
# Epoch 7: val_loss improved from 7.70704 to 7.39877, saving model to best_infant_movement_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 14s 23ms/step - dominant_elbow_accuracy: 0.9204 - dominant_elbow_loss: 0.2697 - dominant_knee_accuracy: 0.8987 - dominant_knee_loss: 0.3220 - loss: 7.8711 - movement_score_loss: 7.2794 - movement_score_mae: 2.3710 - val_dominant_elbow_accuracy: 0.9240 - val_dominant_elbow_loss: 0.2615 - val_dominant_knee_accuracy: 0.8926 - val_dominant_knee_loss: 0.3350 - val_loss: 7.3988 - val_movement_score_loss: 6.7840 - val_movement_score_mae: 2.2585 - learning_rate: 0.0010
# Epoch 8/100
# 592/593 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - dominant_elbow_accuracy: 0.9225 - dominant_elbow_loss: 0.2699 - dominant_knee_accuracy: 0.8934 - dominant_knee_loss: 0.3353 - loss: 7.8296 - movement_score_loss: 7.2244 - movement_score_mae: 2.3501
# Epoch 8: val_loss improved from 7.39877 to 7.15836, saving model to best_infant_movement_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 14s 23ms/step - dominant_elbow_accuracy: 0.9225 - dominant_elbow_loss: 0.2699 - dominant_knee_accuracy: 0.8934 - dominant_knee_loss: 0.3353 - loss: 7.8293 - movement_score_loss: 7.2241 - movement_score_mae: 2.3500 - val_dominant_elbow_accuracy: 0.9240 - val_dominant_elbow_loss: 0.2593 - val_dominant_knee_accuracy: 0.8926 - val_dominant_knee_loss: 0.3367 - val_loss: 7.1584 - val_movement_score_loss: 6.5734 - val_movement_score_mae: 2.2553 - learning_rate: 0.0010
# Epoch 9/100
# 592/593 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - dominant_elbow_accuracy: 0.9146 - dominant_elbow_loss: 0.2832 - dominant_knee_accuracy: 0.8965 - dominant_knee_loss: 0.3272 - loss: 7.7217 - movement_score_loss: 7.1113 - movement_score_mae: 2.3345
# Epoch 9: val_loss did not improve from 7.15836
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 14s 23ms/step - dominant_elbow_accuracy: 0.9146 - dominant_elbow_loss: 0.2832 - dominant_knee_accuracy: 0.8965 - dominant_knee_loss: 0.3272 - loss: 7.7217 - movement_score_loss: 7.1114 - movement_score_mae: 2.3346 - val_dominant_elbow_accuracy: 0.9240 - val_dominant_elbow_loss: 0.2492 - val_dominant_knee_accuracy: 0.8926 - val_dominant_knee_loss: 0.3359 - val_loss: 7.3787 - val_movement_score_loss: 6.7709 - val_movement_score_mae: 2.2269 - learning_rate: 0.0010
# Epoch 10/100
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - dominant_elbow_accuracy: 0.9219 - dominant_elbow_loss: 0.2631 - dominant_knee_accuracy: 0.8987 - dominant_knee_loss: 0.3181 - loss: 7.3806 - movement_score_loss: 6.7994 - movement_score_mae: 2.2426
# Epoch 10: val_loss did not improve from 7.15836
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 15s 25ms/step - dominant_elbow_accuracy: 0.9219 - dominant_elbow_loss: 0.2631 - dominant_knee_accuracy: 0.8987 - dominant_knee_loss: 0.3181 - loss: 7.3805 - movement_score_loss: 6.7993 - movement_score_mae: 2.2426 - val_dominant_elbow_accuracy: 0.9240 - val_dominant_elbow_loss: 0.2710 - val_dominant_knee_accuracy: 0.8926 - val_dominant_knee_loss: 0.3407 - val_loss: 8.6473 - val_movement_score_loss: 8.1044 - val_movement_score_mae: 2.3049 - learning_rate: 0.0010
# Epoch 11/100
# 592/593 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - dominant_elbow_accuracy: 0.9199 - dominant_elbow_loss: 0.2665 - dominant_knee_accuracy: 0.8986 - dominant_knee_loss: 0.3186 - loss: 7.1641 - movement_score_loss: 6.5790 - movement_score_mae: 2.1951
# Epoch 11: val_loss did not improve from 7.15836
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 16s 27ms/step - dominant_elbow_accuracy: 0.9199 - dominant_elbow_loss: 0.2665 - dominant_knee_accuracy: 0.8985 - dominant_knee_loss: 0.3186 - loss: 7.1642 - movement_score_loss: 6.5791 - movement_score_mae: 2.1951 - val_dominant_elbow_accuracy: 0.9240 - val_dominant_elbow_loss: 0.2703 - val_dominant_knee_accuracy: 0.8926 - val_dominant_knee_loss: 0.3363 - val_loss: 8.3608 - val_movement_score_loss: 7.7185 - val_movement_score_mae: 2.3922 - learning_rate: 0.0010
# Epoch 12/100
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - dominant_elbow_accuracy: 0.9206 - dominant_elbow_loss: 0.2621 - dominant_knee_accuracy: 0.8972 - dominant_knee_loss: 0.3206 - loss: 7.0672 - movement_score_loss: 6.4845 - movement_score_mae: 2.1815
# Epoch 12: val_loss did not improve from 7.15836
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - dominant_elbow_accuracy: 0.9206 - dominant_elbow_loss: 0.2621 - dominant_knee_accuracy: 0.8972 - dominant_knee_loss: 0.3206 - loss: 7.0671 - movement_score_loss: 6.4844 - movement_score_mae: 2.1814 - val_dominant_elbow_accuracy: 0.9240 - val_dominant_elbow_loss: 0.2604 - val_dominant_knee_accuracy: 0.8926 - val_dominant_knee_loss: 0.3335 - val_loss: 7.2756 - val_movement_score_loss: 6.7016 - val_movement_score_mae: 2.2325 - learning_rate: 0.0010
# Epoch 13/100
# 592/593 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - dominant_elbow_accuracy: 0.9181 - dominant_elbow_loss: 0.2651 - dominant_knee_accuracy: 0.8984 - dominant_knee_loss: 0.3148 - loss: 6.8038 - movement_score_loss: 6.2239 - movement_score_mae: 2.1129
# Epoch 13: val_loss improved from 7.15836 to 6.49157, saving model to best_infant_movement_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 14s 24ms/step - dominant_elbow_accuracy: 0.9181 - dominant_elbow_loss: 0.2651 - dominant_knee_accuracy: 0.8984 - dominant_knee_loss: 0.3148 - loss: 6.8038 - movement_score_loss: 6.2239 - movement_score_mae: 2.1129 - val_dominant_elbow_accuracy: 0.9240 - val_dominant_elbow_loss: 0.2436 - val_dominant_knee_accuracy: 0.8926 - val_dominant_knee_loss: 0.3269 - val_loss: 6.4916 - val_movement_score_loss: 5.9348 - val_movement_score_mae: 1.9350 - learning_rate: 0.0010
# Epoch 14/100
# 591/593 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - dominant_elbow_accuracy: 0.9192 - dominant_elbow_loss: 0.2633 - dominant_knee_accuracy: 0.8966 - dominant_knee_loss: 0.3207 - loss: 6.7234 - movement_score_loss: 6.1395 - movement_score_mae: 2.0759
# Epoch 14: val_loss did not improve from 6.49157
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 15s 26ms/step - dominant_elbow_accuracy: 0.9192 - dominant_elbow_loss: 0.2633 - dominant_knee_accuracy: 0.8966 - dominant_knee_loss: 0.3207 - loss: 6.7235 - movement_score_loss: 6.1396 - movement_score_mae: 2.0759 - val_dominant_elbow_accuracy: 0.9240 - val_dominant_elbow_loss: 0.2608 - val_dominant_knee_accuracy: 0.8926 - val_dominant_knee_loss: 0.3378 - val_loss: 8.5981 - val_movement_score_loss: 7.9819 - val_movement_score_mae: 2.2825 - learning_rate: 0.0010
# Epoch 15/100
# 592/593 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - dominant_elbow_accuracy: 0.9186 - dominant_elbow_loss: 0.2642 - dominant_knee_accuracy: 0.8989 - dominant_knee_loss: 0.3136 - loss: 6.7965 - movement_score_loss: 6.2186 - movement_score_mae: 2.0938
# Epoch 15: val_loss did not improve from 6.49157
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 15s 25ms/step - dominant_elbow_accuracy: 0.9186 - dominant_elbow_loss: 0.2642 - dominant_knee_accuracy: 0.8989 - dominant_knee_loss: 0.3136 - loss: 6.7965 - movement_score_loss: 6.2187 - movement_score_mae: 2.0938 - val_dominant_elbow_accuracy: 0.9240 - val_dominant_elbow_loss: 0.2629 - val_dominant_knee_accuracy: 0.8926 - val_dominant_knee_loss: 0.3391 - val_loss: 7.4622 - val_movement_score_loss: 6.8868 - val_movement_score_mae: 2.1646 - learning_rate: 0.0010
# Epoch 16/100
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - dominant_elbow_accuracy: 0.9196 - dominant_elbow_loss: 0.2637 - dominant_knee_accuracy: 0.9003 - dominant_knee_loss: 0.3073 - loss: 6.6667 - movement_score_loss: 6.0957 - movement_score_mae: 2.0722
# Epoch 16: val_loss did not improve from 6.49157
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 16s 26ms/step - dominant_elbow_accuracy: 0.9196 - dominant_elbow_loss: 0.2637 - dominant_knee_accuracy: 0.9003 - dominant_knee_loss: 0.3073 - loss: 6.6667 - movement_score_loss: 6.0957 - movement_score_mae: 2.0722 - val_dominant_elbow_accuracy: 0.9240 - val_dominant_elbow_loss: 0.2527 - val_dominant_knee_accuracy: 0.8926 - val_dominant_knee_loss: 0.3332 - val_loss: 8.0299 - val_movement_score_loss: 7.4170 - val_movement_score_mae: 2.3410 - learning_rate: 0.0010
# Epoch 17/100
# 592/593 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - dominant_elbow_accuracy: 0.9198 - dominant_elbow_loss: 0.2654 - dominant_knee_accuracy: 0.9040 - dominant_knee_loss: 0.2990 - loss: 6.8674 - movement_score_loss: 6.3030 - movement_score_mae: 2.1367
# Epoch 17: val_loss did not improve from 6.49157
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 16s 26ms/step - dominant_elbow_accuracy: 0.9198 - dominant_elbow_loss: 0.2654 - dominant_knee_accuracy: 0.9040 - dominant_knee_loss: 0.2991 - loss: 6.8669 - movement_score_loss: 6.3024 - movement_score_mae: 2.1365 - val_dominant_elbow_accuracy: 0.9240 - val_dominant_elbow_loss: 0.2645 - val_dominant_knee_accuracy: 0.8926 - val_dominant_knee_loss: 0.3282 - val_loss: 7.8037 - val_movement_score_loss: 7.2148 - val_movement_score_mae: 2.2405 - learning_rate: 0.0010
# Epoch 18/100
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - dominant_elbow_accuracy: 0.9193 - dominant_elbow_loss: 0.2613 - dominant_knee_accuracy: 0.9011 - dominant_knee_loss: 0.3062 - loss: 6.5873 - movement_score_loss: 6.0199 - movement_score_mae: 2.0524
# Epoch 18: val_loss improved from 6.49157 to 6.04661, saving model to best_infant_movement_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - dominant_elbow_accuracy: 0.9193 - dominant_elbow_loss: 0.2612 - dominant_knee_accuracy: 0.9011 - dominant_knee_loss: 0.3062 - loss: 6.5872 - movement_score_loss: 6.0198 - movement_score_mae: 2.0524 - val_dominant_elbow_accuracy: 0.9244 - val_dominant_elbow_loss: 0.2432 - val_dominant_knee_accuracy: 0.8926 - val_dominant_knee_loss: 0.3203 - val_loss: 6.0466 - val_movement_score_loss: 5.4646 - val_movement_score_mae: 1.9487 - learning_rate: 0.0010
# Epoch 19/100
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - dominant_elbow_accuracy: 0.9184 - dominant_elbow_loss: 0.2609 - dominant_knee_accuracy: 0.8984 - dominant_knee_loss: 0.3083 - loss: 6.3375 - movement_score_loss: 5.7684 - movement_score_mae: 1.9781
# Epoch 19: val_loss improved from 6.04661 to 6.00145, saving model to best_infant_movement_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 15s 26ms/step - dominant_elbow_accuracy: 0.9184 - dominant_elbow_loss: 0.2609 - dominant_knee_accuracy: 0.8984 - dominant_knee_loss: 0.3083 - loss: 6.3376 - movement_score_loss: 5.7684 - movement_score_mae: 1.9781 - val_dominant_elbow_accuracy: 0.9230 - val_dominant_elbow_loss: 0.2451 - val_dominant_knee_accuracy: 0.8926 - val_dominant_knee_loss: 0.3202 - val_loss: 6.0014 - val_movement_score_loss: 5.4119 - val_movement_score_mae: 1.8779 - learning_rate: 0.0010
# Epoch 20/100
# 591/593 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - dominant_elbow_accuracy: 0.9212 - dominant_elbow_loss: 0.2544 - dominant_knee_accuracy: 0.8995 - dominant_knee_loss: 0.3067 - loss: 6.2401 - movement_score_loss: 5.6789 - movement_score_mae: 1.9595
# Epoch 20: val_loss did not improve from 6.00145
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 15s 26ms/step - dominant_elbow_accuracy: 0.9211 - dominant_elbow_loss: 0.2544 - dominant_knee_accuracy: 0.8995 - dominant_knee_loss: 0.3067 - loss: 6.2400 - movement_score_loss: 5.6788 - movement_score_mae: 1.9594 - val_dominant_elbow_accuracy: 0.9240 - val_dominant_elbow_loss: 0.2500 - val_dominant_knee_accuracy: 0.8926 - val_dominant_knee_loss: 0.3208 - val_loss: 6.2986 - val_movement_score_loss: 5.7235 - val_movement_score_mae: 1.9980 - learning_rate: 0.0010
# Epoch 21/100
# 591/593 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - dominant_elbow_accuracy: 0.9186 - dominant_elbow_loss: 0.2602 - dominant_knee_accuracy: 0.8986 - dominant_knee_loss: 0.3065 - loss: 6.2751 - movement_score_loss: 5.7084 - movement_score_mae: 1.9611
# Epoch 21: val_loss did not improve from 6.00145
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 15s 25ms/step - dominant_elbow_accuracy: 0.9186 - dominant_elbow_loss: 0.2602 - dominant_knee_accuracy: 0.8986 - dominant_knee_loss: 0.3065 - loss: 6.2754 - movement_score_loss: 5.7087 - movement_score_mae: 1.9612 - val_dominant_elbow_accuracy: 0.9240 - val_dominant_elbow_loss: 0.2617 - val_dominant_knee_accuracy: 0.8934 - val_dominant_knee_loss: 0.3207 - val_loss: 7.0056 - val_movement_score_loss: 6.3927 - val_movement_score_mae: 2.0912 - learning_rate: 0.0010
# Epoch 22/100
# 592/593 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - dominant_elbow_accuracy: 0.9221 - dominant_elbow_loss: 0.2488 - dominant_knee_accuracy: 0.8966 - dominant_knee_loss: 0.3077 - loss: 6.2535 - movement_score_loss: 5.6970 - movement_score_mae: 1.9490
# Epoch 22: val_loss improved from 6.00145 to 5.80973, saving model to best_infant_movement_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 17s 28ms/step - dominant_elbow_accuracy: 0.9221 - dominant_elbow_loss: 0.2488 - dominant_knee_accuracy: 0.8967 - dominant_knee_loss: 0.3077 - loss: 6.2534 - movement_score_loss: 5.6969 - movement_score_mae: 1.9490 - val_dominant_elbow_accuracy: 0.9251 - val_dominant_elbow_loss: 0.2419 - val_dominant_knee_accuracy: 0.8928 - val_dominant_knee_loss: 0.3094 - val_loss: 5.8097 - val_movement_score_loss: 5.2361 - val_movement_score_mae: 1.7164 - learning_rate: 0.0010
# Epoch 23/100
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - dominant_elbow_accuracy: 0.9211 - dominant_elbow_loss: 0.2509 - dominant_knee_accuracy: 0.8976 - dominant_knee_loss: 0.3084 - loss: 6.1825 - movement_score_loss: 5.6232 - movement_score_mae: 1.9299
# Epoch 23: val_loss did not improve from 5.80973
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 19s 31ms/step - dominant_elbow_accuracy: 0.9211 - dominant_elbow_loss: 0.2509 - dominant_knee_accuracy: 0.8976 - dominant_knee_loss: 0.3084 - loss: 6.1826 - movement_score_loss: 5.6233 - movement_score_mae: 1.9300 - val_dominant_elbow_accuracy: 0.9266 - val_dominant_elbow_loss: 0.2516 - val_dominant_knee_accuracy: 0.8932 - val_dominant_knee_loss: 0.3303 - val_loss: 6.6015 - val_movement_score_loss: 6.0471 - val_movement_score_mae: 1.9346 - learning_rate: 0.0010
# Epoch 24/100
# 591/593 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - dominant_elbow_accuracy: 0.9177 - dominant_elbow_loss: 0.2579 - dominant_knee_accuracy: 0.8982 - dominant_knee_loss: 0.3082 - loss: 6.1581 - movement_score_loss: 5.5920 - movement_score_mae: 1.9183
# Epoch 24: val_loss did not improve from 5.80973
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 19s 31ms/step - dominant_elbow_accuracy: 0.9177 - dominant_elbow_loss: 0.2579 - dominant_knee_accuracy: 0.8982 - dominant_knee_loss: 0.3082 - loss: 6.1578 - movement_score_loss: 5.5917 - movement_score_mae: 1.9183 - val_dominant_elbow_accuracy: 0.9255 - val_dominant_elbow_loss: 0.2384 - val_dominant_knee_accuracy: 0.8928 - val_dominant_knee_loss: 0.3181 - val_loss: 6.4659 - val_movement_score_loss: 5.8785 - val_movement_score_mae: 1.8985 - learning_rate: 0.0010
# Epoch 25/100
# 592/593 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - dominant_elbow_accuracy: 0.9166 - dominant_elbow_loss: 0.2623 - dominant_knee_accuracy: 0.9000 - dominant_knee_loss: 0.3030 - loss: 6.2789 - movement_score_loss: 5.7136 - movement_score_mae: 1.9638
# Epoch 25: val_loss did not improve from 5.80973
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - dominant_elbow_accuracy: 0.9166 - dominant_elbow_loss: 0.2623 - dominant_knee_accuracy: 0.9000 - dominant_knee_loss: 0.3030 - loss: 6.2783 - movement_score_loss: 5.7130 - movement_score_mae: 1.9636 - val_dominant_elbow_accuracy: 0.9249 - val_dominant_elbow_loss: 0.2464 - val_dominant_knee_accuracy: 0.8928 - val_dominant_knee_loss: 0.3183 - val_loss: 7.2176 - val_movement_score_loss: 6.6181 - val_movement_score_mae: 2.0860 - learning_rate: 0.0010
# Epoch 26/100
# 592/593 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - dominant_elbow_accuracy: 0.9211 - dominant_elbow_loss: 0.2493 - dominant_knee_accuracy: 0.8998 - dominant_knee_loss: 0.3008 - loss: 5.9684 - movement_score_loss: 5.4184 - movement_score_mae: 1.8746
# Epoch 26: val_loss improved from 5.80973 to 5.65967, saving model to best_infant_movement_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 18s 31ms/step - dominant_elbow_accuracy: 0.9211 - dominant_elbow_loss: 0.2493 - dominant_knee_accuracy: 0.8998 - dominant_knee_loss: 0.3008 - loss: 5.9684 - movement_score_loss: 5.4184 - movement_score_mae: 1.8746 - val_dominant_elbow_accuracy: 0.9251 - val_dominant_elbow_loss: 0.2375 - val_dominant_knee_accuracy: 0.8928 - val_dominant_knee_loss: 0.3107 - val_loss: 5.6597 - val_movement_score_loss: 5.0879 - val_movement_score_mae: 1.8190 - learning_rate: 0.0010
# Epoch 27/100
# 592/593 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - dominant_elbow_accuracy: 0.9208 - dominant_elbow_loss: 0.2509 - dominant_knee_accuracy: 0.8964 - dominant_knee_loss: 0.3068 - loss: 5.9325 - movement_score_loss: 5.3747 - movement_score_mae: 1.8581
# Epoch 27: val_loss did not improve from 5.65967
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 18s 31ms/step - dominant_elbow_accuracy: 0.9208 - dominant_elbow_loss: 0.2509 - dominant_knee_accuracy: 0.8964 - dominant_knee_loss: 0.3068 - loss: 5.9326 - movement_score_loss: 5.3748 - movement_score_mae: 1.8581 - val_dominant_elbow_accuracy: 0.9253 - val_dominant_elbow_loss: 0.2549 - val_dominant_knee_accuracy: 0.8926 - val_dominant_knee_loss: 0.3252 - val_loss: 7.4496 - val_movement_score_loss: 6.8979 - val_movement_score_mae: 2.0720 - learning_rate: 0.0010
# Epoch 28/100
# 592/593 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - dominant_elbow_accuracy: 0.9233 - dominant_elbow_loss: 0.2471 - dominant_knee_accuracy: 0.8996 - dominant_knee_loss: 0.3000 - loss: 6.0061 - movement_score_loss: 5.4590 - movement_score_mae: 1.8890
# Epoch 28: val_loss did not improve from 5.65967
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 19s 32ms/step - dominant_elbow_accuracy: 0.9233 - dominant_elbow_loss: 0.2471 - dominant_knee_accuracy: 0.8996 - dominant_knee_loss: 0.3000 - loss: 6.0067 - movement_score_loss: 5.4596 - movement_score_mae: 1.8891 - val_dominant_elbow_accuracy: 0.9249 - val_dominant_elbow_loss: 0.2362 - val_dominant_knee_accuracy: 0.8921 - val_dominant_knee_loss: 0.3193 - val_loss: 6.1426 - val_movement_score_loss: 5.5652 - val_movement_score_mae: 1.8282 - learning_rate: 0.0010
# Epoch 29/100
# 591/593 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - dominant_elbow_accuracy: 0.9208 - dominant_elbow_loss: 0.2467 - dominant_knee_accuracy: 0.8992 - dominant_knee_loss: 0.3052 - loss: 6.1089 - movement_score_loss: 5.5569 - movement_score_mae: 1.9110
# Epoch 29: val_loss did not improve from 5.65967
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 19s 32ms/step - dominant_elbow_accuracy: 0.9208 - dominant_elbow_loss: 0.2467 - dominant_knee_accuracy: 0.8992 - dominant_knee_loss: 0.3053 - loss: 6.1091 - movement_score_loss: 5.5571 - movement_score_mae: 1.9110 - val_dominant_elbow_accuracy: 0.9255 - val_dominant_elbow_loss: 0.2413 - val_dominant_knee_accuracy: 0.8926 - val_dominant_knee_loss: 0.3287 - val_loss: 6.5727 - val_movement_score_loss: 5.9916 - val_movement_score_mae: 1.9588 - learning_rate: 0.0010
# Epoch 30/100
# 591/593 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - dominant_elbow_accuracy: 0.9227 - dominant_elbow_loss: 0.2465 - dominant_knee_accuracy: 0.8965 - dominant_knee_loss: 0.3102 - loss: 5.9854 - movement_score_loss: 5.4288 - movement_score_mae: 1.8778
# Epoch 30: val_loss did not improve from 5.65967
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - dominant_elbow_accuracy: 0.9227 - dominant_elbow_loss: 0.2465 - dominant_knee_accuracy: 0.8965 - dominant_knee_loss: 0.3101 - loss: 5.9858 - movement_score_loss: 5.4292 - movement_score_mae: 1.8779 - val_dominant_elbow_accuracy: 0.9266 - val_dominant_elbow_loss: 0.2388 - val_dominant_knee_accuracy: 0.8926 - val_dominant_knee_loss: 0.3198 - val_loss: 6.1897 - val_movement_score_loss: 5.6085 - val_movement_score_mae: 1.8733 - learning_rate: 0.0010
# Epoch 31/100
# 592/593 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - dominant_elbow_accuracy: 0.9209 - dominant_elbow_loss: 0.2505 - dominant_knee_accuracy: 0.8994 - dominant_knee_loss: 0.3040 - loss: 6.0755 - movement_score_loss: 5.5210 - movement_score_mae: 1.9067
# Epoch 31: val_loss did not improve from 5.65967
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 19s 31ms/step - dominant_elbow_accuracy: 0.9209 - dominant_elbow_loss: 0.2504 - dominant_knee_accuracy: 0.8994 - dominant_knee_loss: 0.3040 - loss: 6.0754 - movement_score_loss: 5.5209 - movement_score_mae: 1.9066 - val_dominant_elbow_accuracy: 0.9266 - val_dominant_elbow_loss: 0.2420 - val_dominant_knee_accuracy: 0.8911 - val_dominant_knee_loss: 0.3234 - val_loss: 7.0029 - val_movement_score_loss: 6.4250 - val_movement_score_mae: 1.9486 - learning_rate: 0.0010
# Epoch 32/100
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - dominant_elbow_accuracy: 0.9197 - dominant_elbow_loss: 0.2492 - dominant_knee_accuracy: 0.8994 - dominant_knee_loss: 0.3015 - loss: 5.7878 - movement_score_loss: 5.2371 - movement_score_mae: 1.8257
# Epoch 32: val_loss improved from 5.65967 to 5.19291, saving model to best_infant_movement_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 16s 27ms/step - dominant_elbow_accuracy: 0.9197 - dominant_elbow_loss: 0.2492 - dominant_knee_accuracy: 0.8994 - dominant_knee_loss: 0.3015 - loss: 5.7875 - movement_score_loss: 5.2368 - movement_score_mae: 1.8256 - val_dominant_elbow_accuracy: 0.9263 - val_dominant_elbow_loss: 0.2297 - val_dominant_knee_accuracy: 0.8907 - val_dominant_knee_loss: 0.3100 - val_loss: 5.1929 - val_movement_score_loss: 4.6410 - val_movement_score_mae: 1.5968 - learning_rate: 5.0000e-04
# Epoch 33/100
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - dominant_elbow_accuracy: 0.9202 - dominant_elbow_loss: 0.2443 - dominant_knee_accuracy: 0.8923 - dominant_knee_loss: 0.3099 - loss: 5.2935 - movement_score_loss: 4.7393 - movement_score_mae: 1.6812
# Epoch 33: val_loss improved from 5.19291 to 4.88619, saving model to best_infant_movement_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 14s 24ms/step - dominant_elbow_accuracy: 0.9202 - dominant_elbow_loss: 0.2443 - dominant_knee_accuracy: 0.8924 - dominant_knee_loss: 0.3099 - loss: 5.2935 - movement_score_loss: 4.7392 - movement_score_mae: 1.6812 - val_dominant_elbow_accuracy: 0.9285 - val_dominant_elbow_loss: 0.2210 - val_dominant_knee_accuracy: 0.8917 - val_dominant_knee_loss: 0.3079 - val_loss: 4.8862 - val_movement_score_loss: 4.3391 - val_movement_score_mae: 1.4740 - learning_rate: 5.0000e-04
# Epoch 34/100
# 592/593 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - dominant_elbow_accuracy: 0.9221 - dominant_elbow_loss: 0.2387 - dominant_knee_accuracy: 0.8955 - dominant_knee_loss: 0.3056 - loss: 5.1923 - movement_score_loss: 4.6480 - movement_score_mae: 1.6351
# Epoch 34: val_loss improved from 4.88619 to 4.85144, saving model to best_infant_movement_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 15s 25ms/step - dominant_elbow_accuracy: 0.9221 - dominant_elbow_loss: 0.2387 - dominant_knee_accuracy: 0.8955 - dominant_knee_loss: 0.3055 - loss: 5.1920 - movement_score_loss: 4.6478 - movement_score_mae: 1.6351 - val_dominant_elbow_accuracy: 0.9274 - val_dominant_elbow_loss: 0.2222 - val_dominant_knee_accuracy: 0.8913 - val_dominant_knee_loss: 0.3095 - val_loss: 4.8514 - val_movement_score_loss: 4.3578 - val_movement_score_mae: 1.4597 - learning_rate: 5.0000e-04
# Epoch 35/100
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - dominant_elbow_accuracy: 0.9184 - dominant_elbow_loss: 0.2447 - dominant_knee_accuracy: 0.8978 - dominant_knee_loss: 0.2982 - loss: 5.1362 - movement_score_loss: 4.5933 - movement_score_mae: 1.6293
# Epoch 35: val_loss improved from 4.85144 to 4.79321, saving model to best_infant_movement_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 15s 25ms/step - dominant_elbow_accuracy: 0.9184 - dominant_elbow_loss: 0.2446 - dominant_knee_accuracy: 0.8978 - dominant_knee_loss: 0.2982 - loss: 5.1361 - movement_score_loss: 4.5932 - movement_score_mae: 1.6292 - val_dominant_elbow_accuracy: 0.9270 - val_dominant_elbow_loss: 0.2203 - val_dominant_knee_accuracy: 0.8907 - val_dominant_knee_loss: 0.3052 - val_loss: 4.7932 - val_movement_score_loss: 4.2508 - val_movement_score_mae: 1.5298 - learning_rate: 5.0000e-04
# Epoch 36/100
# 592/593 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - dominant_elbow_accuracy: 0.9237 - dominant_elbow_loss: 0.2331 - dominant_knee_accuracy: 0.8978 - dominant_knee_loss: 0.2968 - loss: 4.9159 - movement_score_loss: 4.3861 - movement_score_mae: 1.5802
# Epoch 36: val_loss improved from 4.79321 to 4.36583, saving model to best_infant_movement_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 14s 24ms/step - dominant_elbow_accuracy: 0.9237 - dominant_elbow_loss: 0.2331 - dominant_knee_accuracy: 0.8978 - dominant_knee_loss: 0.2968 - loss: 4.9157 - movement_score_loss: 4.3859 - movement_score_mae: 1.5801 - val_dominant_elbow_accuracy: 0.9257 - val_dominant_elbow_loss: 0.2200 - val_dominant_knee_accuracy: 0.8928 - val_dominant_knee_loss: 0.2985 - val_loss: 4.3658 - val_movement_score_loss: 3.8442 - val_movement_score_mae: 1.3828 - learning_rate: 5.0000e-04
# Epoch 37/100
# 592/593 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - dominant_elbow_accuracy: 0.9197 - dominant_elbow_loss: 0.2372 - dominant_knee_accuracy: 0.8994 - dominant_knee_loss: 0.2914 - loss: 4.7840 - movement_score_loss: 4.2553 - movement_score_mae: 1.5360
# Epoch 37: val_loss did not improve from 4.36583
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 15s 25ms/step - dominant_elbow_accuracy: 0.9197 - dominant_elbow_loss: 0.2372 - dominant_knee_accuracy: 0.8994 - dominant_knee_loss: 0.2914 - loss: 4.7838 - movement_score_loss: 4.2552 - movement_score_mae: 1.5359 - val_dominant_elbow_accuracy: 0.9261 - val_dominant_elbow_loss: 0.2191 - val_dominant_knee_accuracy: 0.8919 - val_dominant_knee_loss: 0.2975 - val_loss: 4.4607 - val_movement_score_loss: 3.9403 - val_movement_score_mae: 1.4109 - learning_rate: 5.0000e-04
# Epoch 38/100
# 591/593 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - dominant_elbow_accuracy: 0.9193 - dominant_elbow_loss: 0.2444 - dominant_knee_accuracy: 0.8980 - dominant_knee_loss: 0.2928 - loss: 4.7169 - movement_score_loss: 4.1797 - movement_score_mae: 1.5129
# Epoch 38: val_loss improved from 4.36583 to 4.18881, saving model to best_infant_movement_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 14s 24ms/step - dominant_elbow_accuracy: 0.9193 - dominant_elbow_loss: 0.2444 - dominant_knee_accuracy: 0.8980 - dominant_knee_loss: 0.2928 - loss: 4.7165 - movement_score_loss: 4.1793 - movement_score_mae: 1.5128 - val_dominant_elbow_accuracy: 0.9278 - val_dominant_elbow_loss: 0.2187 - val_dominant_knee_accuracy: 0.8924 - val_dominant_knee_loss: 0.2950 - val_loss: 4.1888 - val_movement_score_loss: 3.6653 - val_movement_score_mae: 1.2982 - learning_rate: 5.0000e-04
# Epoch 39/100
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - dominant_elbow_accuracy: 0.9204 - dominant_elbow_loss: 0.2357 - dominant_knee_accuracy: 0.8961 - dominant_knee_loss: 0.2918 - loss: 4.5504 - movement_score_loss: 4.0229 - movement_score_mae: 1.4608
# Epoch 39: val_loss did not improve from 4.18881
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 15s 26ms/step - dominant_elbow_accuracy: 0.9204 - dominant_elbow_loss: 0.2357 - dominant_knee_accuracy: 0.8961 - dominant_knee_loss: 0.2918 - loss: 4.5504 - movement_score_loss: 4.0228 - movement_score_mae: 1.4608 - val_dominant_elbow_accuracy: 0.9270 - val_dominant_elbow_loss: 0.2155 - val_dominant_knee_accuracy: 0.8936 - val_dominant_knee_loss: 0.2951 - val_loss: 4.3090 - val_movement_score_loss: 3.8040 - val_movement_score_mae: 1.3334 - learning_rate: 5.0000e-04
# Epoch 40/100
# 592/593 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - dominant_elbow_accuracy: 0.9238 - dominant_elbow_loss: 0.2273 - dominant_knee_accuracy: 0.8981 - dominant_knee_loss: 0.2892 - loss: 4.3776 - movement_score_loss: 3.8611 - movement_score_mae: 1.4207
# Epoch 40: val_loss improved from 4.18881 to 4.05804, saving model to best_infant_movement_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 15s 26ms/step - dominant_elbow_accuracy: 0.9238 - dominant_elbow_loss: 0.2273 - dominant_knee_accuracy: 0.8981 - dominant_knee_loss: 0.2892 - loss: 4.3777 - movement_score_loss: 3.8612 - movement_score_mae: 1.4207 - val_dominant_elbow_accuracy: 0.9274 - val_dominant_elbow_loss: 0.2121 - val_dominant_knee_accuracy: 0.8928 - val_dominant_knee_loss: 0.2942 - val_loss: 4.0580 - val_movement_score_loss: 3.5428 - val_movement_score_mae: 1.2285 - learning_rate: 5.0000e-04
# Epoch 41/100
# 591/593 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - dominant_elbow_accuracy: 0.9167 - dominant_elbow_loss: 0.2389 - dominant_knee_accuracy: 0.8984 - dominant_knee_loss: 0.2886 - loss: 4.2178 - movement_score_loss: 3.6903 - movement_score_mae: 1.3659
# Epoch 41: val_loss improved from 4.05804 to 4.05352, saving model to best_infant_movement_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 15s 26ms/step - dominant_elbow_accuracy: 0.9167 - dominant_elbow_loss: 0.2388 - dominant_knee_accuracy: 0.8984 - dominant_knee_loss: 0.2886 - loss: 4.2183 - movement_score_loss: 3.6908 - movement_score_mae: 1.3660 - val_dominant_elbow_accuracy: 0.9278 - val_dominant_elbow_loss: 0.2106 - val_dominant_knee_accuracy: 0.8926 - val_dominant_knee_loss: 0.2893 - val_loss: 4.0535 - val_movement_score_loss: 3.5415 - val_movement_score_mae: 1.2679 - learning_rate: 5.0000e-04
# Epoch 42/100
# 592/593 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - dominant_elbow_accuracy: 0.9217 - dominant_elbow_loss: 0.2298 - dominant_knee_accuracy: 0.8979 - dominant_knee_loss: 0.2824 - loss: 4.2561 - movement_score_loss: 3.7439 - movement_score_mae: 1.3822
# Epoch 42: val_loss improved from 4.05352 to 3.75836, saving model to best_infant_movement_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 16s 28ms/step - dominant_elbow_accuracy: 0.9217 - dominant_elbow_loss: 0.2298 - dominant_knee_accuracy: 0.8979 - dominant_knee_loss: 0.2824 - loss: 4.2562 - movement_score_loss: 3.7440 - movement_score_mae: 1.3822 - val_dominant_elbow_accuracy: 0.9272 - val_dominant_elbow_loss: 0.2133 - val_dominant_knee_accuracy: 0.8943 - val_dominant_knee_loss: 0.2866 - val_loss: 3.7584 - val_movement_score_loss: 3.2594 - val_movement_score_mae: 1.2081 - learning_rate: 5.0000e-04
# Epoch 43/100
# 592/593 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - dominant_elbow_accuracy: 0.9200 - dominant_elbow_loss: 0.2303 - dominant_knee_accuracy: 0.8967 - dominant_knee_loss: 0.2828 - loss: 4.1195 - movement_score_loss: 3.6064 - movement_score_mae: 1.3502
# Epoch 43: val_loss did not improve from 3.75836
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 19s 32ms/step - dominant_elbow_accuracy: 0.9200 - dominant_elbow_loss: 0.2303 - dominant_knee_accuracy: 0.8967 - dominant_knee_loss: 0.2828 - loss: 4.1197 - movement_score_loss: 3.6067 - movement_score_mae: 1.3503 - val_dominant_elbow_accuracy: 0.9278 - val_dominant_elbow_loss: 0.2110 - val_dominant_knee_accuracy: 0.8940 - val_dominant_knee_loss: 0.2890 - val_loss: 4.3042 - val_movement_score_loss: 3.8062 - val_movement_score_mae: 1.4055 - learning_rate: 5.0000e-04
# Epoch 44/100
# 591/593 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - dominant_elbow_accuracy: 0.9224 - dominant_elbow_loss: 0.2314 - dominant_knee_accuracy: 0.8947 - dominant_knee_loss: 0.2892 - loss: 4.2155 - movement_score_loss: 3.6949 - movement_score_mae: 1.3683
# Epoch 44: val_loss did not improve from 3.75836
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 19s 32ms/step - dominant_elbow_accuracy: 0.9224 - dominant_elbow_loss: 0.2313 - dominant_knee_accuracy: 0.8947 - dominant_knee_loss: 0.2892 - loss: 4.2156 - movement_score_loss: 3.6951 - movement_score_mae: 1.3683 - val_dominant_elbow_accuracy: 0.9276 - val_dominant_elbow_loss: 0.2050 - val_dominant_knee_accuracy: 0.8928 - val_dominant_knee_loss: 0.2868 - val_loss: 3.8305 - val_movement_score_loss: 3.3315 - val_movement_score_mae: 1.1910 - learning_rate: 5.0000e-04
# Epoch 45/100
# 591/593 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - dominant_elbow_accuracy: 0.9208 - dominant_elbow_loss: 0.2348 - dominant_knee_accuracy: 0.8991 - dominant_knee_loss: 0.2814 - loss: 4.1968 - movement_score_loss: 3.6806 - movement_score_mae: 1.3483
# Epoch 45: val_loss did not improve from 3.75836
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 19s 33ms/step - dominant_elbow_accuracy: 0.9208 - dominant_elbow_loss: 0.2348 - dominant_knee_accuracy: 0.8991 - dominant_knee_loss: 0.2814 - loss: 4.1972 - movement_score_loss: 3.6810 - movement_score_mae: 1.3484 - val_dominant_elbow_accuracy: 0.9280 - val_dominant_elbow_loss: 0.2110 - val_dominant_knee_accuracy: 0.8940 - val_dominant_knee_loss: 0.2868 - val_loss: 3.9498 - val_movement_score_loss: 3.4541 - val_movement_score_mae: 1.2898 - learning_rate: 5.0000e-04
# Epoch 46/100
# 592/593 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - dominant_elbow_accuracy: 0.9206 - dominant_elbow_loss: 0.2367 - dominant_knee_accuracy: 0.8936 - dominant_knee_loss: 0.2885 - loss: 4.2935 - movement_score_loss: 3.7683 - movement_score_mae: 1.3804
# Epoch 46: val_loss did not improve from 3.75836
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 19s 33ms/step - dominant_elbow_accuracy: 0.9206 - dominant_elbow_loss: 0.2367 - dominant_knee_accuracy: 0.8936 - dominant_knee_loss: 0.2885 - loss: 4.2935 - movement_score_loss: 3.7683 - movement_score_mae: 1.3803 - val_dominant_elbow_accuracy: 0.9282 - val_dominant_elbow_loss: 0.2105 - val_dominant_knee_accuracy: 0.8930 - val_dominant_knee_loss: 0.2859 - val_loss: 3.9186 - val_movement_score_loss: 3.4207 - val_movement_score_mae: 1.1890 - learning_rate: 5.0000e-04
# Epoch 47/100
# 591/593 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - dominant_elbow_accuracy: 0.9225 - dominant_elbow_loss: 0.2341 - dominant_knee_accuracy: 0.9003 - dominant_knee_loss: 0.2811 - loss: 4.2037 - movement_score_loss: 3.6885 - movement_score_mae: 1.3499
# Epoch 47: val_loss did not improve from 3.75836
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 23s 39ms/step - dominant_elbow_accuracy: 0.9225 - dominant_elbow_loss: 0.2341 - dominant_knee_accuracy: 0.9003 - dominant_knee_loss: 0.2811 - loss: 4.2041 - movement_score_loss: 3.6889 - movement_score_mae: 1.3501 - val_dominant_elbow_accuracy: 0.9272 - val_dominant_elbow_loss: 0.2142 - val_dominant_knee_accuracy: 0.8924 - val_dominant_knee_loss: 0.2891 - val_loss: 4.4052 - val_movement_score_loss: 3.8929 - val_movement_score_mae: 1.3686 - learning_rate: 5.0000e-04
# Epoch 48/100
# 592/593 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - dominant_elbow_accuracy: 0.9176 - dominant_elbow_loss: 0.2386 - dominant_knee_accuracy: 0.9004 - dominant_knee_loss: 0.2794 - loss: 4.1332 - movement_score_loss: 3.6152 - movement_score_mae: 1.3396
# Epoch 48: val_loss improved from 3.75836 to 3.44179, saving model to best_infant_movement_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 19s 33ms/step - dominant_elbow_accuracy: 0.9176 - dominant_elbow_loss: 0.2386 - dominant_knee_accuracy: 0.9004 - dominant_knee_loss: 0.2794 - loss: 4.1326 - movement_score_loss: 3.6146 - movement_score_mae: 1.3394 - val_dominant_elbow_accuracy: 0.9270 - val_dominant_elbow_loss: 0.2072 - val_dominant_knee_accuracy: 0.8932 - val_dominant_knee_loss: 0.2821 - val_loss: 3.4418 - val_movement_score_loss: 2.9475 - val_movement_score_mae: 1.0781 - learning_rate: 2.5000e-04
# Epoch 49/100
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - dominant_elbow_accuracy: 0.9215 - dominant_elbow_loss: 0.2283 - dominant_knee_accuracy: 0.9000 - dominant_knee_loss: 0.2754 - loss: 3.8228 - movement_score_loss: 3.3191 - movement_score_mae: 1.2450
# Epoch 49: val_loss did not improve from 3.44179
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 14s 24ms/step - dominant_elbow_accuracy: 0.9215 - dominant_elbow_loss: 0.2283 - dominant_knee_accuracy: 0.9000 - dominant_knee_loss: 0.2754 - loss: 3.8227 - movement_score_loss: 3.3191 - movement_score_mae: 1.2450 - val_dominant_elbow_accuracy: 0.9259 - val_dominant_elbow_loss: 0.2110 - val_dominant_knee_accuracy: 0.8936 - val_dominant_knee_loss: 0.2866 - val_loss: 3.6113 - val_movement_score_loss: 3.1904 - val_movement_score_mae: 1.0764 - learning_rate: 2.5000e-04
# Epoch 50/100
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - dominant_elbow_accuracy: 0.9236 - dominant_elbow_loss: 0.2239 - dominant_knee_accuracy: 0.9004 - dominant_knee_loss: 0.2709 - loss: 3.6354 - movement_score_loss: 3.1406 - movement_score_mae: 1.2000
# Epoch 50: val_loss did not improve from 3.44179
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 14s 24ms/step - dominant_elbow_accuracy: 0.9236 - dominant_elbow_loss: 0.2239 - dominant_knee_accuracy: 0.9004 - dominant_knee_loss: 0.2709 - loss: 3.6356 - movement_score_loss: 3.1408 - movement_score_mae: 1.2000 - val_dominant_elbow_accuracy: 0.9274 - val_dominant_elbow_loss: 0.2094 - val_dominant_knee_accuracy: 0.8936 - val_dominant_knee_loss: 0.2759 - val_loss: 3.5960 - val_movement_score_loss: 3.0988 - val_movement_score_mae: 1.1647 - learning_rate: 2.5000e-04
# Epoch 51/100
# 591/593 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - dominant_elbow_accuracy: 0.9235 - dominant_elbow_loss: 0.2249 - dominant_knee_accuracy: 0.8973 - dominant_knee_loss: 0.2757 - loss: 3.5840 - movement_score_loss: 3.0834 - movement_score_mae: 1.1921
# Epoch 51: val_loss did not improve from 3.44179
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 15s 24ms/step - dominant_elbow_accuracy: 0.9235 - dominant_elbow_loss: 0.2249 - dominant_knee_accuracy: 0.8973 - dominant_knee_loss: 0.2757 - loss: 3.5845 - movement_score_loss: 3.0839 - movement_score_mae: 1.1921 - val_dominant_elbow_accuracy: 0.9268 - val_dominant_elbow_loss: 0.2135 - val_dominant_knee_accuracy: 0.8940 - val_dominant_knee_loss: 0.2752 - val_loss: 3.5414 - val_movement_score_loss: 3.0528 - val_movement_score_mae: 1.1244 - learning_rate: 2.5000e-04
# Epoch 52/100
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - dominant_elbow_accuracy: 0.9218 - dominant_elbow_loss: 0.2275 - dominant_knee_accuracy: 0.8977 - dominant_knee_loss: 0.2761 - loss: 3.6242 - movement_score_loss: 3.1206 - movement_score_mae: 1.1912
# Epoch 52: val_loss improved from 3.44179 to 3.13201, saving model to best_infant_movement_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 15s 25ms/step - dominant_elbow_accuracy: 0.9218 - dominant_elbow_loss: 0.2275 - dominant_knee_accuracy: 0.8977 - dominant_knee_loss: 0.2761 - loss: 3.6240 - movement_score_loss: 3.1205 - movement_score_mae: 1.1911 - val_dominant_elbow_accuracy: 0.9278 - val_dominant_elbow_loss: 0.2041 - val_dominant_knee_accuracy: 0.8936 - val_dominant_knee_loss: 0.2772 - val_loss: 3.1320 - val_movement_score_loss: 2.7336 - val_movement_score_mae: 0.9539 - learning_rate: 2.5000e-04
# Epoch 53/100
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - dominant_elbow_accuracy: 0.9215 - dominant_elbow_loss: 0.2269 - dominant_knee_accuracy: 0.8939 - dominant_knee_loss: 0.2789 - loss: 3.5443 - movement_score_loss: 3.0385 - movement_score_mae: 1.1584
# Epoch 53: val_loss did not improve from 3.13201
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 15s 25ms/step - dominant_elbow_accuracy: 0.9215 - dominant_elbow_loss: 0.2268 - dominant_knee_accuracy: 0.8939 - dominant_knee_loss: 0.2789 - loss: 3.5441 - movement_score_loss: 3.0384 - movement_score_mae: 1.1584 - val_dominant_elbow_accuracy: 0.9274 - val_dominant_elbow_loss: 0.2088 - val_dominant_knee_accuracy: 0.8940 - val_dominant_knee_loss: 0.2719 - val_loss: 3.2145 - val_movement_score_loss: 2.7377 - val_movement_score_mae: 0.9974 - learning_rate: 2.5000e-04
# Epoch 54/100
# 591/593 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - dominant_elbow_accuracy: 0.9207 - dominant_elbow_loss: 0.2267 - dominant_knee_accuracy: 0.8966 - dominant_knee_loss: 0.2753 - loss: 3.4955 - movement_score_loss: 2.9935 - movement_score_mae: 1.1420
# Epoch 54: val_loss did not improve from 3.13201
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 15s 25ms/step - dominant_elbow_accuracy: 0.9207 - dominant_elbow_loss: 0.2267 - dominant_knee_accuracy: 0.8966 - dominant_knee_loss: 0.2753 - loss: 3.4953 - movement_score_loss: 2.9934 - movement_score_mae: 1.1420 - val_dominant_elbow_accuracy: 0.9278 - val_dominant_elbow_loss: 0.2070 - val_dominant_knee_accuracy: 0.8930 - val_dominant_knee_loss: 0.2715 - val_loss: 3.2884 - val_movement_score_loss: 2.8045 - val_movement_score_mae: 0.9550 - learning_rate: 2.5000e-04
# Epoch 55/100
# 591/593 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - dominant_elbow_accuracy: 0.9228 - dominant_elbow_loss: 0.2216 - dominant_knee_accuracy: 0.9017 - dominant_knee_loss: 0.2628 - loss: 3.3735 - movement_score_loss: 2.8891 - movement_score_mae: 1.1144
# Epoch 55: val_loss improved from 3.13201 to 3.00816, saving model to best_infant_movement_model.keras
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 15s 26ms/step - dominant_elbow_accuracy: 0.9228 - dominant_elbow_loss: 0.2216 - dominant_knee_accuracy: 0.9017 - dominant_knee_loss: 0.2629 - loss: 3.3735 - movement_score_loss: 2.8891 - movement_score_mae: 1.1144 - val_dominant_elbow_accuracy: 0.9282 - val_dominant_elbow_loss: 0.2038 - val_dominant_knee_accuracy: 0.8930 - val_dominant_knee_loss: 0.2667 - val_loss: 3.0082 - val_movement_score_loss: 2.5398 - val_movement_score_mae: 0.9806 - learning_rate: 2.5000e-04
# Epoch 56/100
# 591/593 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - dominant_elbow_accuracy: 0.9195 - dominant_elbow_loss: 0.2241 - dominant_knee_accuracy: 0.9017 - dominant_knee_loss: 0.2619 - loss: 3.3050 - movement_score_loss: 2.8191 - movement_score_mae: 1.0996
# Epoch 56: val_loss did not improve from 3.00816
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 15s 25ms/step - dominant_elbow_accuracy: 0.9196 - dominant_elbow_loss: 0.2241 - dominant_knee_accuracy: 0.9017 - dominant_knee_loss: 0.2619 - loss: 3.3057 - movement_score_loss: 2.8197 - movement_score_mae: 1.0997 - val_dominant_elbow_accuracy: 0.9261 - val_dominant_elbow_loss: 0.2053 - val_dominant_knee_accuracy: 0.8930 - val_dominant_knee_loss: 0.2763 - val_loss: 3.1304 - val_movement_score_loss: 2.7215 - val_movement_score_mae: 0.9811 - learning_rate: 2.5000e-04
# Epoch 57/100
# 592/593 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - dominant_elbow_accuracy: 0.9238 - dominant_elbow_loss: 0.2208 - dominant_knee_accuracy: 0.8943 - dominant_knee_loss: 0.2765 - loss: 3.3676 - movement_score_loss: 2.8703 - movement_score_mae: 1.1026
# Epoch 57: val_loss did not improve from 3.00816
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 17s 29ms/step - dominant_elbow_accuracy: 0.9238 - dominant_elbow_loss: 0.2209 - dominant_knee_accuracy: 0.8944 - dominant_knee_loss: 0.2764 - loss: 3.3676 - movement_score_loss: 2.8703 - movement_score_mae: 1.1026 - val_dominant_elbow_accuracy: 0.9285 - val_dominant_elbow_loss: 0.2035 - val_dominant_knee_accuracy: 0.8930 - val_dominant_knee_loss: 0.2678 - val_loss: 3.1355 - val_movement_score_loss: 2.6599 - val_movement_score_mae: 0.9652 - learning_rate: 2.5000e-04
# Epoch 58/100
# 592/593 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - dominant_elbow_accuracy: 0.9227 - dominant_elbow_loss: 0.2183 - dominant_knee_accuracy: 0.8981 - dominant_knee_loss: 0.2676 - loss: 3.2849 - movement_score_loss: 2.7990 - movement_score_mae: 1.0891
# Epoch 58: val_loss did not improve from 3.00816
# 593/593 ━━━━━━━━━━━━━━━━━━━━ 16s 26ms/step - dominant_elbow_accuracy: 0.9227 - dominant_elbow_loss: 0.2183 - dominant_knee_accuracy: 0.8981 - dominant_knee_loss: 0.2677 - loss: 3.2852 - movement_score_loss: 2.7993 - movement_score_mae: 1.0892 - val_dominant_elbow_accuracy: 0.9285 - val_dominant_elbow_loss: 0.2041 - val_dominant_knee_accuracy: 0.8936 - val_dominant_knee_loss: 0.2746 - val_loss: 3.3188 - val_movement_score_loss: 2.8918 - val_movement_score_mae: 1.0177 - learning_rate: 2.5000e-04
# Epoch 59/100
# ...
# Epoch 83/100
# 590/591 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - dominant_elbow_accuracy: 0.7655 - dominant_elbow_loss: 0.4651 - dominant_knee_accuracy: 0.8641 - dominant_knee_loss: 0.3076 - loss: 1.1334 - movement_score_loss: 0.3606 - movement_score_mae: 0.4502
# Epoch 83: val_loss did not improve from 1.10427
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 19s 32ms/step - dominant_elbow_accuracy: 0.7654 - dominant_elbow_loss: 0.4651 - dominant_knee_accuracy: 0.8640 - dominant_knee_loss: 0.3077 - loss: 1.1335 - movement_score_loss: 0.3607 - movement_score_mae: 0.4503 - val_dominant_elbow_accuracy: 0.7675 - val_dominant_elbow_loss: 0.4560 - val_dominant_knee_accuracy: 0.8701 - val_dominant_knee_loss: 0.2951 - val_loss: 1.1359 - val_movement_score_loss: 0.3853 - val_movement_score_mae: 0.4492 - learning_rate: 3.1250e-05
# Epoch 84/100
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dominant_elbow_accuracy: 0.7538 - dominant_elbow_loss: 0.4793 - dominant_knee_accuracy: 0.8596 - dominant_knee_loss: 0.3153 - loss: 1.1488 - movement_score_loss: 0.3542 - movement_score_mae: 0.4511
# Epoch 84: val_loss improved from 1.10427 to 1.08338, saving model to best_infant_movement_model.keras
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 20s 34ms/step - dominant_elbow_accuracy: 0.7538 - dominant_elbow_loss: 0.4793 - dominant_knee_accuracy: 0.8596 - dominant_knee_loss: 0.3153 - loss: 1.1488 - movement_score_loss: 0.3542 - movement_score_mae: 0.4511 - val_dominant_elbow_accuracy: 0.7713 - val_dominant_elbow_loss: 0.4519 - val_dominant_knee_accuracy: 0.8781 - val_dominant_knee_loss: 0.2878 - val_loss: 1.0834 - val_movement_score_loss: 0.3438 - val_movement_score_mae: 0.4235 - learning_rate: 3.1250e-05
# Epoch 85/100
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - dominant_elbow_accuracy: 0.7619 - dominant_elbow_loss: 0.4724 - dominant_knee_accuracy: 0.8616 - dominant_knee_loss: 0.3189 - loss: 1.1511 - movement_score_loss: 0.3598 - movement_score_mae: 0.4529
# Epoch 85: val_loss did not improve from 1.08338
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 19s 32ms/step - dominant_elbow_accuracy: 0.7619 - dominant_elbow_loss: 0.4724 - dominant_knee_accuracy: 0.8616 - dominant_knee_loss: 0.3189 - loss: 1.1511 - movement_score_loss: 0.3598 - movement_score_mae: 0.4529 - val_dominant_elbow_accuracy: 0.7721 - val_dominant_elbow_loss: 0.4527 - val_dominant_knee_accuracy: 0.8720 - val_dominant_knee_loss: 0.2905 - val_loss: 1.1032 - val_movement_score_loss: 0.3602 - val_movement_score_mae: 0.4336 - learning_rate: 3.1250e-05
# Epoch 86/100
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - dominant_elbow_accuracy: 0.7652 - dominant_elbow_loss: 0.4736 - dominant_knee_accuracy: 0.8628 - dominant_knee_loss: 0.3179 - loss: 1.1549 - movement_score_loss: 0.3634 - movement_score_mae: 0.4531
# Epoch 86: val_loss did not improve from 1.08338
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 19s 33ms/step - dominant_elbow_accuracy: 0.7652 - dominant_elbow_loss: 0.4736 - dominant_knee_accuracy: 0.8628 - dominant_knee_loss: 0.3179 - loss: 1.1549 - movement_score_loss: 0.3634 - movement_score_mae: 0.4531 - val_dominant_elbow_accuracy: 0.7711 - val_dominant_elbow_loss: 0.4544 - val_dominant_knee_accuracy: 0.8724 - val_dominant_knee_loss: 0.2927 - val_loss: 1.1218 - val_movement_score_loss: 0.3750 - val_movement_score_mae: 0.4409 - learning_rate: 3.1250e-05
# Epoch 87/100
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dominant_elbow_accuracy: 0.7637 - dominant_elbow_loss: 0.4654 - dominant_knee_accuracy: 0.8622 - dominant_knee_loss: 0.3163 - loss: 1.1478 - movement_score_loss: 0.3661 - movement_score_mae: 0.4577
# Epoch 87: val_loss did not improve from 1.08338
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 21s 35ms/step - dominant_elbow_accuracy: 0.7637 - dominant_elbow_loss: 0.4654 - dominant_knee_accuracy: 0.8622 - dominant_knee_loss: 0.3163 - loss: 1.1478 - movement_score_loss: 0.3661 - movement_score_mae: 0.4577 - val_dominant_elbow_accuracy: 0.7675 - val_dominant_elbow_loss: 0.4576 - val_dominant_knee_accuracy: 0.8749 - val_dominant_knee_loss: 0.2924 - val_loss: 1.1097 - val_movement_score_loss: 0.3599 - val_movement_score_mae: 0.4343 - learning_rate: 3.1250e-05
# Epoch 88/100
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dominant_elbow_accuracy: 0.7614 - dominant_elbow_loss: 0.4730 - dominant_knee_accuracy: 0.8563 - dominant_knee_loss: 0.3188 - loss: 1.1636 - movement_score_loss: 0.3718 - movement_score_mae: 0.4596
# Epoch 88: val_loss did not improve from 1.08338
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 22s 37ms/step - dominant_elbow_accuracy: 0.7614 - dominant_elbow_loss: 0.4730 - dominant_knee_accuracy: 0.8563 - dominant_knee_loss: 0.3188 - loss: 1.1636 - movement_score_loss: 0.3718 - movement_score_mae: 0.4596 - val_dominant_elbow_accuracy: 0.7763 - val_dominant_elbow_loss: 0.4509 - val_dominant_knee_accuracy: 0.8737 - val_dominant_knee_loss: 0.2895 - val_loss: 1.1090 - val_movement_score_loss: 0.3688 - val_movement_score_mae: 0.4393 - learning_rate: 3.1250e-05
# Epoch 89/100
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - dominant_elbow_accuracy: 0.7596 - dominant_elbow_loss: 0.4713 - dominant_knee_accuracy: 0.8630 - dominant_knee_loss: 0.3082 - loss: 1.1458 - movement_score_loss: 0.3663 - movement_score_mae: 0.4558
# Epoch 89: val_loss did not improve from 1.08338
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 23s 39ms/step - dominant_elbow_accuracy: 0.7596 - dominant_elbow_loss: 0.4713 - dominant_knee_accuracy: 0.8630 - dominant_knee_loss: 0.3082 - loss: 1.1458 - movement_score_loss: 0.3663 - movement_score_mae: 0.4558 - val_dominant_elbow_accuracy: 0.7747 - val_dominant_elbow_loss: 0.4512 - val_dominant_knee_accuracy: 0.8701 - val_dominant_knee_loss: 0.2968 - val_loss: 1.1092 - val_movement_score_loss: 0.3613 - val_movement_score_mae: 0.4352 - learning_rate: 3.1250e-05
# Epoch 90/100
# 590/591 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - dominant_elbow_accuracy: 0.7665 - dominant_elbow_loss: 0.4677 - dominant_knee_accuracy: 0.8567 - dominant_knee_loss: 0.3181 - loss: 1.1570 - movement_score_loss: 0.3713 - movement_score_mae: 0.4624
# Epoch 90: val_loss did not improve from 1.08338
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 24s 40ms/step - dominant_elbow_accuracy: 0.7664 - dominant_elbow_loss: 0.4677 - dominant_knee_accuracy: 0.8567 - dominant_knee_loss: 0.3180 - loss: 1.1570 - movement_score_loss: 0.3713 - movement_score_mae: 0.4623 - val_dominant_elbow_accuracy: 0.7721 - val_dominant_elbow_loss: 0.4498 - val_dominant_knee_accuracy: 0.8756 - val_dominant_knee_loss: 0.2888 - val_loss: 1.0994 - val_movement_score_loss: 0.3611 - val_movement_score_mae: 0.4351 - learning_rate: 1.5625e-05
# Epoch 91/100
# 590/591 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - dominant_elbow_accuracy: 0.7654 - dominant_elbow_loss: 0.4611 - dominant_knee_accuracy: 0.8656 - dominant_knee_loss: 0.3076 - loss: 1.1341 - movement_score_loss: 0.3655 - movement_score_mae: 0.4531
# Epoch 91: val_loss did not improve from 1.08338
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 26s 43ms/step - dominant_elbow_accuracy: 0.7654 - dominant_elbow_loss: 0.4611 - dominant_knee_accuracy: 0.8656 - dominant_knee_loss: 0.3076 - loss: 1.1342 - movement_score_loss: 0.3655 - movement_score_mae: 0.4531 - val_dominant_elbow_accuracy: 0.7715 - val_dominant_elbow_loss: 0.4517 - val_dominant_knee_accuracy: 0.8764 - val_dominant_knee_loss: 0.2868 - val_loss: 1.0977 - val_movement_score_loss: 0.3594 - val_movement_score_mae: 0.4341 - learning_rate: 1.5625e-05
# Epoch 92/100
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - dominant_elbow_accuracy: 0.7577 - dominant_elbow_loss: 0.4740 - dominant_knee_accuracy: 0.8599 - dominant_knee_loss: 0.3096 - loss: 1.1420 - movement_score_loss: 0.3583 - movement_score_mae: 0.4519
# Epoch 92: val_loss did not improve from 1.08338
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 21s 36ms/step - dominant_elbow_accuracy: 0.7577 - dominant_elbow_loss: 0.4740 - dominant_knee_accuracy: 0.8599 - dominant_knee_loss: 0.3096 - loss: 1.1420 - movement_score_loss: 0.3583 - movement_score_mae: 0.4519 - val_dominant_elbow_accuracy: 0.7711 - val_dominant_elbow_loss: 0.4535 - val_dominant_knee_accuracy: 0.8777 - val_dominant_knee_loss: 0.2853 - val_loss: 1.0970 - val_movement_score_loss: 0.3585 - val_movement_score_mae: 0.4316 - learning_rate: 1.5625e-05
# Epoch 93/100
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - dominant_elbow_accuracy: 0.7584 - dominant_elbow_loss: 0.4725 - dominant_knee_accuracy: 0.8634 - dominant_knee_loss: 0.3069 - loss: 1.1399 - movement_score_loss: 0.3605 - movement_score_mae: 0.4523
# Epoch 93: val_loss improved from 1.08338 to 1.08045, saving model to best_infant_movement_model.keras
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 22s 37ms/step - dominant_elbow_accuracy: 0.7584 - dominant_elbow_loss: 0.4725 - dominant_knee_accuracy: 0.8634 - dominant_knee_loss: 0.3069 - loss: 1.1399 - movement_score_loss: 0.3604 - movement_score_mae: 0.4523 - val_dominant_elbow_accuracy: 0.7740 - val_dominant_elbow_loss: 0.4468 - val_dominant_knee_accuracy: 0.8781 - val_dominant_knee_loss: 0.2859 - val_loss: 1.0804 - val_movement_score_loss: 0.3479 - val_movement_score_mae: 0.4269 - learning_rate: 1.5625e-05
# Epoch 94/100
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - dominant_elbow_accuracy: 0.7572 - dominant_elbow_loss: 0.4772 - dominant_knee_accuracy: 0.8706 - dominant_knee_loss: 0.3043 - loss: 1.1382 - movement_score_loss: 0.3568 - movement_score_mae: 0.4529
# Epoch 94: val_loss did not improve from 1.08045
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 20s 33ms/step - dominant_elbow_accuracy: 0.7572 - dominant_elbow_loss: 0.4771 - dominant_knee_accuracy: 0.8706 - dominant_knee_loss: 0.3043 - loss: 1.1382 - movement_score_loss: 0.3568 - movement_score_mae: 0.4529 - val_dominant_elbow_accuracy: 0.7732 - val_dominant_elbow_loss: 0.4476 - val_dominant_knee_accuracy: 0.8773 - val_dominant_knee_loss: 0.2857 - val_loss: 1.0822 - val_movement_score_loss: 0.3491 - val_movement_score_mae: 0.4277 - learning_rate: 1.5625e-05
# Epoch 95/100
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dominant_elbow_accuracy: 0.7646 - dominant_elbow_loss: 0.4678 - dominant_knee_accuracy: 0.8652 - dominant_knee_loss: 0.3101 - loss: 1.1344 - movement_score_loss: 0.3565 - movement_score_mae: 0.4512
# Epoch 95: val_loss did not improve from 1.08045
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 21s 35ms/step - dominant_elbow_accuracy: 0.7646 - dominant_elbow_loss: 0.4678 - dominant_knee_accuracy: 0.8652 - dominant_knee_loss: 0.3101 - loss: 1.1344 - movement_score_loss: 0.3565 - movement_score_mae: 0.4512 - val_dominant_elbow_accuracy: 0.7738 - val_dominant_elbow_loss: 0.4495 - val_dominant_knee_accuracy: 0.8771 - val_dominant_knee_loss: 0.2861 - val_loss: 1.1059 - val_movement_score_loss: 0.3705 - val_movement_score_mae: 0.4398 - learning_rate: 1.5625e-05
# Epoch 96/100
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - dominant_elbow_accuracy: 0.7633 - dominant_elbow_loss: 0.4701 - dominant_knee_accuracy: 0.8605 - dominant_knee_loss: 0.3116 - loss: 1.1425 - movement_score_loss: 0.3608 - movement_score_mae: 0.4537
# Epoch 96: val_loss did not improve from 1.08045
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 19s 33ms/step - dominant_elbow_accuracy: 0.7633 - dominant_elbow_loss: 0.4701 - dominant_knee_accuracy: 0.8605 - dominant_knee_loss: 0.3116 - loss: 1.1425 - movement_score_loss: 0.3608 - movement_score_mae: 0.4537 - val_dominant_elbow_accuracy: 0.7708 - val_dominant_elbow_loss: 0.4516 - val_dominant_knee_accuracy: 0.8754 - val_dominant_knee_loss: 0.2898 - val_loss: 1.1045 - val_movement_score_loss: 0.3633 - val_movement_score_mae: 0.4338 - learning_rate: 1.5625e-05
# Epoch 97/100
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dominant_elbow_accuracy: 0.7617 - dominant_elbow_loss: 0.4708 - dominant_knee_accuracy: 0.8620 - dominant_knee_loss: 0.3065 - loss: 1.1264 - movement_score_loss: 0.3491 - movement_score_mae: 0.4502
# Epoch 97: val_loss did not improve from 1.08045
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 21s 35ms/step - dominant_elbow_accuracy: 0.7617 - dominant_elbow_loss: 0.4708 - dominant_knee_accuracy: 0.8620 - dominant_knee_loss: 0.3065 - loss: 1.1264 - movement_score_loss: 0.3491 - movement_score_mae: 0.4502 - val_dominant_elbow_accuracy: 0.7732 - val_dominant_elbow_loss: 0.4485 - val_dominant_knee_accuracy: 0.8800 - val_dominant_knee_loss: 0.2863 - val_loss: 1.0938 - val_movement_score_loss: 0.3592 - val_movement_score_mae: 0.4333 - learning_rate: 1.5625e-05
# Epoch 98/100
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - dominant_elbow_accuracy: 0.7614 - dominant_elbow_loss: 0.4728 - dominant_knee_accuracy: 0.8624 - dominant_knee_loss: 0.3136 - loss: 1.1425 - movement_score_loss: 0.3561 - movement_score_mae: 0.4516
# Epoch 98: val_loss did not improve from 1.08045
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 22s 38ms/step - dominant_elbow_accuracy: 0.7614 - dominant_elbow_loss: 0.4727 - dominant_knee_accuracy: 0.8624 - dominant_knee_loss: 0.3136 - loss: 1.1425 - movement_score_loss: 0.3561 - movement_score_mae: 0.4516 - val_dominant_elbow_accuracy: 0.7749 - val_dominant_elbow_loss: 0.4491 - val_dominant_knee_accuracy: 0.8769 - val_dominant_knee_loss: 0.2847 - val_loss: 1.0996 - val_movement_score_loss: 0.3661 - val_movement_score_mae: 0.4375 - learning_rate: 1.5625e-05
# Epoch 99/100
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dominant_elbow_accuracy: 0.7659 - dominant_elbow_loss: 0.4632 - dominant_knee_accuracy: 0.8693 - dominant_knee_loss: 0.3022 - loss: 1.1265 - movement_score_loss: 0.3611 - movement_score_mae: 0.4534
# Epoch 99: val_loss did not improve from 1.08045
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 21s 35ms/step - dominant_elbow_accuracy: 0.7659 - dominant_elbow_loss: 0.4632 - dominant_knee_accuracy: 0.8693 - dominant_knee_loss: 0.3022 - loss: 1.1265 - movement_score_loss: 0.3611 - movement_score_mae: 0.4534 - val_dominant_elbow_accuracy: 0.7721 - val_dominant_elbow_loss: 0.4491 - val_dominant_knee_accuracy: 0.8781 - val_dominant_knee_loss: 0.2866 - val_loss: 1.1015 - val_movement_score_loss: 0.3661 - val_movement_score_mae: 0.4363 - learning_rate: 1.0000e-05
# Epoch 100/100
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - dominant_elbow_accuracy: 0.7590 - dominant_elbow_loss: 0.4678 - dominant_knee_accuracy: 0.8631 - dominant_knee_loss: 0.3107 - loss: 1.1416 - movement_score_loss: 0.3632 - movement_score_mae: 0.4547
# Epoch 100: val_loss did not improve from 1.08045
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 22s 38ms/step - dominant_elbow_accuracy: 0.7590 - dominant_elbow_loss: 0.4678 - dominant_knee_accuracy: 0.8631 - dominant_knee_loss: 0.3107 - loss: 1.1416 - movement_score_loss: 0.3632 - movement_score_mae: 0.4547 - val_dominant_elbow_accuracy: 0.7755 - val_dominant_elbow_loss: 0.4472 - val_dominant_knee_accuracy: 0.8773 - val_dominant_knee_loss: 0.2859 - val_loss: 1.0864 - val_movement_score_loss: 0.3536 - val_movement_score_mae: 0.4298 - learning_rate: 1.0000e-05
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step
#
# ===== תוצאות המודל =====
# RMSE לציון תנועה כללי: 0.5871
# דיוק סיווג ברך דומיננטית: 0.8734
# דיוק סיווג מרפק דומיננטי: 0.7703
#
# דוח סיווג - ברך דומיננטית:
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.75      0.77      1656
#          1.0       0.91      0.92      0.91      4251
#
#     accuracy                           0.87      5907
#    macro avg       0.85      0.84      0.84      5907
# weighted avg       0.87      0.87      0.87      5907
#
#
# דוח סיווג - מרפק דומיננטי:
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.73      0.75      2861
#          1.0       0.76      0.81      0.78      3046
#
#     accuracy                           0.77      5907
#    macro avg       0.77      0.77      0.77      5907
# weighted avg       0.77      0.77      0.77      5907
#
#
# מיפוי תוויות ברך:
# 0: left
# 1: right
#
# מיפוי תוויות מרפק:
# 0: left
# 1: right
# 'infant_movement_gru_mediapipe_model.keras'
#
# Movenet Training Ended
# ==================================================
