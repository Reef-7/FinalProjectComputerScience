# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import GRU, Dense, Input, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import mean_squared_error, accuracy_score, classification_report
import os
import glob

# הגדרת פרמטרים
WINDOW_SIZE = 30  # מספר הפריימים ברצף (ניתן לשינוי בהתאם לצרכים)
RANDOM_STATE = 42
BATCH_SIZE = 32
EPOCHS = 100
LEARNING_RATE = 0.001

def load_and_preprocess_data(file_paths, window_size=WINDOW_SIZE):
    """
    טעינה ועיבוד מקדים של הנתונים מקבצי האקסל
    """
    all_data = []
    
    for file_path in file_paths:
        df = pd.read_csv(file_path) if file_path.endswith('.csv') else pd.read_excel(file_path)
        
        # בדיקה שקיימים העמודות הנדרשות
        required_columns = ['video_id', 'frame', 'window_id', 
                           'overall_movement_score', 'dominant_knee', 'dominant_elbow']
        
        if not all(col in df.columns for col in required_columns):
            print(f"The file {file_path} is missing required columns. Skipping...")
            continue
        df = df[~df['video_id'].isin([43, 44])]
        all_data.append(df)
    
    if not all_data:
        raise ValueError("No valid files found for processing")
        
    # איחוד כל הנתונים
    data = pd.concat(all_data, ignore_index=True)
    
    # המרת ערכים קטגוריאליים למספרים
    label_encoders = {}
    for col in ['dominant_knee', 'dominant_elbow']:
        if data[col].dtype == 'object':
            le = LabelEncoder()
            data[col] = le.fit_transform(data[col])
            label_encoders[col] = le
    
    return data, label_encoders

def prepare_sequences(data, window_size=WINDOW_SIZE):
    """
    הכנת רצפי נתונים עבור GRU לפי חלונות
    """
    feature_columns = [col for col in data.columns if any(x in col for x in 
                      ['_x', '_y', '_confidence'])]
    
    X = []
    y_movement = []
    y_knee = []
    y_elbow = []
    
    # קיבוץ לפי וידאו וחלון
    groups = data.groupby(['video_id', 'window_id'])
    
    for (vid_id, win_id), group in groups:
        if len(group) < window_size:
            # דילוג על חלונות קטנים מדי
            continue
        
        # לכל חלון, ניקח רצפים באורך window_size
        for i in range(0, len(group) - window_size + 1):
            sequence = group.iloc[i:i+window_size][feature_columns].values
            
            # המטרות הן הערכים בפריים האחרון ברצף
            target_frame = group.iloc[i+window_size-1]
            
            X.append(sequence)
            y_movement.append(target_frame['overall_movement_score'])
            y_knee.append(target_frame['dominant_knee'])
            y_elbow.append(target_frame['dominant_elbow'])
    
    X = np.array(X)
    y_movement = np.array(y_movement)
    y_knee = np.array(y_knee)
    y_elbow = np.array(y_elbow)
    
    return X, y_movement, y_knee, y_elbow, feature_columns

def build_gru_model(input_shape, num_knee_classes, num_elbow_classes):
    """
    בניית מודל GRU עם מספר שכבות והתאמה למשימות מרובות
    """
    # שכבת הקלט המשותפת
    inputs = Input(shape=input_shape)
    
    # שכבות GRU משותפות
    x = GRU(128, return_sequences=True)(inputs)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)
    
    x = GRU(64)(x)
    x = BatchNormalization()(x)
    shared_features = Dropout(0.3)(x)
    
    # ענף לציון תנועה כללי (רגרסיה)
    movement_output = Dense(32, activation='relu')(shared_features)
    movement_output = Dense(1, name='movement_score')(movement_output)
    
    # ענף לברך דומיננטית (סיווג)
    knee_output = Dense(32, activation='relu')(shared_features)
    knee_output = Dense(num_knee_classes, activation='softmax', name='dominant_knee')(knee_output)
    
    # ענף למרפק דומיננטי (סיווג)
    elbow_output = Dense(32, activation='relu')(shared_features)
    elbow_output = Dense(num_elbow_classes, activation='softmax', name='dominant_elbow')(elbow_output)
    
    # הגדרת המודל עם קלט ושלושה פלטים
    model = Model(inputs=inputs, outputs=[movement_output, knee_output, elbow_output])
    
    # הגדרת אופטימייזר ופונקציות שגיאה
    model.compile(
        optimizer=Adam(learning_rate=LEARNING_RATE),
        loss={
            'movement_score': 'mean_squared_error',
            'dominant_knee': 'sparse_categorical_crossentropy',
            'dominant_elbow': 'sparse_categorical_crossentropy'
        },
        metrics={
            'movement_score': ['mae'],
            'dominant_knee': ['accuracy'],
            'dominant_elbow': ['accuracy']
        }
    )
    
    return model

def train_model(X_train, y_train, X_val, y_val, input_shape, num_knee_classes, num_elbow_classes):
    """
    אימון המודל עם מנגנוני עצירה מוקדמת ושיפור ביצועים
    """
    model = build_gru_model(input_shape, num_knee_classes, num_elbow_classes)
    
    # הגדרת callbacks
    early_stopping = EarlyStopping(
        monitor='val_loss', 
        patience=15, 
        restore_best_weights=True
    )
    
    reduce_lr = ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        min_lr=0.00001
    )

    '''
        קובץ בו נשמר המודל שמתקבלת בו התוצאה הטובה ביותר על סט הוולידציה
    '''
    model_checkpoint = ModelCheckpoint(
        'best_infant_movement_model.keras', 
        monitor='val_loss',
        save_best_only=True,
        verbose=1
    )
    
    # אימון המודל
    history = model.fit(
        X_train,
        y_train,
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=(X_val, y_val),
        callbacks=[early_stopping, reduce_lr, model_checkpoint],
        verbose=1
    )
    
    return model, history

def evaluate_model(model, X_test, y_test_movement, y_test_knee, y_test_elbow, label_encoders):
    """
    הערכת המודל והצגת מדדי ביצוע
    """
    # ביצוע חיזוי
    y_pred_movement, y_pred_knee_prob, y_pred_elbow_prob = model.predict(X_test)
    
    # המרת הסתברויות לתוויות
    y_pred_knee = np.argmax(y_pred_knee_prob, axis=1)
    y_pred_elbow = np.argmax(y_pred_elbow_prob, axis=1)
    
    # מדדי ביצוע לציון תנועה כללי
    mse_movement = mean_squared_error(y_test_movement, y_pred_movement)
    '''
    ציון בין 0-10 שמודד עד כמה המודל שגה בחישוב ציון התנועה הכללי- כמה רחוק המודל היהי מהציון תנועה הכללי האמיתי שחושב
    '''
    rmse_movement = np.sqrt(mse_movement) 
    
    # מדדי ביצוע לסיווג ברך ומרפק דומיננטיים
    knee_accuracy = accuracy_score(y_test_knee, y_pred_knee)
    elbow_accuracy = accuracy_score(y_test_elbow, y_pred_elbow)
    
    print("\n===== תוצאות המודל =====")
    print(f"RMSE for motion score: {rmse_movement:.4f}")
    print(f"דיוק סיווג ברך דומיננטית: {knee_accuracy:.4f}")
    print(f"דיוק סיווג מרפק דומיננטי: {elbow_accuracy:.4f}")
    
    print("\nדוח סיווג - ברך דומיננטית:")
    print(classification_report(y_test_knee, y_pred_knee))
    
    print("\nדוח סיווג - מרפק דומיננטי:")
    print(classification_report(y_test_elbow, y_pred_elbow))
    
    # פענוח התוויות חזרה לערכים המקוריים (אם נדרש)
    if 'dominant_knee' in label_encoders:
        original_knee_labels = label_encoders['dominant_knee'].inverse_transform(range(len(label_encoders['dominant_knee'].classes_)))
        print("\nמיפוי תוויות ברך:")
        for i, label in enumerate(original_knee_labels):
            print(f"{i}: {label}")
    
    if 'dominant_elbow' in label_encoders:
        original_elbow_labels = label_encoders['dominant_elbow'].inverse_transform(range(len(label_encoders['dominant_elbow'].classes_)))
        print("\nמיפוי תוויות מרפק:")
        for i, label in enumerate(original_elbow_labels):
            print(f"{i}: {label}")
    
    return {
        'rmse_movement': rmse_movement,
        'knee_accuracy': knee_accuracy,
        'elbow_accuracy': elbow_accuracy
    }

def plot_training_history(history):
    """
    יצירת גרפים להצגת התקדמות האימון
    """
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))
    
    # עקומות שגיאה
    axes[0, 0].plot(history.history['loss'], label='Train Loss')
    axes[0, 0].plot(history.history['val_loss'], label='Validation Loss')
    axes[0, 0].set_title('Total Loss')
    axes[0, 0].set_xlabel('Epochs')
    axes[0, 0].set_ylabel('Loss')
    axes[0, 0].legend()
    
    # דיוק ברך דומיננטית
    axes[0, 1].plot(history.history['dominant_knee_accuracy'], label='Train Accuracy')
    axes[0, 1].plot(history.history['val_dominant_knee_accuracy'], label='Validation Accuracy')
    axes[0, 1].set_title('Dominant Knee Accuracy')
    axes[0, 1].set_xlabel('Epochs')
    axes[0, 1].set_ylabel('Accuracy')
    axes[0, 1].legend()
    
    # דיוק מרפק דומיננטי
    axes[1, 0].plot(history.history['dominant_elbow_accuracy'], label='Train Accuracy')
    axes[1, 0].plot(history.history['val_dominant_elbow_accuracy'], label='Validation Accuracy')
    axes[1, 0].set_title('Dominant Elbow Accuracy')
    axes[1, 0].set_xlabel('Epochs')
    axes[1, 0].set_ylabel('Accuracy')
    axes[1, 0].legend()
    
    # שגיאה ממוצעת מוחלטת לציון תנועה
    axes[1, 1].plot(history.history['movement_score_mae'], label='Train MAE')
    axes[1, 1].plot(history.history['val_movement_score_mae'], label='Validation MAE')
    axes[1, 1].set_title('Movement Score MAE')
    axes[1, 1].set_xlabel('Epochs')
    axes[1, 1].set_ylabel('MAE')
    axes[1, 1].legend()
    
    plt.tight_layout()
    plt.savefig('training_history.png')
    plt.show()

def main():
    # הגדרה ידנית של קובץ הנתונים
    file_paths = ['movenet_dataset.csv']
    
    if not os.path.exists('movenet_dataset.csv'):
        print("שגיאה: הקובץ 'movenet_dataset.csv' לא נמצא בתיקייה הנוכחית")
        return
    
    print(f"מתחיל עיבוד של הקובץ: {file_paths[0]}")
    
    # טעינת הנתונים
    try:
        data, label_encoders = load_and_preprocess_data(file_paths)
        print(f"נטענו {len(data)} שורות נתונים")
    except Exception as e:
        print(f"שגיאה בטעינת הנתונים: {e}")
        return
    
    # הכנת רצפי הנתונים
    X, y_movement, y_knee, y_elbow, feature_columns = prepare_sequences(data)
    
    print(f"מספר דוגמאות: {len(X)}")
    print(f"מספר מאפיינים: {X.shape[2]}")
    
    # ספירת מספר הקלאסים הייחודיים
    num_knee_classes = len(np.unique(y_knee))
    num_elbow_classes = len(np.unique(y_elbow))
    
    print(f"מספר קלאסים לברך דומיננטית: {num_knee_classes}")
    print(f"מספר קלאסים למרפק דומיננטי: {num_elbow_classes}")
    
    # חלוקת הנתונים לאימון ובדיקה
    X_train_val, X_test, y_movement_train_val, y_movement_test, \
    y_knee_train_val, y_knee_test, y_elbow_train_val, y_elbow_test = train_test_split(
        X, y_movement, y_knee, y_elbow, test_size=0.2, random_state=RANDOM_STATE
    )
    
    # חלוקה נוספת לאימון ותיקוף
    X_train, X_val, y_movement_train, y_movement_val, \
    y_knee_train, y_knee_val, y_elbow_train, y_elbow_val = train_test_split(
        X_train_val, y_movement_train_val, y_knee_train_val, y_elbow_train_val, 
        test_size=0.2, random_state=RANDOM_STATE
    )
    
    # נירמול הנתונים
    # אין צורך לנרמל את המאפיינים מאחר וכל דגימה היא רצף, 
    # ובמקום זאת נשתמש ב-BatchNormalization בתוך המודל
    
    # הגדרת צורת הקלט למודל
    input_shape = (X_train.shape[1], X_train.shape[2])
    
    # הגדרת הפלטים באופן מתאים לפורמט הנדרש עבור מודל עם פלט מרובה
    y_train = [y_movement_train, y_knee_train, y_elbow_train]
    y_val = [y_movement_val, y_knee_val, y_elbow_val]
    
    # אימון המודל
    model, history = train_model(
        X_train, y_train, X_val, y_val, 
        input_shape, num_knee_classes, num_elbow_classes
    )
    
    # הערכת המודל
    results = evaluate_model(
        model, X_test, y_movement_test, y_knee_test, y_elbow_test, label_encoders
    )
    
    # יצירת גרפים להצגת התקדמות האימון
    plot_training_history(history)
    
    # שמירת המודל
    '''
     הקובץ בו נשמר המודל האחרון לאחר סיום כל האפוקים (לא בהכרח הטוב ביותר
     '''
    model.save('infant_movement_gru_model.keras') 
    print("המודל נשמר בהצלחה כקובץ 'infant_movement_gru_model.keras'")
    
    # שמירת מידע על המאפיינים ששימשו לאימון (לשימוש עתידי)
    with open('model_features.txt', 'w') as f:
        f.write('\n'.join(feature_columns))
    
    print("\nהאימון הסתיים בהצלחה!")

if __name__ == "__main__":
    main()
# Out:
# מתחיל עיבוד של הקובץ: movenet_dataset.csv
# נטענו 55117 שורות נתונים
# מספר דוגמאות: 28174
# מספר מאפיינים: 40
# מספר קלאסים לברך דומיננטית: 2
# מספר קלאסים למרפק דומיננטי: 2
# Epoch 1/100
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - dominant_elbow_accuracy: 0.8775 - dominant_elbow_loss: 0.3587 - dominant_knee_accuracy: 0.8439 - dominant_knee_loss: 0.4338 - loss: 17.4701 - movement_score_loss: 16.6776 - movement_score_mae: 3.3388
# Epoch 1: val_loss improved from inf to 8.22765, saving model to best_infant_movement_model.keras
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 49s 59ms/step - dominant_elbow_accuracy: 0.8776 - dominant_elbow_loss: 0.3586 - dominant_knee_accuracy: 0.8439 - dominant_knee_loss: 0.4337 - loss: 17.4601 - movement_score_loss: 16.6677 - movement_score_mae: 3.3379 - val_dominant_elbow_accuracy: 0.9148 - val_dominant_elbow_loss: 0.2872 - val_dominant_knee_accuracy: 0.8991 - val_dominant_knee_loss: 0.3436 - val_loss: 8.2276 - val_movement_score_loss: 7.5971 - val_movement_score_mae: 2.5658 - learning_rate: 0.0010
# Epoch 2/100
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - dominant_elbow_accuracy: 0.9238 - dominant_elbow_loss: 0.2815 - dominant_knee_accuracy: 0.8952 - dominant_knee_loss: 0.3479 - loss: 9.1027 - movement_score_loss: 8.4733 - movement_score_mae: 2.5430
# Epoch 2: val_loss improved from 8.22765 to 8.21380, saving model to best_infant_movement_model.keras
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - dominant_elbow_accuracy: 0.9238 - dominant_elbow_loss: 0.2815 - dominant_knee_accuracy: 0.8952 - dominant_knee_loss: 0.3479 - loss: 9.1027 - movement_score_loss: 8.4734 - movement_score_mae: 2.5431 - val_dominant_elbow_accuracy: 0.9148 - val_dominant_elbow_loss: 0.2829 - val_dominant_knee_accuracy: 0.8991 - val_dominant_knee_loss: 0.3203 - val_loss: 8.2138 - val_movement_score_loss: 7.6103 - val_movement_score_mae: 2.5478 - learning_rate: 0.0010
# Epoch 3/100
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - dominant_elbow_accuracy: 0.9210 - dominant_elbow_loss: 0.2791 - dominant_knee_accuracy: 0.8952 - dominant_knee_loss: 0.3395 - loss: 8.9070 - movement_score_loss: 8.2884 - movement_score_mae: 2.5619
# Epoch 3: val_loss improved from 8.21380 to 7.42888, saving model to best_infant_movement_model.keras
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 30s 53ms/step - dominant_elbow_accuracy: 0.9210 - dominant_elbow_loss: 0.2791 - dominant_knee_accuracy: 0.8952 - dominant_knee_loss: 0.3395 - loss: 8.9070 - movement_score_loss: 8.2884 - movement_score_mae: 2.5619 - val_dominant_elbow_accuracy: 0.9148 - val_dominant_elbow_loss: 0.2794 - val_dominant_knee_accuracy: 0.8988 - val_dominant_knee_loss: 0.3191 - val_loss: 7.4289 - val_movement_score_loss: 6.8310 - val_movement_score_mae: 2.3813 - learning_rate: 0.0010
# Epoch 4/100
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - dominant_elbow_accuracy: 0.9212 - dominant_elbow_loss: 0.2741 - dominant_knee_accuracy: 0.8945 - dominant_knee_loss: 0.3340 - loss: 8.3698 - movement_score_loss: 7.7616 - movement_score_mae: 2.4620
# Epoch 4: val_loss did not improve from 7.42888
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 28s 50ms/step - dominant_elbow_accuracy: 0.9212 - dominant_elbow_loss: 0.2741 - dominant_knee_accuracy: 0.8945 - dominant_knee_loss: 0.3340 - loss: 8.3700 - movement_score_loss: 7.7619 - movement_score_mae: 2.4621 - val_dominant_elbow_accuracy: 0.9148 - val_dominant_elbow_loss: 0.2864 - val_dominant_knee_accuracy: 0.8993 - val_dominant_knee_loss: 0.3226 - val_loss: 7.9945 - val_movement_score_loss: 7.3860 - val_movement_score_mae: 2.4828 - learning_rate: 0.0010
# Epoch 5/100
# 563/564 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - dominant_elbow_accuracy: 0.9229 - dominant_elbow_loss: 0.2705 - dominant_knee_accuracy: 0.8976 - dominant_knee_loss: 0.3262 - loss: 8.5621 - movement_score_loss: 7.9653 - movement_score_mae: 2.5145
# Epoch 5: val_loss did not improve from 7.42888
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 29s 51ms/step - dominant_elbow_accuracy: 0.9229 - dominant_elbow_loss: 0.2705 - dominant_knee_accuracy: 0.8976 - dominant_knee_loss: 0.3262 - loss: 8.5620 - movement_score_loss: 7.9652 - movement_score_mae: 2.5145 - val_dominant_elbow_accuracy: 0.9148 - val_dominant_elbow_loss: 0.2847 - val_dominant_knee_accuracy: 0.8991 - val_dominant_knee_loss: 0.3238 - val_loss: 7.8317 - val_movement_score_loss: 7.2231 - val_movement_score_mae: 2.5312 - learning_rate: 0.0010
# Epoch 6/100
# 563/564 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - dominant_elbow_accuracy: 0.9224 - dominant_elbow_loss: 0.2724 - dominant_knee_accuracy: 0.9017 - dominant_knee_loss: 0.3163 - loss: 8.2694 - movement_score_loss: 7.6806 - movement_score_mae: 2.4959
# Epoch 6: val_loss did not improve from 7.42888
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 31s 54ms/step - dominant_elbow_accuracy: 0.9224 - dominant_elbow_loss: 0.2724 - dominant_knee_accuracy: 0.9017 - dominant_knee_loss: 0.3164 - loss: 8.2695 - movement_score_loss: 7.6807 - movement_score_mae: 2.4959 - val_dominant_elbow_accuracy: 0.9148 - val_dominant_elbow_loss: 0.2901 - val_dominant_knee_accuracy: 0.8988 - val_dominant_knee_loss: 0.3181 - val_loss: 7.7235 - val_movement_score_loss: 7.1162 - val_movement_score_mae: 2.4774 - learning_rate: 0.0010
# Epoch 7/100
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - dominant_elbow_accuracy: 0.9227 - dominant_elbow_loss: 0.2701 - dominant_knee_accuracy: 0.8941 - dominant_knee_loss: 0.3304 - loss: 8.1292 - movement_score_loss: 7.5288 - movement_score_mae: 2.4805
# Epoch 7: val_loss did not improve from 7.42888
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 30s 53ms/step - dominant_elbow_accuracy: 0.9227 - dominant_elbow_loss: 0.2701 - dominant_knee_accuracy: 0.8941 - dominant_knee_loss: 0.3304 - loss: 8.1292 - movement_score_loss: 7.5287 - movement_score_mae: 2.4805 - val_dominant_elbow_accuracy: 0.9148 - val_dominant_elbow_loss: 0.2851 - val_dominant_knee_accuracy: 0.8991 - val_dominant_knee_loss: 0.3180 - val_loss: 7.9691 - val_movement_score_loss: 7.3664 - val_movement_score_mae: 2.4743 - learning_rate: 0.0010
# Epoch 8/100
# 563/564 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - dominant_elbow_accuracy: 0.9249 - dominant_elbow_loss: 0.2659 - dominant_knee_accuracy: 0.8952 - dominant_knee_loss: 0.3274 - loss: 7.8838 - movement_score_loss: 7.2905 - movement_score_mae: 2.4187
# Epoch 8: val_loss did not improve from 7.42888
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 31s 54ms/step - dominant_elbow_accuracy: 0.9249 - dominant_elbow_loss: 0.2659 - dominant_knee_accuracy: 0.8952 - dominant_knee_loss: 0.3274 - loss: 7.8841 - movement_score_loss: 7.2908 - movement_score_mae: 2.4188 - val_dominant_elbow_accuracy: 0.9144 - val_dominant_elbow_loss: 0.2720 - val_dominant_knee_accuracy: 0.8991 - val_dominant_knee_loss: 0.3195 - val_loss: 7.5270 - val_movement_score_loss: 6.9355 - val_movement_score_mae: 2.4266 - learning_rate: 0.0010
# Epoch 9/100
# 563/564 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - dominant_elbow_accuracy: 0.9198 - dominant_elbow_loss: 0.2723 - dominant_knee_accuracy: 0.8923 - dominant_knee_loss: 0.3317 - loss: 7.6341 - movement_score_loss: 7.0302 - movement_score_mae: 2.3609
# Epoch 9: val_loss improved from 7.42888 to 7.12426, saving model to best_infant_movement_model.keras
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 30s 53ms/step - dominant_elbow_accuracy: 0.9199 - dominant_elbow_loss: 0.2722 - dominant_knee_accuracy: 0.8923 - dominant_knee_loss: 0.3316 - loss: 7.6336 - movement_score_loss: 7.0297 - movement_score_mae: 2.3608 - val_dominant_elbow_accuracy: 0.9142 - val_dominant_elbow_loss: 0.2766 - val_dominant_knee_accuracy: 0.8991 - val_dominant_knee_loss: 0.3104 - val_loss: 7.1243 - val_movement_score_loss: 6.5380 - val_movement_score_mae: 2.2449 - learning_rate: 5.0000e-04
# Epoch 10/100
# 563/564 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - dominant_elbow_accuracy: 0.9213 - dominant_elbow_loss: 0.2644 - dominant_knee_accuracy: 0.8976 - dominant_knee_loss: 0.3099 - loss: 7.2270 - movement_score_loss: 6.6527 - movement_score_mae: 2.2537
# Epoch 10: val_loss improved from 7.12426 to 6.59829, saving model to best_infant_movement_model.keras
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 29s 51ms/step - dominant_elbow_accuracy: 0.9213 - dominant_elbow_loss: 0.2644 - dominant_knee_accuracy: 0.8976 - dominant_knee_loss: 0.3099 - loss: 7.2266 - movement_score_loss: 6.6523 - movement_score_mae: 2.2535 - val_dominant_elbow_accuracy: 0.9157 - val_dominant_elbow_loss: 0.2747 - val_dominant_knee_accuracy: 0.8991 - val_dominant_knee_loss: 0.3117 - val_loss: 6.5983 - val_movement_score_loss: 6.0120 - val_movement_score_mae: 2.0855 - learning_rate: 5.0000e-04
# Epoch 11/100
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - dominant_elbow_accuracy: 0.9235 - dominant_elbow_loss: 0.2529 - dominant_knee_accuracy: 0.8981 - dominant_knee_loss: 0.3072 - loss: 6.8262 - movement_score_loss: 6.2662 - movement_score_mae: 2.1423
# Epoch 11: val_loss improved from 6.59829 to 6.49078, saving model to best_infant_movement_model.keras
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 29s 52ms/step - dominant_elbow_accuracy: 0.9235 - dominant_elbow_loss: 0.2529 - dominant_knee_accuracy: 0.8981 - dominant_knee_loss: 0.3072 - loss: 6.8261 - movement_score_loss: 6.2660 - movement_score_mae: 2.1422 - val_dominant_elbow_accuracy: 0.9184 - val_dominant_elbow_loss: 0.2626 - val_dominant_knee_accuracy: 0.8988 - val_dominant_knee_loss: 0.3071 - val_loss: 6.4908 - val_movement_score_loss: 5.9195 - val_movement_score_mae: 2.0223 - learning_rate: 5.0000e-04
# Epoch 12/100
# 563/564 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - dominant_elbow_accuracy: 0.9205 - dominant_elbow_loss: 0.2628 - dominant_knee_accuracy: 0.8931 - dominant_knee_loss: 0.3174 - loss: 6.5912 - movement_score_loss: 6.0110 - movement_score_mae: 2.0741
# Epoch 12: val_loss did not improve from 6.49078
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 30s 54ms/step - dominant_elbow_accuracy: 0.9205 - dominant_elbow_loss: 0.2628 - dominant_knee_accuracy: 0.8931 - dominant_knee_loss: 0.3174 - loss: 6.5913 - movement_score_loss: 6.0111 - movement_score_mae: 2.0741 - val_dominant_elbow_accuracy: 0.9155 - val_dominant_elbow_loss: 0.2652 - val_dominant_knee_accuracy: 0.8988 - val_dominant_knee_loss: 0.3085 - val_loss: 6.5130 - val_movement_score_loss: 5.9394 - val_movement_score_mae: 2.0188 - learning_rate: 5.0000e-04
# Epoch 13/100
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - dominant_elbow_accuracy: 0.9229 - dominant_elbow_loss: 0.2550 - dominant_knee_accuracy: 0.8966 - dominant_knee_loss: 0.3035 - loss: 6.3127 - movement_score_loss: 5.7543 - movement_score_mae: 2.0115
# Epoch 13: val_loss did not improve from 6.49078
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 30s 53ms/step - dominant_elbow_accuracy: 0.9229 - dominant_elbow_loss: 0.2549 - dominant_knee_accuracy: 0.8966 - dominant_knee_loss: 0.3035 - loss: 6.3127 - movement_score_loss: 5.7542 - movement_score_mae: 2.0114 - val_dominant_elbow_accuracy: 0.9181 - val_dominant_elbow_loss: 0.2729 - val_dominant_knee_accuracy: 0.8991 - val_dominant_knee_loss: 0.3037 - val_loss: 6.5051 - val_movement_score_loss: 5.9298 - val_movement_score_mae: 1.9599 - learning_rate: 5.0000e-04
# Epoch 14/100
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - dominant_elbow_accuracy: 0.9210 - dominant_elbow_loss: 0.2556 - dominant_knee_accuracy: 0.8949 - dominant_knee_loss: 0.3054 - loss: 6.1054 - movement_score_loss: 5.5444 - movement_score_mae: 1.9499
# Epoch 14: val_loss improved from 6.49078 to 5.60461, saving model to best_infant_movement_model.keras
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 31s 54ms/step - dominant_elbow_accuracy: 0.9210 - dominant_elbow_loss: 0.2556 - dominant_knee_accuracy: 0.8949 - dominant_knee_loss: 0.3054 - loss: 6.1054 - movement_score_loss: 5.5444 - movement_score_mae: 1.9499 - val_dominant_elbow_accuracy: 0.9179 - val_dominant_elbow_loss: 0.2564 - val_dominant_knee_accuracy: 0.8991 - val_dominant_knee_loss: 0.2966 - val_loss: 5.6046 - val_movement_score_loss: 5.0506 - val_movement_score_mae: 1.8025 - learning_rate: 5.0000e-04
# Epoch 15/100
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - dominant_elbow_accuracy: 0.9217 - dominant_elbow_loss: 0.2566 - dominant_knee_accuracy: 0.8922 - dominant_knee_loss: 0.3085 - loss: 6.0350 - movement_score_loss: 5.4699 - movement_score_mae: 1.9225
# Epoch 15: val_loss improved from 5.60461 to 5.45072, saving model to best_infant_movement_model.keras
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 30s 53ms/step - dominant_elbow_accuracy: 0.9217 - dominant_elbow_loss: 0.2566 - dominant_knee_accuracy: 0.8922 - dominant_knee_loss: 0.3085 - loss: 6.0347 - movement_score_loss: 5.4697 - movement_score_mae: 1.9224 - val_dominant_elbow_accuracy: 0.9181 - val_dominant_elbow_loss: 0.2497 - val_dominant_knee_accuracy: 0.8991 - val_dominant_knee_loss: 0.2889 - val_loss: 5.4507 - val_movement_score_loss: 4.9112 - val_movement_score_mae: 1.7870 - learning_rate: 5.0000e-04
# Epoch 16/100
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - dominant_elbow_accuracy: 0.9221 - dominant_elbow_loss: 0.2476 - dominant_knee_accuracy: 0.8939 - dominant_knee_loss: 0.3030 - loss: 5.6243 - movement_score_loss: 5.0737 - movement_score_mae: 1.8250
# Epoch 16: val_loss did not improve from 5.45072
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 30s 53ms/step - dominant_elbow_accuracy: 0.9221 - dominant_elbow_loss: 0.2476 - dominant_knee_accuracy: 0.8939 - dominant_knee_loss: 0.3030 - loss: 5.6244 - movement_score_loss: 5.0738 - movement_score_mae: 1.8250 - val_dominant_elbow_accuracy: 0.9195 - val_dominant_elbow_loss: 0.2626 - val_dominant_knee_accuracy: 0.8995 - val_dominant_knee_loss: 0.2955 - val_loss: 5.6082 - val_movement_score_loss: 5.0510 - val_movement_score_mae: 1.7933 - learning_rate: 5.0000e-04
# Epoch 17/100
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - dominant_elbow_accuracy: 0.9205 - dominant_elbow_loss: 0.2526 - dominant_knee_accuracy: 0.8969 - dominant_knee_loss: 0.2942 - loss: 5.7549 - movement_score_loss: 5.2081 - movement_score_mae: 1.8442
# Epoch 17: val_loss improved from 5.45072 to 4.97964, saving model to best_infant_movement_model.keras
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 30s 54ms/step - dominant_elbow_accuracy: 0.9205 - dominant_elbow_loss: 0.2526 - dominant_knee_accuracy: 0.8969 - dominant_knee_loss: 0.2942 - loss: 5.7546 - movement_score_loss: 5.2078 - movement_score_mae: 1.8441 - val_dominant_elbow_accuracy: 0.9188 - val_dominant_elbow_loss: 0.2469 - val_dominant_knee_accuracy: 0.9008 - val_dominant_knee_loss: 0.2833 - val_loss: 4.9796 - val_movement_score_loss: 4.4507 - val_movement_score_mae: 1.5954 - learning_rate: 5.0000e-04
# Epoch 18/100
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - dominant_elbow_accuracy: 0.9232 - dominant_elbow_loss: 0.2448 - dominant_knee_accuracy: 0.8941 - dominant_knee_loss: 0.2930 - loss: 5.2968 - movement_score_loss: 4.7590 - movement_score_mae: 1.7186
# Epoch 18: val_loss improved from 4.97964 to 4.81726, saving model to best_infant_movement_model.keras
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 31s 55ms/step - dominant_elbow_accuracy: 0.9232 - dominant_elbow_loss: 0.2448 - dominant_knee_accuracy: 0.8941 - dominant_knee_loss: 0.2930 - loss: 5.2968 - movement_score_loss: 4.7590 - movement_score_mae: 1.7186 - val_dominant_elbow_accuracy: 0.9159 - val_dominant_elbow_loss: 0.2456 - val_dominant_knee_accuracy: 0.9004 - val_dominant_knee_loss: 0.2849 - val_loss: 4.8173 - val_movement_score_loss: 4.2863 - val_movement_score_mae: 1.5903 - learning_rate: 5.0000e-04
# Epoch 19/100
# 563/564 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - dominant_elbow_accuracy: 0.9237 - dominant_elbow_loss: 0.2397 - dominant_knee_accuracy: 0.8944 - dominant_knee_loss: 0.2884 - loss: 5.0434 - movement_score_loss: 4.5153 - movement_score_mae: 1.6493
# Epoch 19: val_loss did not improve from 4.81726
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 30s 53ms/step - dominant_elbow_accuracy: 0.9237 - dominant_elbow_loss: 0.2397 - dominant_knee_accuracy: 0.8944 - dominant_knee_loss: 0.2884 - loss: 5.0437 - movement_score_loss: 4.5156 - movement_score_mae: 1.6493 - val_dominant_elbow_accuracy: 0.9159 - val_dominant_elbow_loss: 0.2510 - val_dominant_knee_accuracy: 0.8991 - val_dominant_knee_loss: 0.2873 - val_loss: 5.6553 - val_movement_score_loss: 5.1165 - val_movement_score_mae: 1.6467 - learning_rate: 5.0000e-04
# Epoch 20/100
# 563/564 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - dominant_elbow_accuracy: 0.9206 - dominant_elbow_loss: 0.2470 - dominant_knee_accuracy: 0.8988 - dominant_knee_loss: 0.2862 - loss: 5.2035 - movement_score_loss: 4.6703 - movement_score_mae: 1.6815
# Epoch 20: val_loss improved from 4.81726 to 4.45151, saving model to best_infant_movement_model.keras
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 30s 53ms/step - dominant_elbow_accuracy: 0.9206 - dominant_elbow_loss: 0.2470 - dominant_knee_accuracy: 0.8988 - dominant_knee_loss: 0.2862 - loss: 5.2029 - movement_score_loss: 4.6697 - movement_score_mae: 1.6813 - val_dominant_elbow_accuracy: 0.9164 - val_dominant_elbow_loss: 0.2385 - val_dominant_knee_accuracy: 0.8991 - val_dominant_knee_loss: 0.2824 - val_loss: 4.4515 - val_movement_score_loss: 3.9300 - val_movement_score_mae: 1.4862 - learning_rate: 5.0000e-04
# Epoch 21/100
# 563/564 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - dominant_elbow_accuracy: 0.9226 - dominant_elbow_loss: 0.2380 - dominant_knee_accuracy: 0.8964 - dominant_knee_loss: 0.2846 - loss: 4.8259 - movement_score_loss: 4.3033 - movement_score_mae: 1.5930
# Epoch 21: val_loss improved from 4.45151 to 4.42620, saving model to best_infant_movement_model.keras
# 564/564 ━━━━━━━━━━━━━━━━━━━━ 32s 57ms/step - dominant_elbow_accuracy: 0.9226 - dominant_elbow_loss: 0.2380 - dominant_knee_accuracy: 0.8964 - dominant_knee_loss: 0.2846 - loss: 4.8258 - movement_score_loss: 4.3032 - movement_score_mae: 1.5930 - val_dominant_elbow_accuracy: 0.9188 - val_dominant_elbow_loss: 0.2477 - val_dominant_knee_accuracy: 0.9006 - val_dominant_knee_loss: 0.2820 - val_loss: 4.4262 - val_movement_score_loss: 3.8958 - val_movement_score_mae: 1.4440 - learning_rate: 5.0000e-04
# Epoch 22/100
# 214/564 ━━━━━━━━━━━━━━━━━━━━ 17s 51ms/step - dominant_elbow_accuracy: 0.9225 - dominant_elbow_loss: 0.2418 - dominant_knee_accuracy: 0.9018 - dominant_knee_loss: 0.2739 - loss: 4.7637 - movement_score_loss: 4.2480 - movement_score_mae: 1.5720
